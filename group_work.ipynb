# %%
import pandas as pd
import os
import sklearn
from PIL import Image
import numpy as np
import logging

# %%
class WildScenesDataset:
    _data_list_dir = os.path.join('datasets', 'data_list')
    _csv_files = {
        'train': os.path.join(_data_list_dir, 'train.csv'),
        'valid': os.path.join(_data_list_dir, 'valid.csv'),
        'test': os.path.join(_data_list_dir, 'test.csv'),
    }
    csv = _csv_files
    _label_to_trainid = {
        1: 15,  # Ignored class
        2: 0,  # Bush
        3: 1,  # Dirt
        4: 2,  # Fence
        5: 3,  # Grass
        6: 4,  # Gravel
        7: 5,  # Log
        8: 6,  # Mud
        9: 7,  # Other-Object
        10: 8,  # Other-terrain
        11: 15,  # Ignored class
        12: 9,  # Rock
        13: 10,  # Sky
        14: 11,  # Structure
        15: 12,  # Tree-foliage
        16: 13,  # Tree-trunk
        17: 15,  # Ignored class
        18: 14,  # Water
    }
    def __init__(self, dataset_type, transform=None):
        assert dataset_type in ('train', 'valid', 'test')
        self._dataset_type = dataset_type
        self._data_frame = pd.read_csv(WildScenesDataset._csv_files[self._dataset_type])
        self._transform = transform

    def __len__(self):
        return len(self._data_frame)

    def __getitem__(self, index):
        if index >= len(self):
            raise IndexError(f"Index {index} out of bounds for dataset of size {len(self)}")
        try:
            image_path = self._data_frame['image'].iloc[index]
            label_path = self._data_frame['label'].iloc[index]

            image = Image.open(image_path).convert('RGB')
            label = Image.open(label_path).convert('L')
            # 将灰度图转换为Numpy数组
            label_np = np.array(label)

            # 将标签索引映射到训练标识（trainId）值
            label_trainId = np.vectorize(lambda x: self._label_to_trainid.get(x, 255))(label_np)

            if self._transform is not None:
                for t in self._transform:
                    image, label_trainId = t(image, label_trainId)

            return image, label_trainId
        except Exception as e:
            logging.error(f"Error loading item at index {index}: {str(e)}")

    @staticmethod
    def _get_image_label_dir():
        """
        Traverse server image and label directories and yield image and label paths.
        :return: Generator yielding (image path, label path)
        """
        data_err = 'data error. check!'
        image_base = WildScenesDataset.image_file_base
        label_base = WildScenesDataset.label_file_base

        for image in os.listdir(image_base):
            image_origin = os.path.join(image_base, image)
            image_label = os.path.join(label_base, image)

            if not (os.path.isfile(image_label) and
                    os.path.exists(image_label) and
                    os.path.isfile(image_label)):
                print(image_origin, image_label, data_err)  # Print error message and skip if paths are invalid
                continue

            yield image_origin, image_label

    @staticmethod
    def make_data_list(train_rate=0.7, valid_rate=0.2, shuffle=True):
        """
        Shuffle and generate data_list CSV files with image and label paths sorted by filename.
        :param train_rate: Training set ratio, default 0.7
        :param valid_rate: Validation set ratio, default 0.2
        :param shuffle: Whether to shuffle the dataset, default True
        :return: None
        """
        g = WildScenesDataset._get_image_label_dir()  # Get generator
        abspaths = list(g)  # Convert generator to list

        # Create DataFrame with image and label paths
        df = pd.DataFrame(
            data=abspaths,
            columns=['image', 'label']
        )

        # Sort DataFrame by filename (assumed to be timestamp in a sortable format)
        df['timestamp'] = df['image'].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('-')[0]))
        df = df.sort_values(by='timestamp').reset_index(drop=True)

        if shuffle:
            df = sklearn.utils.shuffle(df)  # Shuffle dataframe if specified

        # Calculate sizes for train, valid, and test sets
        train_size = int(df.shape[0] * train_rate)
        valid_size = int(df.shape[0] * valid_rate)

        print('total: {:d} | train: {:d} | val: {:d} | test: {:d}'.format(
            df.shape[0], train_size, valid_size,
            df.shape[0] - train_size - valid_size))

        # Split dataframe into train, valid, and test sets
        df_train = df[0: train_size]
        df_valid = df[train_size: train_size + valid_size]
        df_test = df[train_size + valid_size:]

        # Save train, valid, and test sets to CSV files
        df_train[['image', 'label']].to_csv(os.path.join(WildScenesDataset.csv['train']), index=False)
        df_valid[['image', 'label']].to_csv(os.path.join(WildScenesDataset.csv['valid']), index=False)
        df_test[['image', 'label']].to_csv(os.path.join(WildScenesDataset.csv['test']), index=False)

    # 测试語義分割時用
    @staticmethod
    def test_label_mapping(label_path):
        """
        Test the label mapping for a single label image.

        :param label_path: Path to the label image
        :return: Tuple of original label numpy array and mapped trainId numpy array
        """
        # Open the label image and convert to numpy array
        label = Image.open(label_path).convert('L')
        label_np = np.array(label, dtype=np.uint8)

        # Map label indices to trainId values
        label_trainId = np.vectorize(lambda x: WildScenesDataset._label_to_trainid.get(x, 255))(label_np)

        return label_np, label_trainId

# %%
# Example usage
root_dir = os.path.join('..', 'WildScenes_Dataset-61gd5a0t-', 'data', 'WildScenes', 'WildScenes2d', 'V-01')
WildScenesDataset.image_file_base = os.path.join(root_dir, 'image')
WildScenesDataset.label_file_base = os.path.join(root_dir, 'indexLabel')
WildScenesDataset.make_data_list()

# Test label mapping for the first image in labelIndex
test_label_path = os.path.join(WildScenesDataset.label_file_base,
                               '1623370408-092005506.png')  # Replace with an actual image name
original_label, mapped_label = WildScenesDataset.test_label_mapping(test_label_path)

print("Original label array (shape: {}):".format(original_label.shape))
print(original_label)
print("\nMapped trainId array (shape: {}):".format(mapped_label.shape))
print(mapped_label)

# Optional: print unique values in each array
print("\nUnique values in original label array:", np.unique(original_label))
print("Unique values in mapped trainId array:", np.unique(mapped_label))
# Out:
# total: 1576 | train: 1103 | val: 315 | test: 158
# Original label array (shape: (1512, 2016)):
# [[ 8  8  8 ...  8  8  8]
#  [ 8  8  8 ...  8  8  8]
#  [ 8  8  8 ...  8  8  8]
#  ...
#  [18 18 18 ...  2  2  2]
#  [18 18 18 ...  2  2  2]
#  [18 18 18 ...  2  2  2]]
#
# Mapped trainId array (shape: (1512, 2016)):
# [[ 6  6  6 ...  6  6  6]
#  [ 6  6  6 ...  6  6  6]
#  [ 6  6  6 ...  6  6  6]
#  ...
#  [14 14 14 ...  0  0  0]
#  [14 14 14 ...  0  0  0]
#  [14 14 14 ...  0  0  0]]
#
# Unique values in original label array: [ 2  7  8 14 15 16 17 18]
# Unique values in mapped trainId array: [ 0  5  6 11 12 13 14 15]

# %%
import random
import torch
import numpy as np
from torchvision.transforms import functional as TF
import cv2
from PIL import Image

class TrainTransform:
    def __init__(self, size=256, gaussian_prob=0.5, gaussian_kernel=(5, 5), gaussian_sigma=(0.1, 2.0)):
        self.size = (size, size)  # Changed to tuple
        self.gaussian_prob = gaussian_prob
        self.gaussian_kernel = gaussian_kernel
        self.gaussian_sigma = gaussian_sigma

    def __call__(self, image, label):
        # Resize
        image = TF.resize(image, self.size)
        label = TF.resize(label, self.size, interpolation=TF.InterpolationMode.NEAREST)

        # Random horizontal flip
        if random.random() > 0.5:
            image = TF.hflip(image)
            label = TF.hflip(label)

        # Random rotation
        angle = random.uniform(-10, 10)
        image = TF.rotate(image, angle)
        label = TF.rotate(label, angle, interpolation=TF.InterpolationMode.NEAREST)

        # Random Gaussian blur
        if random.random() < self.gaussian_prob:
            sigma = random.uniform(self.gaussian_sigma[0], self.gaussian_sigma[1])
            image_np = np.array(image)
            image_np = cv2.GaussianBlur(image_np, self.gaussian_kernel, sigma)
            image = Image.fromarray(image_np)

        # Convert to tensor and normalize
        image = TF.to_tensor(image)
        image = TF.normalize(image, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        label = torch.from_numpy(np.array(label)).long()

        # Verify shapes
        assert image.shape[0] == 3, f"Image should have 3 channels, got {image.shape[0]}"
        assert image.shape[1] == image.shape[2] == self.size[0], f"Image should be square with size {self.size[0]}, got shape {image.shape}"
        assert label.shape == image.shape[1:], f"Label shape {label.shape} doesn't match image shape {image.shape[1:]}"

        return image, label

class TestTransform:
    def __init__(self, size=256):
        self.size = (size, size)  # Changed to tuple

    def __call__(self, image, label):
        # Resize
        image = TF.resize(image, self.size)
        label = TF.resize(label, self.size, interpolation=TF.InterpolationMode.NEAREST)

        # Convert to tensor and normalize
        image = TF.to_tensor(image)
        image = TF.normalize(image, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        label = torch.from_numpy(np.array(label)).long()

        # Verify shapes
        assert image.shape[0] == 3, f"Image should have 3 channels, got {image.shape[0]}"
        assert image.shape[1] == image.shape[2] == self.size[0], f"Image should be square with size {self.size[0]}, got shape {image.shape}"
        assert label.shape == image.shape[1:], f"Label shape {label.shape} doesn't match image shape {image.shape[1:]}"

        return image, label

# %%
import os
import sys
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image

# 假设这些导入是正确的，如果不是，请相应调整

# from transforms import TrainTransform, TestTransform

color_map = {
    0: [224, 31, 77],  # Bush
    1: [64, 180, 78],  # Dirt
    2: [26, 127, 127],  # Fence
    3: [127, 127, 127],  # Grass
    4: [145, 24, 178],  # Gravel
    5: [125, 128, 16],  # Log
    6: [251, 225, 48],  # Mud
    7: [248, 190, 190],  # Other-object
    8: [89, 239, 239],  # Other-terrain
    9: [173, 255, 196],  # Rock
    10: [19, 0, 126],  # Sky
    11: [167, 110, 44],  # Structure
    12: [208, 245, 71],  # Tree-foliage
    13: [238, 47, 227],  # Tree-trunk
    14: [40, 127, 198],  # Water
}

class EnhancedWildScenesDataset(WildScenesDataset):
    def __init__(self, dataset_type, transform=None):
        super().__init__(dataset_type, transform)
        self.color_map = self._load_color_map()
        self.transform = self._get_transform(dataset_type)

    def __getitem__(self, index):
        image_path = self._data_frame['image'][index]
        label_path = self._data_frame['label'][index]

        image = Image.open(image_path).convert('RGB')
        # Use test_label_mapping to get both original and mapped labels
        original_label, mapped_label = self.test_label_mapping(label_path)

        # Convert numpy array to PIL Image for compatibility with transforms
        label = Image.fromarray(mapped_label.astype(np.uint8))

        if self.transform is not None:
            image, label = self.transform(image, label)

        # Verify shapes
        # assert image.shape[0] == 3, f"Image should have 3 channels, got {image.shape[0]}"
        # assert image.shape[1] == image.shape[2], f"Image should be square, got shape {image.shape}"
        # assert label.shape == image.shape[1:], f"Label shape {label.shape} doesn't match image shape {image.shape[1:]}"

        return image, label

    def _load_color_map(self):
        return {key: np.array(value) for key, value in color_map.items()}

    def _get_transform(self, dataset_type):
        if dataset_type == 'train':
            return TrainTransform()
        elif dataset_type in ['valid', 'test']:
            return TestTransform()
        else:
            raise ValueError('Invalid dataset type')

    @staticmethod
    def get_color_coded_label(label_trainId):
        """
        Convert trainId label to RGB color-coded label.
        :param label_trainId: numpy array of trainId labels
        :return: numpy array of RGB color-coded labels
        """
        height, width = label_trainId.shape
        label_RGB = np.zeros((height, width, 3), dtype=np.uint8)
        for trainId, color in color_map.items():
            label_RGB[label_trainId == trainId] = color
        return label_RGB

def get_data_loader(dataset_type, batch_size=4):
    dataset = EnhancedWildScenesDataset(dataset_type)
    shuffle = dataset_type == 'train'
    return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, num_workers=0, pin_memory=True, drop_last=True)

# 测试data_loader
train_loader = get_data_loader('train', batch_size=4)
for images, labels in train_loader:
    print(f"Batch image shape: {images.shape}") # 一個批次的圖像數據形狀，一個批次4個圖象，每個圖象3通道，每個圖像尺寸256*341
    print(f"Batch label shape: {labels.shape}") # 一個批次的label數據形狀，單通道，表示的是trainId標注的
    print(f"Batch label unique values: {torch.unique(labels)}")
    break

dataset = EnhancedWildScenesDataset('train')
image, label = dataset[0]
color_coded_label = dataset.get_color_coded_label(label.numpy())
print(f"Color-coded label shape: {color_coded_label.shape}") # 使用顔色編碼的label圖像形狀，發現是3通道，成了！
# Out:
# Batch image shape: torch.Size([4, 3, 256, 256])
# Batch label shape: torch.Size([4, 256, 256])
# Batch label unique values: tensor([ 0,  3,  5,  6,  9, 12, 13, 14, 15])
# Color-coded label shape: (256, 256, 3)

# %%
import torch
import torch.optim as optim
from torch.optim.lr_scheduler import OneCycleLR
from torch.cuda.amp import GradScaler, autocast
from data_load import EnhancedWildScenesDataset
from tqdm import tqdm
import numpy as np
import os
import logging
from utils.metrics import calculate_miou_train, calculate_pixel_accuracy, calculate_dice_coefficient
from utils.losses import CombinedLoss
from models.custom_deeplabv3 import CustomDeepLabV3
from models.dense_unet import DenseUNet, TransitionUp, DenseBlock
from PIL import Image
import torch.nn as nn
import torch.nn.functional as F
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

def train_epoch(model, dataloader, criterion, optimizer, scheduler, device, num_classes, scaler):
    model.train()
    total_loss = 0
    total_miou = 0
    total_pixel_acc = 0
    total_dice = 0
    num_batches = 0

    for images, labels in tqdm(dataloader, desc="Training"):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        with torch.cuda.amp.autocast():
            outputs = model(images)
            outputs = outputs['out'] if isinstance(outputs, dict) else outputs

            if len(labels.shape) == 4 and labels.shape[1] > 1:
                labels = torch.argmax(labels, dim=1)

            if outputs.shape[2:] != labels.shape[1:]:
                outputs = F.interpolate(outputs, size=labels.shape[1:], mode='bilinear', align_corners=True)

            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        scheduler.step()

        total_loss += loss.item()
        pred = torch.argmax(outputs, dim=1)
        miou = calculate_miou_train(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)
        pixel_acc = calculate_pixel_accuracy(pred.cpu().numpy(), labels.cpu().numpy())
        dice = calculate_dice_coefficient(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)

        if not np.isnan(miou):
            total_miou += miou
            total_pixel_acc += pixel_acc
            total_dice += dice
            num_batches += 1

    return (total_loss / len(dataloader),
            total_miou / num_batches if num_batches > 0 else 0.0,
            total_pixel_acc / num_batches if num_batches > 0 else 0.0,
            total_dice / num_batches if num_batches > 0 else 0.0)


def validate_epoch(model, dataloader, criterion, device, num_classes):
    model.eval()
    total_loss = 0
    total_miou = 0
    total_pixel_acc = 0
    total_dice = 0

    with torch.no_grad():
        for images, labels in tqdm(dataloader, desc="Validating"):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            outputs = outputs['out'] if isinstance(outputs, dict) else outputs

            if len(labels.shape) == 4 and labels.shape[1] > 1:
                labels = torch.argmax(labels, dim=1)

            if outputs.shape[2:] != labels.shape[1:]:
                outputs = F.interpolate(outputs, size=labels.shape[1:], mode='bilinear', align_corners=True)

            loss = criterion(outputs, labels)

            total_loss += loss.item()
            pred = torch.argmax(outputs, dim=1)
            miou = calculate_miou_train(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)
            pixel_acc = calculate_pixel_accuracy(pred.cpu().numpy(), labels.cpu().numpy())
            dice = calculate_dice_coefficient(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)

            total_miou += miou
            total_pixel_acc += pixel_acc
            total_dice += dice

    num_batches = len(dataloader)
    return (total_loss / num_batches,
            total_miou / num_batches,
            total_pixel_acc / num_batches,
            total_dice / num_batches)


def save_checkpoint(model, optimizer, epoch, metrics, filename):
    # 保存检查点
    state = {
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'epoch': epoch,
        'metrics': metrics
    }
    torch.save(state, filename)


def setup_logger(log_file):
    # 设置日志记录器
    logging.basicConfig(filename=log_file, level=logging.INFO,
                        format='%(asctime)s - %(levelname)s - %(message)s')
    console = logging.StreamHandler()
    console.setLevel(logging.INFO)
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    console.setFormatter(formatter)
    logging.getLogger('').addHandler(console)


def train(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device, save_dir, num_classes):
    # 训练模型的主函数
    best_miou = 0
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    scaler = GradScaler()

    for epoch in range(num_epochs):
        current_epoch = epoch + 1
        logging.info(f"Epoch {current_epoch}/{num_epochs}")

        train_loss, train_miou, train_pixel_acc, train_dice = train_epoch(
            model, train_loader, criterion, optimizer, scheduler, device, num_classes, scaler)
        logging.info(f"Epoch {current_epoch} - Train Loss: {train_loss:.4f}, Train mIoU: {train_miou:.4f}, "
                     f"Train Pixel Acc: {train_pixel_acc:.4f}, Train Dice: {train_dice:.4f}")

        val_loss, val_miou, val_pixel_acc, val_dice = validate_epoch(
            model, val_loader, criterion, device, num_classes)
        logging.info(f"Epoch {current_epoch} - Val Loss: {val_loss:.4f}, Val mIoU: {val_miou:.4f}, "
                     f"Val Pixel Acc: {val_pixel_acc:.4f}, Val Dice: {val_dice:.4f}")

        metrics = {
            'miou': val_miou,
            'pixel_acc': val_pixel_acc,
            'dice': val_dice
        }

        if val_miou > best_miou:
            best_miou = val_miou
            best_model_path = os.path.join(save_dir, f'best_model_epoch_{current_epoch}.pth')
            save_checkpoint(model, optimizer, current_epoch, metrics, best_model_path)
            logging.info(f"Epoch {current_epoch} - Best model saved with mIoU: {best_miou:.4f}")

        if current_epoch % 5 == 0:
            checkpoint_path = os.path.join(save_dir, f'checkpoint_epoch_{current_epoch}.pth')
            save_checkpoint(model, optimizer, current_epoch, metrics, checkpoint_path)
            logging.info(f"Epoch {current_epoch} - Checkpoint saved")

        current_lr = optimizer.param_groups[0]['lr']
        logging.info(f"Current learning rate: {current_lr:.6f}")

    logging.info(f"Training completed after {num_epochs} epochs.")
    return best_model_path

if __name__ == "__main__":
    setup_logger('training.log')

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logging.info(f"Using device: {device}")

    train_loader = EnhancedWildScenesDataset.get_data_loader('train', batch_size=8)
    val_loader = EnhancedWildScenesDataset.get_data_loader('valid', batch_size=8)

    # test_loader = EnhancedWildScenesDataset.get_data_loader('test', batch_size=8)

    num_classes = 18

    # 选择模型
    model = CustomDeepLabV3(num_classes=num_classes).to(device)

    # 选择损失函数
    # criterion = FocalLoss(alpha=1, gamma=2)
    criterion = CombinedLoss(weight_focal=1.0, weight_dice=0.5)

    # 选择优化器
    # optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=0.0001, nesterov=True)
    optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)

    num_epochs = 60
    steps_per_epoch = len(train_loader)
    scheduler = OneCycleLR(
        optimizer,
        max_lr=0.01,
        steps_per_epoch=steps_per_epoch,
        epochs=num_epochs,
        pct_start=0.3,
        anneal_strategy='cos',
        div_factor=25,
        final_div_factor=1000
    )

    save_dir = 'model_checkpoints'
    best_model_path = train(model, train_loader, val_loader, criterion, optimizer, scheduler,
                            num_epochs, device, save_dir, num_classes)

    logging.info("Training and prediction completed!")
# Out:
# 2024-07-15 03:23:44,834 - INFO - Using device: cuda
# 2024-07-15 03:23:45,891 - INFO - Epoch 1/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [03:18<00:00,  1.45s/it]
# 2024-07-15 03:27:04,110 - INFO - Epoch 1 - Train Loss: 0.8528, Train mIoU: 0.5948, Train Pixel Acc: 0.7644, Train Dice: 0.6334
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:52<00:00,  1.34s/it]
# 2024-07-15 03:27:56,492 - INFO - Epoch 1 - Val Loss: 0.8528, Val mIoU: 0.6205, Val Pixel Acc: 0.7122, Val Dice: 0.6636
# 2024-07-15 03:27:57,102 - INFO - Epoch 1 - Best model saved with mIoU: 0.6205
# 2024-07-15 03:27:57,103 - INFO - Current learning rate: 0.000473
# 2024-07-15 03:27:57,104 - INFO - Epoch 2/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:57<00:00,  1.30s/it]
# 2024-07-15 03:30:54,811 - INFO - Epoch 2 - Train Loss: 0.6277, Train mIoU: 0.6404, Train Pixel Acc: 0.8174, Train Dice: 0.6780
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:49<00:00,  1.27s/it]
# 2024-07-15 03:31:44,381 - INFO - Epoch 2 - Val Loss: 0.7763, Val mIoU: 0.6362, Val Pixel Acc: 0.7270, Val Dice: 0.6777
# 2024-07-15 03:31:44,987 - INFO - Epoch 2 - Best model saved with mIoU: 0.6362
# 2024-07-15 03:31:44,988 - INFO - Current learning rate: 0.000690
# 2024-07-15 03:31:44,988 - INFO - Epoch 3/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:22<00:00,  1.04s/it]
# 2024-07-15 03:34:07,805 - INFO - Epoch 3 - Train Loss: 0.6014, Train mIoU: 0.6418, Train Pixel Acc: 0.8272, Train Dice: 0.6810
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:36<00:00,  1.08it/s]
# 2024-07-15 03:34:43,926 - INFO - Epoch 3 - Val Loss: 0.8203, Val mIoU: 0.6181, Val Pixel Acc: 0.7093, Val Dice: 0.6620
# 2024-07-15 03:34:43,927 - INFO - Current learning rate: 0.001044
# 2024-07-15 03:34:43,927 - INFO - Epoch 4/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:04<00:00,  1.10it/s]
# 2024-07-15 03:36:48,591 - INFO - Epoch 4 - Train Loss: 0.5943, Train mIoU: 0.6451, Train Pixel Acc: 0.8252, Train Dice: 0.6884
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:35<00:00,  1.09it/s]
# 2024-07-15 03:37:24,307 - INFO - Epoch 4 - Val Loss: 0.8390, Val mIoU: 0.6142, Val Pixel Acc: 0.7108, Val Dice: 0.6563
# 2024-07-15 03:37:24,308 - INFO - Current learning rate: 0.001524
# 2024-07-15 03:37:24,309 - INFO - Epoch 5/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:06<00:00,  1.08it/s]
# 2024-07-15 03:39:30,833 - INFO - Epoch 5 - Train Loss: 0.5742, Train mIoU: 0.6319, Train Pixel Acc: 0.8109, Train Dice: 0.6749
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:54<00:00,  1.40s/it]
# 2024-07-15 03:40:25,608 - INFO - Epoch 5 - Val Loss: 0.8120, Val mIoU: 0.5895, Val Pixel Acc: 0.5893, Val Dice: 0.6333
# 2024-07-15 03:40:26,234 - INFO - Epoch 5 - Checkpoint saved
# 2024-07-15 03:40:26,235 - INFO - Current learning rate: 0.002116
# 2024-07-15 03:40:26,236 - INFO - Epoch 6/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:48<00:00,  1.23s/it]
# 2024-07-15 03:43:14,799 - INFO - Epoch 6 - Train Loss: 0.4919, Train mIoU: 0.6084, Train Pixel Acc: 0.7909, Train Dice: 0.6510
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:52<00:00,  1.36s/it]
# 2024-07-15 03:44:07,670 - INFO - Epoch 6 - Val Loss: 0.7401, Val mIoU: 0.6267, Val Pixel Acc: 0.7246, Val Dice: 0.6662
# 2024-07-15 03:44:07,671 - INFO - Current learning rate: 0.002802
# 2024-07-15 03:44:07,672 - INFO - Epoch 7/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [03:01<00:00,  1.33s/it]
# 2024-07-15 03:47:09,352 - INFO - Epoch 7 - Train Loss: 0.4656, Train mIoU: 0.6125, Train Pixel Acc: 0.8004, Train Dice: 0.6555
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:53<00:00,  1.38s/it]
# 2024-07-15 03:48:03,115 - INFO - Epoch 7 - Val Loss: 0.6204, Val mIoU: 0.6169, Val Pixel Acc: 0.7218, Val Dice: 0.6623
# 2024-07-15 03:48:03,115 - INFO - Current learning rate: 0.003561
# 2024-07-15 03:48:03,116 - INFO - Epoch 8/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [03:05<00:00,  1.36s/it]
# 2024-07-15 03:51:08,865 - INFO - Epoch 8 - Train Loss: 0.4541, Train mIoU: 0.6166, Train Pixel Acc: 0.8017, Train Dice: 0.6607
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:53<00:00,  1.37s/it]
# 2024-07-15 03:52:02,303 - INFO - Epoch 8 - Val Loss: 0.7747, Val mIoU: 0.6023, Val Pixel Acc: 0.5838, Val Dice: 0.6453
# 2024-07-15 03:52:02,304 - INFO - Current learning rate: 0.004369
# 2024-07-15 03:52:02,305 - INFO - Epoch 9/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [03:02<00:00,  1.33s/it]
# 2024-07-15 03:55:05,127 - INFO - Epoch 9 - Train Loss: 0.4327, Train mIoU: 0.6260, Train Pixel Acc: 0.8144, Train Dice: 0.6698
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:55<00:00,  1.42s/it]
# 2024-07-15 03:56:00,357 - INFO - Epoch 9 - Val Loss: 0.8070, Val mIoU: 0.5821, Val Pixel Acc: 0.6409, Val Dice: 0.6288
# 2024-07-15 03:56:00,357 - INFO - Current learning rate: 0.005203
# 2024-07-15 03:56:00,358 - INFO - Epoch 10/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:57<00:00,  1.29s/it]
# 2024-07-15 03:58:57,483 - INFO - Epoch 10 - Train Loss: 0.4212, Train mIoU: 0.6277, Train Pixel Acc: 0.8181, Train Dice: 0.6710
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:51<00:00,  1.32s/it]
# 2024-07-15 03:59:49,163 - INFO - Epoch 10 - Val Loss: 0.5955, Val mIoU: 0.5959, Val Pixel Acc: 0.7232, Val Dice: 0.6454
# 2024-07-15 03:59:49,760 - INFO - Epoch 10 - Checkpoint saved
# 2024-07-15 03:59:49,761 - INFO - Current learning rate: 0.006037
# 2024-07-15 03:59:49,762 - INFO - Epoch 11/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [03:09<00:00,  1.38s/it]
# 2024-07-15 04:02:59,021 - INFO - Epoch 11 - Train Loss: 0.4725, Train mIoU: 0.6229, Train Pixel Acc: 0.7904, Train Dice: 0.6645
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:53<00:00,  1.38s/it]
# 2024-07-15 04:03:52,746 - INFO - Epoch 11 - Val Loss: 0.6507, Val mIoU: 0.6217, Val Pixel Acc: 0.7266, Val Dice: 0.6610
# 2024-07-15 04:03:52,747 - INFO - Current learning rate: 0.006845
# 2024-07-15 04:03:52,748 - INFO - Epoch 12/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:56<00:00,  1.29s/it]
# 2024-07-15 04:06:48,895 - INFO - Epoch 12 - Train Loss: 0.4441, Train mIoU: 0.6314, Train Pixel Acc: 0.7999, Train Dice: 0.6717
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:54<00:00,  1.40s/it]
# 2024-07-15 04:07:43,446 - INFO - Epoch 12 - Val Loss: 0.6727, Val mIoU: 0.6285, Val Pixel Acc: 0.7285, Val Dice: 0.6674
# 2024-07-15 04:07:43,447 - INFO - Current learning rate: 0.007604
# 2024-07-15 04:07:43,448 - INFO - Epoch 13/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:58<00:00,  1.30s/it]
# 2024-07-15 04:10:41,697 - INFO - Epoch 13 - Train Loss: 0.4140, Train mIoU: 0.6433, Train Pixel Acc: 0.8138, Train Dice: 0.6849
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:52<00:00,  1.35s/it]
# 2024-07-15 04:11:34,478 - INFO - Epoch 13 - Val Loss: 0.6408, Val mIoU: 0.6029, Val Pixel Acc: 0.6910, Val Dice: 0.6510
# 2024-07-15 04:11:34,479 - INFO - Current learning rate: 0.008289
# 2024-07-15 04:11:34,480 - INFO - Epoch 14/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [03:02<00:00,  1.33s/it]
# 2024-07-15 04:14:36,687 - INFO - Epoch 14 - Train Loss: 0.4110, Train mIoU: 0.6420, Train Pixel Acc: 0.8147, Train Dice: 0.6859
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:54<00:00,  1.40s/it]
# 2024-07-15 04:15:31,270 - INFO - Epoch 14 - Val Loss: 0.7332, Val mIoU: 0.6126, Val Pixel Acc: 0.6429, Val Dice: 0.6572
# 2024-07-15 04:15:31,271 - INFO - Current learning rate: 0.008880
# 2024-07-15 04:15:31,272 - INFO - Epoch 15/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:57<00:00,  1.30s/it]
# 2024-07-15 04:18:28,749 - INFO - Epoch 15 - Train Loss: 0.4087, Train mIoU: 0.6386, Train Pixel Acc: 0.8160, Train Dice: 0.6821
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:53<00:00,  1.37s/it]
# 2024-07-15 04:19:22,018 - INFO - Epoch 15 - Val Loss: 0.5836, Val mIoU: 0.6408, Val Pixel Acc: 0.7553, Val Dice: 0.6845
# 2024-07-15 04:19:22,623 - INFO - Epoch 15 - Best model saved with mIoU: 0.6408
# 2024-07-15 04:19:23,352 - INFO - Epoch 15 - Checkpoint saved
# 2024-07-15 04:19:23,353 - INFO - Current learning rate: 0.009359
# 2024-07-15 04:19:23,353 - INFO - Epoch 16/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [03:03<00:00,  1.34s/it]
# 2024-07-15 04:22:26,785 - INFO - Epoch 16 - Train Loss: 0.3941, Train mIoU: 0.6483, Train Pixel Acc: 0.8178, Train Dice: 0.6923
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:53<00:00,  1.38s/it]
# 2024-07-15 04:23:20,766 - INFO - Epoch 16 - Val Loss: 0.6054, Val mIoU: 0.6416, Val Pixel Acc: 0.7100, Val Dice: 0.6886
# 2024-07-15 04:23:21,362 - INFO - Epoch 16 - Best model saved with mIoU: 0.6416
# 2024-07-15 04:23:21,363 - INFO - Current learning rate: 0.009712
# 2024-07-15 04:23:21,364 - INFO - Epoch 17/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [03:04<00:00,  1.34s/it]
# 2024-07-15 04:26:25,383 - INFO - Epoch 17 - Train Loss: 0.3819, Train mIoU: 0.6526, Train Pixel Acc: 0.8226, Train Dice: 0.6977
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:57<00:00,  1.46s/it]
# 2024-07-15 04:27:22,438 - INFO - Epoch 17 - Val Loss: 0.5715, Val mIoU: 0.6410, Val Pixel Acc: 0.7359, Val Dice: 0.6866
# 2024-07-15 04:27:22,439 - INFO - Current learning rate: 0.009928
# 2024-07-15 04:27:22,440 - INFO - Epoch 18/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [03:02<00:00,  1.33s/it]
# 2024-07-15 04:30:25,062 - INFO - Epoch 18 - Train Loss: 0.3768, Train mIoU: 0.6553, Train Pixel Acc: 0.8224, Train Dice: 0.6996
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:55<00:00,  1.41s/it]
# 2024-07-15 04:31:20,081 - INFO - Epoch 18 - Val Loss: 0.7643, Val mIoU: 0.6157, Val Pixel Acc: 0.5956, Val Dice: 0.6600
# 2024-07-15 04:31:20,081 - INFO - Current learning rate: 0.010000
# 2024-07-15 04:31:20,083 - INFO - Epoch 19/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [03:02<00:00,  1.33s/it]
# 2024-07-15 04:34:22,970 - INFO - Epoch 19 - Train Loss: 0.3646, Train mIoU: 0.6631, Train Pixel Acc: 0.8280, Train Dice: 0.7100
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:54<00:00,  1.40s/it]
# 2024-07-15 04:35:17,721 - INFO - Epoch 19 - Val Loss: 0.6240, Val mIoU: 0.6387, Val Pixel Acc: 0.7197, Val Dice: 0.6825
# 2024-07-15 04:35:17,723 - INFO - Current learning rate: 0.009986
# 2024-07-15 04:35:17,724 - INFO - Epoch 20/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [03:02<00:00,  1.34s/it]
# 2024-07-15 04:38:20,709 - INFO - Epoch 20 - Train Loss: 0.3676, Train mIoU: 0.6581, Train Pixel Acc: 0.8259, Train Dice: 0.7051
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:55<00:00,  1.43s/it]
# 2024-07-15 04:39:16,387 - INFO - Epoch 20 - Val Loss: 0.8887, Val mIoU: 0.6073, Val Pixel Acc: 0.6598, Val Dice: 0.6530
# 2024-07-15 04:39:16,993 - INFO - Epoch 20 - Checkpoint saved
# 2024-07-15 04:39:16,994 - INFO - Current learning rate: 0.009944
# 2024-07-15 04:39:16,994 - INFO - Epoch 21/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [03:02<00:00,  1.33s/it]
# 2024-07-15 04:42:19,114 - INFO - Epoch 21 - Train Loss: 0.3776, Train mIoU: 0.6569, Train Pixel Acc: 0.8194, Train Dice: 0.7035
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:55<00:00,  1.42s/it]
# 2024-07-15 04:43:14,579 - INFO - Epoch 21 - Val Loss: 0.6564, Val mIoU: 0.6214, Val Pixel Acc: 0.7304, Val Dice: 0.6633
# 2024-07-15 04:43:14,579 - INFO - Current learning rate: 0.009874
# 2024-07-15 04:43:14,580 - INFO - Epoch 22/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:56<00:00,  1.29s/it]
# 2024-07-15 04:46:10,767 - INFO - Epoch 22 - Train Loss: 0.4188, Train mIoU: 0.6447, Train Pixel Acc: 0.8020, Train Dice: 0.6898
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:35<00:00,  1.09it/s]
# 2024-07-15 04:46:46,496 - INFO - Epoch 22 - Val Loss: 0.6787, Val mIoU: 0.6054, Val Pixel Acc: 0.6924, Val Dice: 0.6514
# 2024-07-15 04:46:46,496 - INFO - Current learning rate: 0.009777
# 2024-07-15 04:46:46,497 - INFO - Epoch 23/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:48<00:00,  1.23s/it]
# 2024-07-15 04:49:35,054 - INFO - Epoch 23 - Train Loss: 0.3809, Train mIoU: 0.6597, Train Pixel Acc: 0.8184, Train Dice: 0.7047
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:50<00:00,  1.29s/it]
# 2024-07-15 04:50:25,204 - INFO - Epoch 23 - Val Loss: 0.5894, Val mIoU: 0.6391, Val Pixel Acc: 0.7230, Val Dice: 0.6852
# 2024-07-15 04:50:25,205 - INFO - Current learning rate: 0.009653
# 2024-07-15 04:50:25,207 - INFO - Epoch 24/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [03:00<00:00,  1.32s/it]
# 2024-07-15 04:53:25,418 - INFO - Epoch 24 - Train Loss: 0.3637, Train mIoU: 0.6635, Train Pixel Acc: 0.8239, Train Dice: 0.7107
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:53<00:00,  1.38s/it]
# 2024-07-15 04:54:19,139 - INFO - Epoch 24 - Val Loss: 0.6887, Val mIoU: 0.6349, Val Pixel Acc: 0.7243, Val Dice: 0.6784
# 2024-07-15 04:54:19,140 - INFO - Current learning rate: 0.009504
# 2024-07-15 04:54:19,140 - INFO - Epoch 25/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:28<00:00,  1.08s/it]
# 2024-07-15 04:56:47,528 - INFO - Epoch 25 - Train Loss: 0.3597, Train mIoU: 0.6637, Train Pixel Acc: 0.8270, Train Dice: 0.7119
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:33<00:00,  1.16it/s]
# 2024-07-15 04:57:21,127 - INFO - Epoch 25 - Val Loss: 0.6042, Val mIoU: 0.6315, Val Pixel Acc: 0.6842, Val Dice: 0.6804
# 2024-07-15 04:57:21,645 - INFO - Epoch 25 - Checkpoint saved
# 2024-07-15 04:57:21,646 - INFO - Current learning rate: 0.009329
# 2024-07-15 04:57:21,646 - INFO - Epoch 26/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:04<00:00,  1.10it/s]
# 2024-07-15 04:59:25,805 - INFO - Epoch 26 - Train Loss: 0.3584, Train mIoU: 0.6656, Train Pixel Acc: 0.8292, Train Dice: 0.7146
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:34<00:00,  1.13it/s]
# 2024-07-15 05:00:00,177 - INFO - Epoch 26 - Val Loss: 0.5810, Val mIoU: 0.6422, Val Pixel Acc: 0.7425, Val Dice: 0.6877
# 2024-07-15 05:00:00,692 - INFO - Epoch 26 - Best model saved with mIoU: 0.6422
# 2024-07-15 05:00:00,693 - INFO - Current learning rate: 0.009130
# 2024-07-15 05:00:00,694 - INFO - Epoch 27/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:54<00:00,  1.20it/s]
# 2024-07-15 05:01:55,159 - INFO - Epoch 27 - Train Loss: 0.3500, Train mIoU: 0.6690, Train Pixel Acc: 0.8319, Train Dice: 0.7185
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:33<00:00,  1.16it/s]
# 2024-07-15 05:02:28,655 - INFO - Epoch 27 - Val Loss: 0.5310, Val mIoU: 0.6519, Val Pixel Acc: 0.7518, Val Dice: 0.6977
# 2024-07-15 05:02:29,174 - INFO - Epoch 27 - Best model saved with mIoU: 0.6519
# 2024-07-15 05:02:29,175 - INFO - Current learning rate: 0.008907
# 2024-07-15 05:02:29,175 - INFO - Epoch 28/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:49<00:00,  1.25it/s]
# 2024-07-15 05:04:18,750 - INFO - Epoch 28 - Train Loss: 0.3396, Train mIoU: 0.6744, Train Pixel Acc: 0.8358, Train Dice: 0.7248
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:34<00:00,  1.13it/s]
# 2024-07-15 05:04:53,172 - INFO - Epoch 28 - Val Loss: 0.5689, Val mIoU: 0.6525, Val Pixel Acc: 0.7662, Val Dice: 0.6954
# 2024-07-15 05:04:53,686 - INFO - Epoch 28 - Best model saved with mIoU: 0.6525
# 2024-07-15 05:04:53,687 - INFO - Current learning rate: 0.008663
# 2024-07-15 05:04:53,688 - INFO - Epoch 29/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:56<00:00,  1.18it/s]
# 2024-07-15 05:06:49,799 - INFO - Epoch 29 - Train Loss: 0.3453, Train mIoU: 0.6705, Train Pixel Acc: 0.8322, Train Dice: 0.7207
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:36<00:00,  1.08it/s]
# 2024-07-15 05:07:25,957 - INFO - Epoch 29 - Val Loss: 0.5679, Val mIoU: 0.6609, Val Pixel Acc: 0.7745, Val Dice: 0.7022
# 2024-07-15 05:07:26,477 - INFO - Epoch 29 - Best model saved with mIoU: 0.6609
# 2024-07-15 05:07:26,478 - INFO - Current learning rate: 0.008399
# 2024-07-15 05:07:26,478 - INFO - Epoch 30/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:54<00:00,  1.19it/s]
# 2024-07-15 05:09:21,202 - INFO - Epoch 30 - Train Loss: 0.3345, Train mIoU: 0.6762, Train Pixel Acc: 0.8338, Train Dice: 0.7273
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:33<00:00,  1.15it/s]
# 2024-07-15 05:09:55,144 - INFO - Epoch 30 - Val Loss: 0.5805, Val mIoU: 0.6553, Val Pixel Acc: 0.7701, Val Dice: 0.6994
# 2024-07-15 05:09:55,665 - INFO - Epoch 30 - Checkpoint saved
# 2024-07-15 05:09:55,666 - INFO - Current learning rate: 0.008115
# 2024-07-15 05:09:55,666 - INFO - Epoch 31/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:58<00:00,  1.16it/s]
# 2024-07-15 05:11:54,129 - INFO - Epoch 31 - Train Loss: 0.3296, Train mIoU: 0.6783, Train Pixel Acc: 0.8381, Train Dice: 0.7301
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:35<00:00,  1.11it/s]
# 2024-07-15 05:12:29,246 - INFO - Epoch 31 - Val Loss: 0.7232, Val mIoU: 0.6331, Val Pixel Acc: 0.7082, Val Dice: 0.6794
# 2024-07-15 05:12:29,246 - INFO - Current learning rate: 0.007814
# 2024-07-15 05:12:29,247 - INFO - Epoch 32/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:52<00:00,  1.21it/s]
# 2024-07-15 05:14:22,065 - INFO - Epoch 32 - Train Loss: 0.3314, Train mIoU: 0.6801, Train Pixel Acc: 0.8376, Train Dice: 0.7323
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:36<00:00,  1.06it/s]
# 2024-07-15 05:14:58,771 - INFO - Epoch 32 - Val Loss: 0.7001, Val mIoU: 0.6245, Val Pixel Acc: 0.7232, Val Dice: 0.6755
# 2024-07-15 05:14:58,772 - INFO - Current learning rate: 0.007498
# 2024-07-15 05:14:58,772 - INFO - Epoch 33/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:58<00:00,  1.15it/s]
# 2024-07-15 05:16:57,770 - INFO - Epoch 33 - Train Loss: 0.3228, Train mIoU: 0.6902, Train Pixel Acc: 0.8402, Train Dice: 0.7423
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:33<00:00,  1.15it/s]
# 2024-07-15 05:17:31,671 - INFO - Epoch 33 - Val Loss: 0.5624, Val mIoU: 0.6464, Val Pixel Acc: 0.7657, Val Dice: 0.6925
# 2024-07-15 05:17:31,672 - INFO - Current learning rate: 0.007167
# 2024-07-15 05:17:31,672 - INFO - Epoch 34/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:57<00:00,  1.17it/s]
# 2024-07-15 05:19:29,113 - INFO - Epoch 34 - Train Loss: 0.3220, Train mIoU: 0.6839, Train Pixel Acc: 0.8380, Train Dice: 0.7368
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:35<00:00,  1.11it/s]
# 2024-07-15 05:20:04,156 - INFO - Epoch 34 - Val Loss: 0.5625, Val mIoU: 0.6537, Val Pixel Acc: 0.7469, Val Dice: 0.6997
# 2024-07-15 05:20:04,156 - INFO - Current learning rate: 0.006824
# 2024-07-15 05:20:04,156 - INFO - Epoch 35/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:02<00:00,  1.12it/s]
# 2024-07-15 05:22:06,224 - INFO - Epoch 35 - Train Loss: 0.3095, Train mIoU: 0.6920, Train Pixel Acc: 0.8430, Train Dice: 0.7467
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:34<00:00,  1.12it/s]
# 2024-07-15 05:22:40,931 - INFO - Epoch 35 - Val Loss: 0.5725, Val mIoU: 0.6537, Val Pixel Acc: 0.7557, Val Dice: 0.7024
# 2024-07-15 05:22:41,576 - INFO - Epoch 35 - Checkpoint saved
# 2024-07-15 05:22:41,577 - INFO - Current learning rate: 0.006471
# 2024-07-15 05:22:41,577 - INFO - Epoch 36/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:54<00:00,  1.20it/s]
# 2024-07-15 05:24:35,632 - INFO - Epoch 36 - Train Loss: 0.2978, Train mIoU: 0.7034, Train Pixel Acc: 0.8495, Train Dice: 0.7576
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:34<00:00,  1.14it/s]
# 2024-07-15 05:25:09,982 - INFO - Epoch 36 - Val Loss: 0.7591, Val mIoU: 0.6289, Val Pixel Acc: 0.6314, Val Dice: 0.6797
# 2024-07-15 05:25:09,983 - INFO - Current learning rate: 0.006110
# 2024-07-15 05:25:09,983 - INFO - Epoch 37/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:57<00:00,  1.17it/s]
# 2024-07-15 05:27:07,162 - INFO - Epoch 37 - Train Loss: 0.2989, Train mIoU: 0.7005, Train Pixel Acc: 0.8503, Train Dice: 0.7537
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:34<00:00,  1.14it/s]
# 2024-07-15 05:27:41,398 - INFO - Epoch 37 - Val Loss: 0.5694, Val mIoU: 0.6502, Val Pixel Acc: 0.7480, Val Dice: 0.6990
# 2024-07-15 05:27:41,398 - INFO - Current learning rate: 0.005743
# 2024-07-15 05:27:41,398 - INFO - Epoch 38/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:55<00:00,  1.19it/s]
# 2024-07-15 05:29:36,866 - INFO - Epoch 38 - Train Loss: 0.2901, Train mIoU: 0.7052, Train Pixel Acc: 0.8511, Train Dice: 0.7609
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:34<00:00,  1.12it/s]
# 2024-07-15 05:30:11,817 - INFO - Epoch 38 - Val Loss: 0.7041, Val mIoU: 0.6302, Val Pixel Acc: 0.7264, Val Dice: 0.6770
# 2024-07-15 05:30:11,818 - INFO - Current learning rate: 0.005371
# 2024-07-15 05:30:11,818 - INFO - Epoch 39/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:00<00:00,  1.14it/s]
# 2024-07-15 05:32:11,916 - INFO - Epoch 39 - Train Loss: 0.2994, Train mIoU: 0.7025, Train Pixel Acc: 0.8472, Train Dice: 0.7567
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:32<00:00,  1.20it/s]
# 2024-07-15 05:32:44,555 - INFO - Epoch 39 - Val Loss: 0.6669, Val mIoU: 0.6464, Val Pixel Acc: 0.7246, Val Dice: 0.6927
# 2024-07-15 05:32:44,556 - INFO - Current learning rate: 0.004997
# 2024-07-15 05:32:44,556 - INFO - Epoch 40/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:57<00:00,  1.17it/s]
# 2024-07-15 05:34:41,620 - INFO - Epoch 40 - Train Loss: 0.2819, Train mIoU: 0.7116, Train Pixel Acc: 0.8570, Train Dice: 0.7654
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:32<00:00,  1.20it/s]
# 2024-07-15 05:35:14,107 - INFO - Epoch 40 - Val Loss: 0.6387, Val mIoU: 0.6521, Val Pixel Acc: 0.7438, Val Dice: 0.6981
# 2024-07-15 05:35:14,705 - INFO - Epoch 40 - Checkpoint saved
# 2024-07-15 05:35:14,706 - INFO - Current learning rate: 0.004624
# 2024-07-15 05:35:14,706 - INFO - Epoch 41/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:54<00:00,  1.20it/s]
# 2024-07-15 05:37:09,247 - INFO - Epoch 41 - Train Loss: 0.2793, Train mIoU: 0.7154, Train Pixel Acc: 0.8548, Train Dice: 0.7712
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:35<00:00,  1.09it/s]
# 2024-07-15 05:37:45,102 - INFO - Epoch 41 - Val Loss: 0.6981, Val mIoU: 0.6441, Val Pixel Acc: 0.7044, Val Dice: 0.6920
# 2024-07-15 05:37:45,103 - INFO - Current learning rate: 0.004252
# 2024-07-15 05:37:45,103 - INFO - Epoch 42/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:51<00:00,  1.23it/s]
# 2024-07-15 05:39:36,725 - INFO - Epoch 42 - Train Loss: 0.2647, Train mIoU: 0.7265, Train Pixel Acc: 0.8596, Train Dice: 0.7826
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:33<00:00,  1.18it/s]
# 2024-07-15 05:40:09,860 - INFO - Epoch 42 - Val Loss: 0.6768, Val mIoU: 0.6504, Val Pixel Acc: 0.7285, Val Dice: 0.6985
# 2024-07-15 05:40:09,860 - INFO - Current learning rate: 0.003885
# 2024-07-15 05:40:09,861 - INFO - Epoch 43/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:57<00:00,  1.17it/s]
# 2024-07-15 05:42:06,945 - INFO - Epoch 43 - Train Loss: 0.2558, Train mIoU: 0.7341, Train Pixel Acc: 0.8635, Train Dice: 0.7906
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:35<00:00,  1.10it/s]
# 2024-07-15 05:42:42,251 - INFO - Epoch 43 - Val Loss: 0.7006, Val mIoU: 0.6518, Val Pixel Acc: 0.7493, Val Dice: 0.6994
# 2024-07-15 05:42:42,252 - INFO - Current learning rate: 0.003524
# 2024-07-15 05:42:42,253 - INFO - Epoch 44/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:50<00:00,  1.24it/s]
# 2024-07-15 05:44:32,612 - INFO - Epoch 44 - Train Loss: 0.2514, Train mIoU: 0.7354, Train Pixel Acc: 0.8656, Train Dice: 0.7921
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:32<00:00,  1.19it/s]
# 2024-07-15 05:45:05,449 - INFO - Epoch 44 - Val Loss: 0.6649, Val mIoU: 0.6504, Val Pixel Acc: 0.7232, Val Dice: 0.7011
# 2024-07-15 05:45:05,449 - INFO - Current learning rate: 0.003171
# 2024-07-15 05:45:05,450 - INFO - Epoch 45/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:06<00:00,  1.08it/s]
# 2024-07-15 05:47:12,098 - INFO - Epoch 45 - Train Loss: 0.2473, Train mIoU: 0.7399, Train Pixel Acc: 0.8660, Train Dice: 0.7968
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:45<00:00,  1.16s/it]
# 2024-07-15 05:47:57,158 - INFO - Epoch 45 - Val Loss: 0.6924, Val mIoU: 0.6605, Val Pixel Acc: 0.7533, Val Dice: 0.7117
# 2024-07-15 05:47:57,681 - INFO - Epoch 45 - Checkpoint saved
# 2024-07-15 05:47:57,682 - INFO - Current learning rate: 0.002828
# 2024-07-15 05:47:57,683 - INFO - Epoch 46/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:59<00:00,  1.14it/s]
# 2024-07-15 05:49:57,359 - INFO - Epoch 46 - Train Loss: 0.2416, Train mIoU: 0.7445, Train Pixel Acc: 0.8678, Train Dice: 0.8025
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:32<00:00,  1.19it/s]
# 2024-07-15 05:50:30,238 - INFO - Epoch 46 - Val Loss: 0.7333, Val mIoU: 0.6506, Val Pixel Acc: 0.7539, Val Dice: 0.6976
# 2024-07-15 05:50:30,238 - INFO - Current learning rate: 0.002498
# 2024-07-15 05:50:30,239 - INFO - Epoch 47/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:00<00:00,  1.14it/s]
# 2024-07-15 05:52:30,942 - INFO - Epoch 47 - Train Loss: 0.2371, Train mIoU: 0.7494, Train Pixel Acc: 0.8698, Train Dice: 0.8068
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:33<00:00,  1.15it/s]
# 2024-07-15 05:53:04,832 - INFO - Epoch 47 - Val Loss: 0.6906, Val mIoU: 0.6572, Val Pixel Acc: 0.7655, Val Dice: 0.7060
# 2024-07-15 05:53:04,832 - INFO - Current learning rate: 0.002181
# 2024-07-15 05:53:04,832 - INFO - Epoch 48/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:57<00:00,  1.17it/s]
# 2024-07-15 05:55:02,272 - INFO - Epoch 48 - Train Loss: 0.2266, Train mIoU: 0.7586, Train Pixel Acc: 0.8731, Train Dice: 0.8150
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:34<00:00,  1.11it/s]
# 2024-07-15 05:55:37,256 - INFO - Epoch 48 - Val Loss: 0.7166, Val mIoU: 0.6581, Val Pixel Acc: 0.7587, Val Dice: 0.7088
# 2024-07-15 05:55:37,256 - INFO - Current learning rate: 0.001881
# 2024-07-15 05:55:37,256 - INFO - Epoch 49/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:58<00:00,  1.15it/s]
# 2024-07-15 05:57:36,244 - INFO - Epoch 49 - Train Loss: 0.2204, Train mIoU: 0.7660, Train Pixel Acc: 0.8751, Train Dice: 0.8223
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:33<00:00,  1.16it/s]
# 2024-07-15 05:58:09,731 - INFO - Epoch 49 - Val Loss: 0.7065, Val mIoU: 0.6596, Val Pixel Acc: 0.7635, Val Dice: 0.7089
# 2024-07-15 05:58:09,731 - INFO - Current learning rate: 0.001597
# 2024-07-15 05:58:09,731 - INFO - Epoch 50/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:50<00:00,  1.24it/s]
# 2024-07-15 06:00:00,109 - INFO - Epoch 50 - Train Loss: 0.2121, Train mIoU: 0.7741, Train Pixel Acc: 0.8782, Train Dice: 0.8296
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:33<00:00,  1.15it/s]
# 2024-07-15 06:00:34,006 - INFO - Epoch 50 - Val Loss: 0.7215, Val mIoU: 0.6606, Val Pixel Acc: 0.7597, Val Dice: 0.7103
# 2024-07-15 06:00:34,540 - INFO - Epoch 50 - Checkpoint saved
# 2024-07-15 06:00:34,540 - INFO - Current learning rate: 0.001333
# 2024-07-15 06:00:34,540 - INFO - Epoch 51/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:00<00:00,  1.14it/s]
# 2024-07-15 06:02:34,954 - INFO - Epoch 51 - Train Loss: 0.2081, Train mIoU: 0.7754, Train Pixel Acc: 0.8802, Train Dice: 0.8309
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:35<00:00,  1.09it/s]
# 2024-07-15 06:03:10,582 - INFO - Epoch 51 - Val Loss: 0.8071, Val mIoU: 0.6530, Val Pixel Acc: 0.7417, Val Dice: 0.7017
# 2024-07-15 06:03:10,582 - INFO - Current learning rate: 0.001089
# 2024-07-15 06:03:10,582 - INFO - Epoch 52/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:56<00:00,  1.17it/s]
# 2024-07-15 06:05:07,451 - INFO - Epoch 52 - Train Loss: 0.2044, Train mIoU: 0.7783, Train Pixel Acc: 0.8816, Train Dice: 0.8338
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:35<00:00,  1.10it/s]
# 2024-07-15 06:05:42,780 - INFO - Epoch 52 - Val Loss: 0.7843, Val mIoU: 0.6550, Val Pixel Acc: 0.7533, Val Dice: 0.7043
# 2024-07-15 06:05:42,780 - INFO - Current learning rate: 0.000868
# 2024-07-15 06:05:42,780 - INFO - Epoch 53/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [02:06<00:00,  1.08it/s]
# 2024-07-15 06:07:49,647 - INFO - Epoch 53 - Train Loss: 0.2005, Train mIoU: 0.7815, Train Pixel Acc: 0.8829, Train Dice: 0.8369
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:36<00:00,  1.07it/s]
# 2024-07-15 06:08:26,024 - INFO - Epoch 53 - Val Loss: 0.7955, Val mIoU: 0.6549, Val Pixel Acc: 0.7430, Val Dice: 0.7047
# 2024-07-15 06:08:26,024 - INFO - Current learning rate: 0.000669
# 2024-07-15 06:08:26,024 - INFO - Epoch 54/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:50<00:00,  1.23it/s]
# 2024-07-15 06:10:16,978 - INFO - Epoch 54 - Train Loss: 0.1977, Train mIoU: 0.7875, Train Pixel Acc: 0.8845, Train Dice: 0.8418
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:34<00:00,  1.13it/s]
# 2024-07-15 06:10:51,435 - INFO - Epoch 54 - Val Loss: 0.7873, Val mIoU: 0.6545, Val Pixel Acc: 0.7549, Val Dice: 0.7044
# 2024-07-15 06:10:51,435 - INFO - Current learning rate: 0.000494
# 2024-07-15 06:10:51,436 - INFO - Epoch 55/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:58<00:00,  1.16it/s]
# 2024-07-15 06:12:49,442 - INFO - Epoch 55 - Train Loss: 0.1950, Train mIoU: 0.7870, Train Pixel Acc: 0.8851, Train Dice: 0.8420
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:34<00:00,  1.13it/s]
# 2024-07-15 06:13:23,961 - INFO - Epoch 55 - Val Loss: 0.8164, Val mIoU: 0.6554, Val Pixel Acc: 0.7520, Val Dice: 0.7053
# 2024-07-15 06:13:24,478 - INFO - Epoch 55 - Checkpoint saved
# 2024-07-15 06:13:24,478 - INFO - Current learning rate: 0.000345
# 2024-07-15 06:13:24,479 - INFO - Epoch 56/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:53<00:00,  1.20it/s]
# 2024-07-15 06:15:18,179 - INFO - Epoch 56 - Train Loss: 0.1905, Train mIoU: 0.7963, Train Pixel Acc: 0.8862, Train Dice: 0.8505
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:35<00:00,  1.11it/s]
# 2024-07-15 06:15:53,411 - INFO - Epoch 56 - Val Loss: 0.8394, Val mIoU: 0.6546, Val Pixel Acc: 0.7479, Val Dice: 0.7039
# 2024-07-15 06:15:53,412 - INFO - Current learning rate: 0.000222
# 2024-07-15 06:15:53,412 - INFO - Epoch 57/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:57<00:00,  1.16it/s]
# 2024-07-15 06:17:51,346 - INFO - Epoch 57 - Train Loss: 0.1893, Train mIoU: 0.7917, Train Pixel Acc: 0.8871, Train Dice: 0.8461
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:33<00:00,  1.16it/s]
# 2024-07-15 06:18:24,947 - INFO - Epoch 57 - Val Loss: 0.8353, Val mIoU: 0.6558, Val Pixel Acc: 0.7504, Val Dice: 0.7057
# 2024-07-15 06:18:24,948 - INFO - Current learning rate: 0.000125
# 2024-07-15 06:18:24,949 - INFO - Epoch 58/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:56<00:00,  1.17it/s]
# 2024-07-15 06:20:21,576 - INFO - Epoch 58 - Train Loss: 0.1899, Train mIoU: 0.7924, Train Pixel Acc: 0.8876, Train Dice: 0.8463
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:35<00:00,  1.11it/s]
# 2024-07-15 06:20:56,607 - INFO - Epoch 58 - Val Loss: 0.8217, Val mIoU: 0.6575, Val Pixel Acc: 0.7529, Val Dice: 0.7072
# 2024-07-15 06:20:56,608 - INFO - Current learning rate: 0.000056
# 2024-07-15 06:20:56,608 - INFO - Epoch 59/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:58<00:00,  1.15it/s]
# 2024-07-15 06:22:55,244 - INFO - Epoch 59 - Train Loss: 0.1891, Train mIoU: 0.7932, Train Pixel Acc: 0.8877, Train Dice: 0.8475
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:35<00:00,  1.11it/s]
# 2024-07-15 06:23:30,251 - INFO - Epoch 59 - Val Loss: 0.8304, Val mIoU: 0.6565, Val Pixel Acc: 0.7475, Val Dice: 0.7067
# 2024-07-15 06:23:30,251 - INFO - Current learning rate: 0.000014
# 2024-07-15 06:23:30,251 - INFO - Epoch 60/60
# Training: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 137/137 [01:58<00:00,  1.15it/s]
# 2024-07-15 06:25:29,152 - INFO - Epoch 60 - Train Loss: 0.1869, Train mIoU: 0.7967, Train Pixel Acc: 0.8879, Train Dice: 0.8503
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:35<00:00,  1.11it/s]
# 2024-07-15 06:26:04,205 - INFO - Epoch 60 - Val Loss: 0.8184, Val mIoU: 0.6570, Val Pixel Acc: 0.7526, Val Dice: 0.7073
# 2024-07-15 06:26:04,722 - INFO - Epoch 60 - Checkpoint saved
# 2024-07-15 06:26:04,722 - INFO - Current learning rate: 0.000000
# 2024-07-15 06:26:04,723 - INFO - Training completed after 60 epochs.
# 2024-07-15 06:26:04,724 - INFO - Training and prediction completed!
