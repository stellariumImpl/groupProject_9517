# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
from torch.cuda.amp import GradScaler, autocast
from data_load_for_mask2former import EnhancedWildScenesDataset
from tqdm import tqdm
import numpy as np
import os
import logging
from utils.metrics import calculate_miou_train, calculate_pixel_accuracy, calculate_dice_coefficient
from utils.losses import CombinedLoss
from utils.log import setup_logger, save_checkpoint
import torch.nn.functional as F
from torchvision import models
from torchvision.models.segmentation import FCN_ResNet50_Weights  # 确保正确导入

def train_epoch(model, dataloader, criterion, optimizer, device, num_classes, scaler, accumulation_steps=2):
    model.train()
    total_loss = 0
    total_miou = 0
    total_pixel_acc = 0
    total_dice = 0
    num_batches = 0
    optimizer.zero_grad()

    for i, (images, labels) in enumerate(tqdm(dataloader, desc="Training")):
        images, labels = images.to(device), labels.to(device)

        with torch.cuda.amp.autocast():
            outputs = model(images)['out']
            outputs = F.interpolate(outputs, size=labels.shape[-2:], mode='bilinear', align_corners=False)
            loss = criterion(outputs, labels)
            loss = loss / accumulation_steps

        scaler.scale(loss).backward()

        if (i + 1) % accumulation_steps == 0:
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        total_loss += loss.item() * accumulation_steps
        pred = torch.argmax(outputs, dim=1)
        miou = calculate_miou_train(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)
        pixel_acc = calculate_pixel_accuracy(pred.cpu().numpy(), labels.cpu().numpy())
        dice = calculate_dice_coefficient(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)

        if not np.isnan(miou):
            total_miou += miou
            total_pixel_acc += pixel_acc
            total_dice += dice
            num_batches += 1

    if (i + 1) % accumulation_steps != 0:
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        scaler.step(optimizer)
        scaler.update()
        optimizer.zero_grad()

    return (total_loss / len(dataloader),
            total_miou / num_batches if num_batches > 0 else 0.0,
            total_pixel_acc / num_batches if num_batches > 0 else 0.0,
            total_dice / num_batches if num_batches > 0 else 0.0)

def validate_epoch(model, dataloader, criterion, device, num_classes):
    model.eval()
    total_loss = 0
    total_miou = 0
    total_pixel_acc = 0
    total_dice = 0

    with torch.no_grad():
        for images, labels in tqdm(dataloader, desc="Validating"):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)['out']
            outputs = F.interpolate(outputs, size=labels.shape[-2:], mode='bilinear', align_corners=False)
            loss = criterion(outputs, labels)

            total_loss += loss.item()
            pred = torch.argmax(outputs, dim=1)
            miou = calculate_miou_train(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)
            pixel_acc = calculate_pixel_accuracy(pred.cpu().numpy(), labels.cpu().numpy())
            dice = calculate_dice_coefficient(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)

            total_miou += miou
            total_pixel_acc += pixel_acc
            total_dice += dice

    num_batches = len(dataloader)
    return (total_loss / num_batches,
            total_miou / num_batches,
            total_pixel_acc / num_batches,
            total_dice / num_batches)

def train(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device, save_dir, num_classes):
    best_miou = 0
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    scaler = GradScaler()

    for epoch in range(num_epochs):
        torch.cuda.empty_cache()
        current_epoch = epoch + 1
        logging.info(f"Epoch {current_epoch}/{num_epochs}")

        train_loss, train_miou, train_pixel_acc, train_dice = train_epoch(
            model, train_loader, criterion, optimizer, device, num_classes, scaler)
        logging.info(f"Epoch {current_epoch} - Train Loss: {train_loss:.4f}, Train mIoU: {train_miou:.4f}, "
                     f"Train Pixel Acc: {train_pixel_acc:.4f}, Train Dice: {train_dice:.4f}")

        val_loss, val_miou, val_pixel_acc, val_dice = validate_epoch(
            model, val_loader, criterion, device, num_classes)
        logging.info(f"Epoch {current_epoch} - Val Loss: {val_loss:.4f}, Val mIoU: {val_miou:.4f}, "
                     f"Val Pixel Acc: {val_pixel_acc:.4f}, Val Dice: {val_dice:.4f}")

        scheduler.step()

        metrics = {
            'miou': val_miou,
            'pixel_acc': val_pixel_acc,
            'dice': val_dice
        }

        if val_miou > best_miou:
            best_miou = val_miou
            best_model_path = os.path.join(save_dir, f'best_model_epoch_{current_epoch}.pth')
            save_checkpoint(model, optimizer, current_epoch, metrics, best_model_path)
            logging.info(f"Epoch {current_epoch} - Best model saved with mIoU: {best_miou:.4f}")

        # if current_epoch % 5 == 0:
        #     checkpoint_path = os.path.join(save_dir, f'checkpoint_epoch_{current_epoch}.pth')
        #     save_checkpoint(model, optimizer, current_epoch, metrics, checkpoint_path)
        #     logging.info(f"Epoch {current_epoch} - Checkpoint saved")

        current_lr = optimizer.param_groups[0]['lr']
        logging.info(f"Current learning rate: {current_lr:.6f}")

    logging.info(f"Training completed after {num_epochs} epochs.")
    return best_model_path

if __name__ == "__main__":
    save_dir = os.path.join('model_checkpoints', 'FCN')
    os.makedirs(save_dir, exist_ok=True)

    log_file = os.path.join(save_dir, 'training.log')
    setup_logger(log_file)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logging.info(f"Using device: {device}")

    # 修改数据加载器以使用新的增强
    train_loader = EnhancedWildScenesDataset.get_data_loader('train', batch_size=16)
    val_loader = EnhancedWildScenesDataset.get_data_loader('valid', batch_size=16)

    num_classes = 17

    # 加载预训练的FCN模型
    model = models.segmentation.fcn_resnet50(weights=FCN_ResNet50_Weights.COCO_WITH_VOC_LABELS_V1)
    model.classifier[4] = nn.Conv2d(512, num_classes, kernel_size=1)
    model = model.to(device)

    criterion = CombinedLoss(weight_focal=0.75, weight_dice=0.25)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
    num_epochs = 60
    scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2, eta_min=1e-6)

    best_model_path = train(model, train_loader, val_loader, criterion, optimizer, scheduler,
                            num_epochs, device, save_dir, num_classes)

    logging.info("Training and prediction completed!")
# Out:
# Using device: cuda
# Epoch 1/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:45<00:00,  3.40s/it]
# Epoch 1 - Train Loss: 0.5894, Train mIoU: 0.5989, Train Pixel Acc: 0.7359, Train Dice: 0.6352
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:22<00:00,  3.65s/it]
# Epoch 1 - Val Loss: 0.3868, Val mIoU: 0.6352, Val Pixel Acc: 0.8047, Val Dice: 0.6721
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_1.pth
# Epoch 1 - Best model saved with mIoU: 0.6352
# Current learning rate: 0.000976
# Epoch 2/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:38<00:00,  3.34s/it]
# Epoch 2 - Train Loss: 0.3922, Train mIoU: 0.6334, Train Pixel Acc: 0.8001, Train Dice: 0.6703
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:05<00:00,  3.23s/it]
# Epoch 2 - Val Loss: 0.3554, Val mIoU: 0.6495, Val Pixel Acc: 0.8234, Val Dice: 0.6849
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_2.pth
# Epoch 2 - Best model saved with mIoU: 0.6495
# Current learning rate: 0.000905
# Epoch 3/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:35<00:00,  3.33s/it]
# Epoch 3 - Train Loss: 0.3704, Train mIoU: 0.6459, Train Pixel Acc: 0.8135, Train Dice: 0.6821
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:04<00:00,  3.20s/it]
# Epoch 3 - Val Loss: 0.3712, Val mIoU: 0.6390, Val Pixel Acc: 0.8095, Val Dice: 0.6751
# Current learning rate: 0.000794
# Epoch 4/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:33<00:00,  3.31s/it]
# Epoch 4 - Train Loss: 0.3622, Train mIoU: 0.6389, Train Pixel Acc: 0.8132, Train Dice: 0.6764
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:06<00:00,  3.23s/it]
# Epoch 4 - Val Loss: 0.3333, Val mIoU: 0.6506, Val Pixel Acc: 0.8272, Val Dice: 0.6873
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_4.pth
# Epoch 4 - Best model saved with mIoU: 0.6506
# Current learning rate: 0.000655
# Epoch 5/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:36<00:00,  3.33s/it]
# Epoch 5 - Train Loss: 0.2975, Train mIoU: 0.6459, Train Pixel Acc: 0.8245, Train Dice: 0.6850
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:05<00:00,  3.21s/it]
# Epoch 5 - Val Loss: 0.2703, Val mIoU: 0.6497, Val Pixel Acc: 0.8263, Val Dice: 0.6915
# Checkpoint saved: model_checkpoints\FCN\checkpoint_epoch_5.pth
# Epoch 5 - Checkpoint saved
# Current learning rate: 0.000501
# Epoch 6/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:31<00:00,  3.30s/it]
# Epoch 6 - Train Loss: 0.2647, Train mIoU: 0.6555, Train Pixel Acc: 0.8280, Train Dice: 0.6988
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:04<00:00,  3.20s/it]
# Epoch 6 - Val Loss: 0.2466, Val mIoU: 0.6604, Val Pixel Acc: 0.8366, Val Dice: 0.7014
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_6.pth
# Epoch 6 - Best model saved with mIoU: 0.6604
# Current learning rate: 0.000346
# Epoch 7/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:32<00:00,  3.30s/it]
# Epoch 7 - Train Loss: 0.2511, Train mIoU: 0.6551, Train Pixel Acc: 0.8339, Train Dice: 0.6995
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:05<00:00,  3.21s/it]
# Epoch 7 - Val Loss: 0.2414, Val mIoU: 0.6587, Val Pixel Acc: 0.8395, Val Dice: 0.7017
# Current learning rate: 0.000207
# Epoch 8/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:33<00:00,  3.31s/it]
# Epoch 8 - Train Loss: 0.2428, Train mIoU: 0.6598, Train Pixel Acc: 0.8383, Train Dice: 0.7059
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:05<00:00,  3.21s/it]
# Epoch 8 - Val Loss: 0.2365, Val mIoU: 0.6592, Val Pixel Acc: 0.8406, Val Dice: 0.7056
# Current learning rate: 0.000096
# Epoch 9/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:30<00:00,  3.29s/it]
# Epoch 9 - Train Loss: 0.2365, Train mIoU: 0.6620, Train Pixel Acc: 0.8424, Train Dice: 0.7080
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:04<00:00,  3.20s/it]
# Epoch 9 - Val Loss: 0.2344, Val mIoU: 0.6535, Val Pixel Acc: 0.8437, Val Dice: 0.6994
# Current learning rate: 0.000025
# Epoch 10/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:30<00:00,  3.29s/it]
# Epoch 10 - Train Loss: 0.2331, Train mIoU: 0.6637, Train Pixel Acc: 0.8440, Train Dice: 0.7111
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:05<00:00,  3.23s/it]
# Epoch 10 - Val Loss: 0.2330, Val mIoU: 0.6607, Val Pixel Acc: 0.8448, Val Dice: 0.7061
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_10.pth
# Epoch 10 - Best model saved with mIoU: 0.6607
# Checkpoint saved: model_checkpoints\FCN\checkpoint_epoch_10.pth
# Epoch 10 - Checkpoint saved
# Current learning rate: 0.001000
# Epoch 11/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:32<00:00,  3.30s/it]
# Epoch 11 - Train Loss: 0.2660, Train mIoU: 0.6391, Train Pixel Acc: 0.8227, Train Dice: 0.6832
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:05<00:00,  3.21s/it]
# Epoch 11 - Val Loss: 0.2601, Val mIoU: 0.6531, Val Pixel Acc: 0.8271, Val Dice: 0.6937
# Current learning rate: 0.000994
# Epoch 12/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:34<00:00,  3.32s/it]
# Epoch 12 - Train Loss: 0.2638, Train mIoU: 0.6373, Train Pixel Acc: 0.8228, Train Dice: 0.6832
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:05<00:00,  3.21s/it]
# Epoch 12 - Val Loss: 0.2634, Val mIoU: 0.6240, Val Pixel Acc: 0.8270, Val Dice: 0.6684
# Current learning rate: 0.000976
# Epoch 13/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:31<00:00,  3.29s/it]
# Epoch 13 - Train Loss: 0.2793, Train mIoU: 0.6346, Train Pixel Acc: 0.8147, Train Dice: 0.6793
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:05<00:00,  3.22s/it]
# Epoch 13 - Val Loss: 0.2534, Val mIoU: 0.6482, Val Pixel Acc: 0.8299, Val Dice: 0.6914
# Current learning rate: 0.000946
# Epoch 14/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:36<00:00,  3.33s/it]
# Epoch 14 - Train Loss: 0.2485, Train mIoU: 0.6506, Train Pixel Acc: 0.8286, Train Dice: 0.6968
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:05<00:00,  3.22s/it]
# Epoch 14 - Val Loss: 0.2411, Val mIoU: 0.6458, Val Pixel Acc: 0.8244, Val Dice: 0.6928
# Current learning rate: 0.000905
# Epoch 15/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:30<00:00,  3.29s/it]
# Epoch 15 - Train Loss: 0.2347, Train mIoU: 0.6604, Train Pixel Acc: 0.8309, Train Dice: 0.7058
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:06<00:00,  3.24s/it]
# Epoch 15 - Val Loss: 0.2368, Val mIoU: 0.6604, Val Pixel Acc: 0.8274, Val Dice: 0.7026
# Checkpoint saved: model_checkpoints\FCN\checkpoint_epoch_15.pth
# Epoch 15 - Checkpoint saved
# Current learning rate: 0.000854
# Epoch 16/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:29<00:00,  3.28s/it]
# Epoch 16 - Train Loss: 0.2285, Train mIoU: 0.6612, Train Pixel Acc: 0.8317, Train Dice: 0.7081
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:04<00:00,  3.20s/it]
# Epoch 16 - Val Loss: 0.2335, Val mIoU: 0.6624, Val Pixel Acc: 0.8287, Val Dice: 0.7073
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_16.pth
# Epoch 16 - Best model saved with mIoU: 0.6624
# Current learning rate: 0.000794
# Epoch 17/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:33<00:00,  3.31s/it]
# Epoch 17 - Train Loss: 0.2246, Train mIoU: 0.6604, Train Pixel Acc: 0.8349, Train Dice: 0.7083
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:05<00:00,  3.21s/it]
# Epoch 17 - Val Loss: 0.2240, Val mIoU: 0.6714, Val Pixel Acc: 0.8301, Val Dice: 0.7220
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_17.pth
# Epoch 17 - Best model saved with mIoU: 0.6714
# Current learning rate: 0.000727
# Epoch 18/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:32<00:00,  3.31s/it]
# Epoch 18 - Train Loss: 0.2197, Train mIoU: 0.6707, Train Pixel Acc: 0.8358, Train Dice: 0.7198
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:09<00:00,  3.32s/it]
# Epoch 18 - Val Loss: 0.2224, Val mIoU: 0.6692, Val Pixel Acc: 0.8272, Val Dice: 0.7181
# Current learning rate: 0.000655
# Epoch 19/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:31<00:00,  3.29s/it]
# Epoch 19 - Train Loss: 0.2166, Train mIoU: 0.6723, Train Pixel Acc: 0.8354, Train Dice: 0.7205
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:05<00:00,  3.21s/it]
# Epoch 19 - Val Loss: 0.2165, Val mIoU: 0.6732, Val Pixel Acc: 0.8361, Val Dice: 0.7212
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_19.pth
# Epoch 19 - Best model saved with mIoU: 0.6732
# Current learning rate: 0.000579
# Epoch 20/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:39<00:00,  3.36s/it]
# Epoch 20 - Train Loss: 0.2078, Train mIoU: 0.6802, Train Pixel Acc: 0.8401, Train Dice: 0.7297
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:06<00:00,  3.23s/it]
# Epoch 20 - Val Loss: 0.2103, Val mIoU: 0.6811, Val Pixel Acc: 0.8427, Val Dice: 0.7301
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_20.pth
# Epoch 20 - Best model saved with mIoU: 0.6811
# Checkpoint saved: model_checkpoints\FCN\checkpoint_epoch_20.pth
# Epoch 20 - Checkpoint saved
# Current learning rate: 0.000501
# Epoch 21/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:42<00:00,  3.38s/it]
# Epoch 21 - Train Loss: 0.2012, Train mIoU: 0.6874, Train Pixel Acc: 0.8431, Train Dice: 0.7385
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:10<00:00,  3.36s/it]
# Epoch 21 - Val Loss: 0.2065, Val mIoU: 0.6827, Val Pixel Acc: 0.8392, Val Dice: 0.7312
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_21.pth
# Epoch 21 - Best model saved with mIoU: 0.6827
# Current learning rate: 0.000422
# Epoch 22/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:47<00:00,  3.42s/it]
# Epoch 22 - Train Loss: 0.1945, Train mIoU: 0.6960, Train Pixel Acc: 0.8467, Train Dice: 0.7477
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:06<00:00,  3.25s/it]
# Epoch 22 - Val Loss: 0.2047, Val mIoU: 0.6847, Val Pixel Acc: 0.8406, Val Dice: 0.7354
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_22.pth
# Epoch 22 - Best model saved with mIoU: 0.6847
# Current learning rate: 0.000346
# Epoch 23/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:34<00:00,  3.32s/it]
# Epoch 23 - Train Loss: 0.1901, Train mIoU: 0.6976, Train Pixel Acc: 0.8485, Train Dice: 0.7497
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:07<00:00,  3.26s/it]
# Epoch 23 - Val Loss: 0.2059, Val mIoU: 0.6789, Val Pixel Acc: 0.8395, Val Dice: 0.7293
# Current learning rate: 0.000274
# Epoch 24/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:37<00:00,  3.34s/it]
# Epoch 24 - Train Loss: 0.1866, Train mIoU: 0.7019, Train Pixel Acc: 0.8506, Train Dice: 0.7549
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:06<00:00,  3.25s/it]
# Epoch 24 - Val Loss: 0.2017, Val mIoU: 0.6879, Val Pixel Acc: 0.8422, Val Dice: 0.7373
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_24.pth
# Epoch 24 - Best model saved with mIoU: 0.6879
# Current learning rate: 0.000207
# Epoch 25/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:37<00:00,  3.34s/it]
# Epoch 25 - Train Loss: 0.1816, Train mIoU: 0.7061, Train Pixel Acc: 0.8532, Train Dice: 0.7593
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:08<00:00,  3.28s/it]
# Epoch 25 - Val Loss: 0.2011, Val mIoU: 0.6873, Val Pixel Acc: 0.8452, Val Dice: 0.7374
# Checkpoint saved: model_checkpoints\FCN\checkpoint_epoch_25.pth
# Epoch 25 - Checkpoint saved
# Current learning rate: 0.000147
# Epoch 26/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:39<00:00,  3.36s/it]
# Epoch 26 - Train Loss: 0.1796, Train mIoU: 0.7074, Train Pixel Acc: 0.8546, Train Dice: 0.7617
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:07<00:00,  3.27s/it]
# Epoch 26 - Val Loss: 0.2069, Val mIoU: 0.6872, Val Pixel Acc: 0.8451, Val Dice: 0.7368
# Current learning rate: 0.000096
# Epoch 27/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:40<00:00,  3.36s/it]
# Epoch 27 - Train Loss: 0.1766, Train mIoU: 0.7099, Train Pixel Acc: 0.8551, Train Dice: 0.7632
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:05<00:00,  3.21s/it]
# Epoch 27 - Val Loss: 0.2028, Val mIoU: 0.6883, Val Pixel Acc: 0.8452, Val Dice: 0.7384
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_27.pth
# Epoch 27 - Best model saved with mIoU: 0.6883
# Current learning rate: 0.000055
# Epoch 28/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:35<00:00,  3.32s/it]
# Epoch 28 - Train Loss: 0.1723, Train mIoU: 0.7144, Train Pixel Acc: 0.8576, Train Dice: 0.7686
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:06<00:00,  3.25s/it]
# Epoch 28 - Val Loss: 0.2018, Val mIoU: 0.6912, Val Pixel Acc: 0.8455, Val Dice: 0.7421
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_28.pth
# Epoch 28 - Best model saved with mIoU: 0.6912
# Current learning rate: 0.000025
# Epoch 29/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:38<00:00,  3.35s/it]
# Epoch 29 - Train Loss: 0.1712, Train mIoU: 0.7191, Train Pixel Acc: 0.8575, Train Dice: 0.7727
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:09<00:00,  3.31s/it]
# Epoch 29 - Val Loss: 0.2011, Val mIoU: 0.6940, Val Pixel Acc: 0.8457, Val Dice: 0.7462
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_29.pth
# Epoch 29 - Best model saved with mIoU: 0.6940
# Current learning rate: 0.000007
# Epoch 30/30
# Training: 100%|██████████████████████████████████████████████████████████████████████| 137/137 [07:43<00:00,  3.38s/it]
# Epoch 30 - Train Loss: 0.1707, Train mIoU: 0.7163, Train Pixel Acc: 0.8581, Train Dice: 0.7707
# Validating: 100%|██████████████████████████████████████████████████████████████████████| 39/39 [02:12<00:00,  3.40s/it]
# Epoch 30 - Val Loss: 0.2005, Val mIoU: 0.6942, Val Pixel Acc: 0.8452, Val Dice: 0.7462
# Checkpoint saved: model_checkpoints\FCN\best_model_epoch_30.pth
# Epoch 30 - Best model saved with mIoU: 0.6942
# Checkpoint saved: model_checkpoints\FCN\checkpoint_epoch_30.pth
# Epoch 30 - Checkpoint saved
# Current learning rate: 0.001000
# Training completed after 30 epochs.
# Training and prediction completed!

# %%
import torch
import torch.nn.functional as F
from tqdm import tqdm
import numpy as np
import os
import logging
from data_load_for_mask2former import EnhancedWildScenesDataset
from torchvision import models
from torchvision.models.segmentation import FCN_ResNet50_Weights
from utils.metrics import calculate_miou, calculate_pixel_accuracy, calculate_dice_coefficient
import matplotlib.pyplot as plt

def setup_logger(log_file):
    os.makedirs(os.path.dirname(log_file), exist_ok=True)
    logging.basicConfig(level=logging.INFO,
                        format='%(asctime)s - %(levelname)s - %(message)s',
                        handlers=[
                            logging.FileHandler(log_file),
                            logging.StreamHandler()
                        ])

def test(model, dataloader, device, num_classes, save_dir):
    model.eval()
    total_miou = 0
    total_pixel_acc = 0
    total_dice = 0
    num_batches = 0
    class_iou = np.zeros(num_classes)

    with torch.no_grad():
        for i, (images, labels) in enumerate(tqdm(dataloader, desc="Testing")):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)['out']  # FCN返回字典，我们需要'out'键的值

            if len(labels.shape) == 4 and labels.shape[1] > 1:
                labels = torch.argmax(labels, dim=1)

            if outputs.shape[2:] != labels.shape[1:]:
                outputs = F.interpolate(outputs, size=labels.shape[1:], mode='bilinear', align_corners=False)

            pred = torch.argmax(outputs, dim=1)

            miou, class_iou_batch = calculate_miou(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)
            pixel_acc = calculate_pixel_accuracy(pred.cpu().numpy(), labels.cpu().numpy())
            dice = calculate_dice_coefficient(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)

            total_miou += miou
            total_pixel_acc += pixel_acc
            total_dice += dice
            class_iou += class_iou_batch

            if i % 10 == 0:  # Save every 10th image
                save_comparison(images[0], labels[0], pred[0], i, save_dir)

    num_batches = len(dataloader)
    avg_miou = total_miou / num_batches
    avg_pixel_acc = total_pixel_acc / num_batches
    avg_dice = total_dice / num_batches
    avg_class_iou = class_iou / num_batches

    return avg_miou, avg_pixel_acc, avg_dice, avg_class_iou

def normalize_image(image):
    """Normalize image tensor to [0, 1] range."""
    image = image.cpu().numpy()
    image = (image - image.min()) / (image.max() - image.min())
    return np.clip(image, 0, 1)

def save_comparison(image, ground_truth, prediction, index, save_dir):
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
    
    # Normalize and convert image to correct format
    image_np = normalize_image(image)
    image_np = np.transpose(image_np, (1, 2, 0))  # Change from (C, H, W) to (H, W, C)
    
    # Original image
    ax1.imshow(image_np)
    ax1.set_title("Original Image")
    ax1.axis('off')
    
    # Ground truth
    ax2.imshow(ground_truth.cpu().numpy(), cmap='viridis')
    ax2.set_title("Ground Truth")
    ax2.axis('off')
    
    # Prediction
    ax3.imshow(prediction.cpu().numpy(), cmap='viridis')
    ax3.set_title("Prediction")
    ax3.axis('off')
    
    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, f'comparison_{index}.png'))
    plt.close()

if __name__ == "__main__":
    save_dir = 'prediction/FCN'
    log_file = os.path.join(save_dir, 'testing.log')
    
    os.makedirs(save_dir, exist_ok=True)
    
    setup_logger(log_file)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logging.info(f"Using device: {device}")

    test_loader = EnhancedWildScenesDataset.get_data_loader('test', batch_size=8)

    num_classes = 17

    # 加载预训练的FCN模型
    model = models.segmentation.fcn_resnet50(weights=FCN_ResNet50_Weights.COCO_WITH_VOC_LABELS_V1)
    model.classifier[4] = torch.nn.Conv2d(512, num_classes, kernel_size=1)
    model = model.to(device)
    
    # 使用相对路径加载最佳模型
    best_model_path = os.path.join('model_checkpoints', 'FCN', 'best_model_epoch_28.pth')
    
    if os.path.exists(best_model_path):
        checkpoint = torch.load(best_model_path, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        logging.info(f"Loaded model from {best_model_path}")
    else:
        logging.error(f"Model file not found at {best_model_path}")
        exit(1)

    miou, pixel_acc, dice, class_iou = test(model, test_loader, device, num_classes, save_dir)
    
    logging.info(f"Test Results:")
    logging.info(f"Mean IoU: {miou:.4f}")
    logging.info(f"Pixel Accuracy: {pixel_acc:.4f}")
    logging.info(f"Dice Coefficient: {dice:.4f}")
    
    # 打印每个类别的IoU
    for i, iou in enumerate(class_iou):
        logging.info(f"Class {i} IoU: {iou:.4f}")

    # 可视化每个类别的IoU
    plt.figure(figsize=(12, 6))
    plt.bar(range(num_classes), class_iou)
    plt.title('Per-class IoU')
    plt.xlabel('Class')
    plt.ylabel('IoU')
    plt.savefig(os.path.join(save_dir, 'per_class_iou.png'))
    plt.close()
# Out:
# 2024-07-22 03:49:23,643 - INFO - Using device: cuda
# 2024-07-22 03:49:24,696 - INFO - Loaded model from model_checkpoints/FCN/best_model_epoch_28.pth
# Testing: 100%|██████████| 35/35 [03:15<00:00,  5.59s/it]
# 2024-07-22 03:52:40,484 - INFO - Test Results:
# 2024-07-22 03:52:40,485 - INFO - Mean IoU: 0.4576
# 2024-07-22 03:52:40,486 - INFO - Pixel Accuracy: 0.8313
# 2024-07-22 03:52:40,487 - INFO - Dice Coefficient: 0.7418
# 2024-07-22 03:52:40,488 - INFO - Class 0 IoU: 0.8254
# 2024-07-22 03:52:40,489 - INFO - Class 1 IoU: nan
# 2024-07-22 03:52:40,490 - INFO - Class 2 IoU: nan
# 2024-07-22 03:52:40,490 - INFO - Class 3 IoU: nan
# 2024-07-22 03:52:40,491 - INFO - Class 4 IoU: nan
# 2024-07-22 03:52:40,492 - INFO - Class 5 IoU: 0.4160
# 2024-07-22 03:52:40,495 - INFO - Class 6 IoU: 0.8085
# 2024-07-22 03:52:40,496 - INFO - Class 7 IoU: 0.1717
# 2024-07-22 03:52:40,497 - INFO - Class 8 IoU: nan
# 2024-07-22 03:52:40,498 - INFO - Class 9 IoU: nan
# 2024-07-22 03:52:40,498 - INFO - Class 10 IoU: nan
# 2024-07-22 03:52:40,499 - INFO - Class 11 IoU: nan
# 2024-07-22 03:52:40,500 - INFO - Class 12 IoU: 0.2532
# 2024-07-22 03:52:40,501 - INFO - Class 13 IoU: 0.1301
# 2024-07-22 03:52:40,502 - INFO - Class 14 IoU: 0.6461
# 2024-07-22 03:52:40,502 - INFO - Class 15 IoU: nan
# 2024-07-22 03:52:40,503 - INFO - Class 16 IoU: 0.6696

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
from tqdm import tqdm
import seaborn as sns
from data_load_for_mask2former import EnhancedWildScenesDataset
from torchvision import models
from torchvision.models.segmentation import FCN_ResNet50_Weights
from sklearn.metrics import confusion_matrix
import csv
import pandas as pd

# 定义颜色映射
color_map = {
    1: [224, 31, 77],  # Bush
    0: [64, 180, 78],  # Dirt
    2: [26, 127, 127],  # Fence
    14: [127, 127, 127],  # Grass
    3: [145, 24, 178],  # Gravel
    13: [125, 128, 16],  # Log
    12: [251, 225, 48],  # Mud
    7: [248, 190, 190],  # Other-object
    8: [89, 239, 239],  # Other-terrain
    9: [173, 255, 196],  # Rock
    16: [19, 0, 126],  # Sky
    11: [167, 110, 44],  # Structure
    6: [208, 245, 71],  # Tree-foliage
    5: [238, 47, 227],  # Tree-trunk
    4: [40, 127, 198],  # Water
    15: [0, 0, 0],  # 背景类（黑色）
    10: [128, 128, 128],  # 忽略类（灰色）
}

class_names = ['Dirt', 'Bush', 'Fence', 'Gravel', 'Water', 'Tree-trunk', 'Tree-Foliage', 'Other-object',
               'Other-terrain', 'Rock', 'Ignore', 'Structure', 'Mud', 'Log', 'Grass', 'Background', 'Sky']


def apply_color_map(segmentation):
    color_segmentation = np.zeros((*segmentation.shape, 3), dtype=np.uint8)
    for class_idx, color in color_map.items():
        color_segmentation[segmentation == class_idx] = color
    return color_segmentation


def overlay_segmentation(image, segmentation, alpha=0.5):
    colored_seg = apply_color_map(segmentation)
    return (image * (1 - alpha) + colored_seg * alpha).astype(np.uint8)


def save_comparison(image, ground_truth, prediction, index, save_dir):
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

    ax1.imshow(image.permute(1, 2, 0).cpu().numpy())
    ax1.set_title('Original Image')
    ax1.axis('off')

    ax2.imshow(apply_color_map(ground_truth.cpu().numpy()))
    ax2.set_title('Ground Truth')
    ax2.axis('off')

    ax3.imshow(apply_color_map(prediction.cpu().numpy()))
    ax3.set_title('Prediction')
    ax3.axis('off')

    ax4.imshow(overlay_segmentation(image.permute(1, 2, 0).cpu().numpy(), prediction.cpu().numpy()))
    ax4.set_title('Overlay')
    ax4.axis('off')

    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, f'comparison_{index}.png'))
    plt.close()


def plot_confusion_matrix(y_true, y_pred, save_path):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.savefig(save_path)
    plt.close()


def plot_per_class_iou(class_iou, save_path):
    plt.figure(figsize=(12, 6))
    valid_iou = [iou for iou in class_iou if not np.isnan(iou)]
    plt.bar(range(len(valid_iou)), valid_iou)
    plt.title('Per-class IoU')
    plt.xlabel('Class')
    plt.ylabel('IoU')
    valid_class_names = [name for i, name in enumerate(class_names) if i < len(valid_iou)]
    plt.xticks(range(len(valid_iou)), valid_class_names, rotation=90)
    plt.tight_layout()
    plt.savefig(save_path)
    plt.close()


def calculate_miou(pred, target, num_classes):
    ious = []
    pred = pred.ravel()
    target = target.ravel()
    for cls in range(num_classes):
        pred_inds = pred == cls
        target_inds = target == cls
        intersection = np.logical_and(pred_inds, target_inds).sum()
        union = np.logical_or(pred_inds, target_inds).sum()
        if union == 0:
            ious.append(float('nan'))  # 如果该类别不存在，则IoU为NaN
        else:
            ious.append(intersection / union)
    miou = np.nanmean(ious)  # 忽略NaN值计算平均IoU
    return miou, np.array(ious)


def visualize_results(model, dataloader, device, num_classes, save_dir):
    model.eval()
    all_class_ious = np.zeros(num_classes)
    class_counts = np.zeros(num_classes)
    image_ious = []

    with torch.no_grad():
        for i, (images, labels) in enumerate(tqdm(dataloader, desc="Visualizing")):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            outputs = outputs['out'] if isinstance(outputs, dict) else outputs

            if len(labels.shape) == 4 and labels.shape[1] > 1:
                labels = torch.argmax(labels, dim=1)

            if outputs.shape[2:] != labels.shape[1:]:
                outputs = F.interpolate(outputs, size=labels.shape[1:], mode='bilinear', align_corners=True)

            pred = torch.argmax(outputs, dim=1)

            # 计算每张图片的IoU
            for j in range(images.shape[0]):
                image_index = i * dataloader.batch_size + j
                _, class_ious = calculate_miou(pred[j].cpu().numpy(), labels[j].cpu().numpy(), num_classes)
                all_class_ious += np.nan_to_num(class_ious)  # 将NaN转换为0
                class_counts += ~np.isnan(class_ious)  # 统计非NaN值的数量
                image_ious.append(class_ious)

                # 保存每张图片的可视化结果
                save_comparison(images[j], labels[j], pred[j], image_index, save_dir)

    # 计算平均IoU
    average_ious = np.where(class_counts > 0, all_class_ious / class_counts, 0)

    print("Class IoUs:")
    for cls, iou in enumerate(average_ious):
        print(f"Class {cls} ({class_names[cls]}): {iou:.4f}")

    # 绘制每类IoU图
    plot_per_class_iou(average_ious, os.path.join(save_dir, 'per_class_iou.png'))

    # 计算mIoU
    miou = np.mean(average_ious)
    print(f"Mean IoU: {miou:.4f}")

    # 创建并保存CSV文件
    csv_file = os.path.join(save_dir, 'image_class_ious.csv')
    df = pd.DataFrame(image_ious, columns=[f"{cls}_{name}" for cls, name in enumerate(class_names)])
    df.index.name = 'Image_Number'
    df.to_csv(csv_file)
    print(f"Image-wise class IoUs saved to {csv_file}")

    return average_ious, miou


if __name__ == "__main__":
    save_dir = 'visualization_results/FCN_ResNet50'
    os.makedirs(save_dir, exist_ok=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    num_classes = 17

    # 创建FCN-ResNet50模型实例
    model = models.segmentation.fcn_resnet50(weights=FCN_ResNet50_Weights.DEFAULT)
    model.classifier[4] = torch.nn.Conv2d(512, num_classes, kernel_size=(1, 1), stride=(1, 1))
    model = model.to(device)

    # 加载模型权重
    model_path = os.path.join('model_checkpoints', 'FCN', 'best_model_epoch_28.pth')
    checkpoint = torch.load(model_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])

    model.eval()

    test_loader = EnhancedWildScenesDataset.get_data_loader('test', batch_size=8)

    # 运行可视化并获取结果
    class_ious, miou = visualize_results(model, test_loader, device, num_classes, save_dir)

    # 保存结果到文件
    results_file = os.path.join(save_dir, 'iou_results.txt')
    with open(results_file, 'w') as f:
        f.write(f"Mean IoU: {miou:.4f}\n\n")
        f.write("Class IoUs:\n")
        for cls, iou in enumerate(class_ious):
            f.write(f"Class {cls} ({class_names[cls]}): {iou:.4f}\n")

    print(f"Visualization results and IoU statistics saved in {save_dir}")
# Out:
# Visualizing:   0%|          | 0/35 [00:00<?, ?it/s]2024-07-22 04:22:22,287 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:22,713 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:23,102 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:23,501 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:23,939 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:24,381 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:24,799 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:25,224 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:   3%|▎         | 1/35 [00:10<06:13, 10.98s/it]2024-07-22 04:22:31,175 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:31,711 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:32,100 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:32,540 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:32,925 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:33,354 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:33,760 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:34,191 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:   6%|▌         | 2/35 [00:19<05:23,  9.81s/it]2024-07-22 04:22:40,182 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:40,808 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:41,499 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:42,073 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:42,498 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:42,903 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:43,325 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:43,893 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:   9%|▊         | 3/35 [00:29<05:12,  9.76s/it]2024-07-22 04:22:49,951 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:50,373 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:50,796 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:51,201 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:51,616 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:52,050 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:52,479 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:52,913 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  11%|█▏        | 4/35 [00:38<04:53,  9.47s/it]2024-07-22 04:22:59,005 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:59,431 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:22:59,858 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:00,278 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:00,715 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:01,151 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:01,553 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:01,973 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  14%|█▍        | 5/35 [00:47<04:39,  9.32s/it]2024-07-22 04:23:08,131 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:08,553 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:08,947 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:09,350 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:09,768 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:10,190 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:10,601 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:10,995 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  17%|█▋        | 6/35 [00:56<04:27,  9.22s/it]2024-07-22 04:23:16,990 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:17,388 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:17,817 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:18,200 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:18,605 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:19,021 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:19,415 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:19,823 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  20%|██        | 7/35 [01:05<04:14,  9.10s/it]2024-07-22 04:23:25,798 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:26,218 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:26,609 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:27,020 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:27,440 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:28,101 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:28,501 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:28,913 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  23%|██▎       | 8/35 [01:14<04:05,  9.09s/it]2024-07-22 04:23:34,864 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:35,282 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:35,688 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:36,122 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:36,548 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:36,965 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:37,386 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:37,789 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  26%|██▌       | 9/35 [01:23<03:54,  9.02s/it]2024-07-22 04:23:43,829 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:44,246 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:44,655 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:45,086 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:45,524 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:45,922 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:46,350 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:46,777 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  29%|██▊       | 10/35 [01:32<03:45,  9.01s/it]2024-07-22 04:23:52,761 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:53,173 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:53,567 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:53,966 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:54,358 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:54,757 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:55,186 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:23:55,951 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  31%|███▏      | 11/35 [01:41<03:37,  9.06s/it]2024-07-22 04:24:01,988 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:02,394 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:02,803 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:03,229 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:03,637 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:04,040 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:04,470 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:04,873 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  34%|███▍      | 12/35 [01:50<03:27,  9.02s/it]2024-07-22 04:24:10,853 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:11,279 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:11,683 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:12,069 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:12,472 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:12,885 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:13,316 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:13,711 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  37%|███▋      | 13/35 [01:59<03:17,  8.97s/it]2024-07-22 04:24:19,689 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:20,105 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:20,512 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:20,903 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:21,296 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:21,717 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:22,105 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:22,500 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  40%|████      | 14/35 [02:08<03:07,  8.91s/it]2024-07-22 04:24:28,472 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:28,884 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:29,264 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:29,684 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:30,126 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:30,543 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:30,960 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:31,384 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  43%|████▎     | 15/35 [02:17<02:58,  8.91s/it]2024-07-22 04:24:37,846 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:38,262 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:38,663 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:39,066 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:39,460 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:39,875 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:40,311 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:40,715 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  46%|████▌     | 16/35 [02:26<02:51,  9.03s/it]2024-07-22 04:24:46,659 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:47,028 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:47,464 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:47,873 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:48,283 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:48,710 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:49,115 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:49,518 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  49%|████▊     | 17/35 [02:35<02:41,  8.95s/it]2024-07-22 04:24:55,390 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:55,796 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:56,184 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:56,571 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:56,980 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:57,371 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:57,768 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:24:58,189 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  51%|█████▏    | 18/35 [02:43<02:31,  8.88s/it]2024-07-22 04:25:04,256 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:04,665 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:05,094 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:05,490 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:05,896 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:06,317 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:06,748 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:07,179 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  54%|█████▍    | 19/35 [02:52<02:22,  8.91s/it]2024-07-22 04:25:13,127 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:13,537 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:13,946 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:14,366 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:14,782 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:15,196 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:15,607 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:15,993 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  57%|█████▋    | 20/35 [03:01<02:13,  8.89s/it]2024-07-22 04:25:21,919 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:22,993 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:23,413 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:23,829 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:24,234 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:24,671 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:25,066 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:25,493 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  60%|██████    | 21/35 [03:11<02:06,  9.07s/it]2024-07-22 04:25:31,482 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:31,894 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:32,317 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:32,718 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:33,112 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:33,517 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:33,923 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:34,319 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  63%|██████▎   | 22/35 [03:20<01:56,  8.99s/it]2024-07-22 04:25:40,262 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:40,677 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:41,072 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:41,501 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:41,917 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:42,298 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:42,733 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:43,156 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  66%|██████▌   | 23/35 [03:28<01:47,  8.95s/it]2024-07-22 04:25:49,183 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:49,596 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:50,019 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:50,448 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:50,885 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:51,304 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:51,745 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:52,139 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  69%|██████▊   | 24/35 [03:37<01:38,  8.95s/it]2024-07-22 04:25:58,107 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:58,501 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:58,910 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:59,330 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:25:59,726 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:00,134 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:00,571 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:00,971 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  71%|███████▏  | 25/35 [03:46<01:29,  8.92s/it]2024-07-22 04:26:06,985 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:07,398 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:07,804 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:08,216 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:08,632 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:09,063 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:09,486 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:09,902 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  74%|███████▍  | 26/35 [03:55<01:20,  8.93s/it]2024-07-22 04:26:15,900 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:16,319 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:16,757 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:17,176 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:18,470 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:18,874 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:19,295 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:19,724 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  77%|███████▋  | 27/35 [04:05<01:13,  9.19s/it]2024-07-22 04:26:25,714 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:26,143 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:26,572 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:26,956 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:27,367 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:27,783 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:28,209 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:28,636 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  80%|████████  | 28/35 [04:14<01:03,  9.11s/it]2024-07-22 04:26:34,633 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:35,033 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:35,449 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:35,859 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:36,287 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:36,701 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:37,109 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:37,544 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  83%|████████▎ | 29/35 [04:23<00:54,  9.04s/it]2024-07-22 04:26:43,616 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:44,055 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:44,478 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:44,906 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:45,326 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:45,755 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:46,186 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:46,614 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  86%|████████▌ | 30/35 [04:32<00:45,  9.07s/it]2024-07-22 04:26:52,628 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:53,035 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:53,443 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:53,853 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:54,248 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:54,655 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:55,062 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:26:55,470 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  89%|████████▊ | 31/35 [04:41<00:35,  8.99s/it]2024-07-22 04:27:01,443 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:01,839 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:02,238 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:02,633 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:03,041 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:03,473 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:03,906 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:04,369 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  91%|█████████▏| 32/35 [04:50<00:26,  8.97s/it]2024-07-22 04:27:10,433 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:10,844 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:11,259 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:11,644 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:12,069 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:12,476 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:12,858 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:13,272 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  94%|█████████▍| 33/35 [04:59<00:17,  8.94s/it]2024-07-22 04:27:19,201 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:19,610 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:20,045 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:20,443 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:20,854 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:21,242 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:21,651 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:22,089 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing:  97%|█████████▋| 34/35 [05:07<00:08,  8.90s/it]2024-07-22 04:27:27,982 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:28,365 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:28,773 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:30,367 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:30,761 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:31,182 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:31,567 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2024-07-22 04:27:31,968 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualizing: 100%|██████████| 35/35 [05:17<00:00,  9.08s/it]
# Class IoUs:
# Class 0 (Dirt): 0.7390
# Class 1 (Bush): 0.0000
# Class 2 (Fence): 0.5259
# Class 3 (Gravel): 0.2651
# Class 4 (Water): 0.0000
# Class 5 (Tree-trunk): 0.3596
# Class 6 (Tree-Foliage): 0.8072
# Class 7 (Other-object): 0.1130
# Class 8 (Other-terrain): 0.0827
# Class 9 (Rock): 0.1731
# Class 10 (Ignore): 0.0000
# Class 11 (Structure): 0.3499
# Class 12 (Mud): 0.1418
# Class 13 (Log): 0.1121
# Class 14 (Grass): 0.5970
# Class 15 (Background): 0.0000
# Class 16 (Sky): 0.4721
# Mean IoU: 0.2787
# Image-wise class IoUs saved to visualization_results/FCN_ResNet50/image_class_ious.csv
# Visualization results and IoU statistics saved in visualization_results/FCN_ResNet50
# /tmp/ipykernel_35723/3699646465.py:150: RuntimeWarning: invalid value encountered in true_divide
#   average_ious = np.where(class_counts > 0, all_class_ious / class_counts, 0)
