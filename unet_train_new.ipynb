# %%
import pandas as pd
import os
import sklearn
from PIL import Image
import numpy as np
import logging


class WildScenesDataset:
    root_dirs = [
        os.path.join('..',  'WildScenes2d', 'V-01'),
        os.path.join('..',  'WildScenes2d', 'V-02'),
        os.path.join('..',  'WildScenes2d', 'V-03')
    ]
    _data_list_dir = os.path.join('datasets', 'data_list')
    _csv_files = {
        'train': os.path.join(_data_list_dir, 'train.csv'),
        'valid': os.path.join(_data_list_dir, 'valid.csv'),
        'test': os.path.join(_data_list_dir, 'test.csv'),
    }
    csv = _csv_files
    _label_to_trainid = {
        0: 15,  # 背景类
        1: 16,  # 忽略类
        2: 0,  # Bush
        3: 1,  # Dirt
        4: 2,  # Fence
        5: 3,  # Grass
        6: 4,  # Gravel
        7: 5,  # Log
        8: 6,  # Mud
        9: 7,  # Other-Object
        10: 8,  # Other-terrain
        11: 16,  # 忽略类
        12: 9,  # Rock
        13: 10,  # Sky
        14: 11,  # Structure
        15: 12,  # Tree-foliage
        16: 13,  # Tree-trunk
        17: 16,  # 忽略类
        18: 14,  # Water
    }
    def __init__(self, dataset_type, transform=None):
        assert dataset_type in ('train', 'valid', 'test')
        self._dataset_type = dataset_type
        self._data_frame = pd.read_csv(WildScenesDataset._csv_files[self._dataset_type])
        self._transform = transform

    def __len__(self):
        return len(self._data_frame)

    def __getitem__(self, index):
        if index >= len(self):
            raise IndexError(f"Index {index} out of bounds for dataset of size {len(self)}")
        try:
            image_path = self._data_frame['image'].iloc[index]
            label_path = self._data_frame['label'].iloc[index]

            image = Image.open(image_path).convert('RGB')
            label = Image.open(label_path).convert('L')
            # 将灰度图转换为Numpy数组
            label_np = np.array(label)

            # 将标签索引映射到训练标识（trainId）值
            label_trainId = np.vectorize(lambda x: self._label_to_trainid.get(x, 255))(label_np)

            if self._transform is not None:
                for t in self._transform:
                    image, label_trainId = t(image, label_trainId)

            return image, label_trainId
        except Exception as e:
            logging.error(f"Error loading item at index {index}: {str(e)}")

    @staticmethod
    def _get_image_label_dir():
        """
        Traverse server image and label directories and yield image and label paths.
        :return: Generator yielding (image path, label path)
        """
        data_err = 'data error. check!'
        image_base = WildScenesDataset.image_file_base
        label_base = WildScenesDataset.label_file_base

        for image in os.listdir(image_base):
            image_origin = os.path.join(image_base, image)
            image_label = os.path.join(label_base, image)

            if not (os.path.isfile(image_label) and
                    os.path.exists(image_label) and
                    os.path.isfile(image_label)):
                print(image_origin, image_label, data_err)  # Print error message and skip if paths are invalid
                continue

            yield image_origin, image_label

    @staticmethod
    def make_data_list(train_rate=0.7, valid_rate=0.2, shuffle=True):
        """
        Shuffle and generate data_list CSV files with image and label paths sorted by filename.
        :param train_rate: Training set ratio, default 0.7
        :param valid_rate: Validation set ratio, default 0.2
        :param shuffle: Whether to shuffle the dataset, default True
        :return: None
        """
        # Ensure the directory exists
        data_list_dir = WildScenesDataset._data_list_dir
        if not os.path.exists(data_list_dir):
            os.makedirs(data_list_dir)
            print(f"Created directory: {data_list_dir}")

        all_image_paths = []
        all_label_paths = []

        # Traverse all root directories to collect image and label paths
        for root_dir in WildScenesDataset.root_dirs:
            image_base = os.path.join(root_dir, 'image')
            label_base = os.path.join(root_dir, 'indexLabel')

            if not os.path.exists(image_base) or not os.path.exists(label_base):
                print(f"Error: Image or label directory does not exist in {root_dir}")
                continue

            for image in os.listdir(image_base):
                image_origin = os.path.join(image_base, image)
                image_label = os.path.join(label_base, image)

                if not (os.path.isfile(image_label) and os.path.exists(image_label)):
                    print(f"Warning: Skipping invalid file pair {image_origin}, {image_label}")
                    continue

                all_image_paths.append(image_origin)
                all_label_paths.append(image_label)

        # Create DataFrame with image and label paths
        df = pd.DataFrame(
            data={'image': all_image_paths, 'label': all_label_paths}
        )

        # Sort DataFrame by filename (assumed to be timestamp in a sortable format)
        df['timestamp'] = df['image'].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('-')[0]))
        df = df.sort_values(by='timestamp').reset_index(drop=True)

        if shuffle:
            df = sklearn.utils.shuffle(df)  # Shuffle dataframe if specified

        # Calculate sizes for train, valid, and test sets
        train_size = int(df.shape[0] * train_rate)
        valid_size = int(df.shape[0] * valid_rate)

        print('total: {:d} | train: {:d} | val: {:d} | test: {:d}'.format(
            df.shape[0], train_size, valid_size,
            df.shape[0] - train_size - valid_size))

        # Split dataframe into train, valid, and test sets
        df_train = df[0: train_size]
        df_valid = df[train_size: train_size + valid_size]
        df_test = df[train_size + valid_size:]

        # Save train, valid, and test sets to CSV files
        df_train[['image', 'label']].to_csv(os.path.join(WildScenesDataset.csv['train']), index=False)
        df_valid[['image', 'label']].to_csv(os.path.join(WildScenesDataset.csv['valid']), index=False)
        df_test[['image', 'label']].to_csv(os.path.join(WildScenesDataset.csv['test']), index=False)

    # 测试語義分割時用
    @staticmethod
    def test_label_mapping(label_path):
        """
        Test the label mapping for a single label image.

        :param label_path: Path to the label image
        :return: Tuple of original label numpy array and mapped trainId numpy array
        """
        # Open the label image and convert to numpy array
        label = Image.open(label_path).convert('L')
        label_np = np.array(label, dtype=np.uint8)

        # Map label indices to trainId values
        label_trainId = np.vectorize(lambda x: WildScenesDataset._label_to_trainid.get(x, 255))(label_np)

        return label_np, label_trainId

if __name__=='__main__':
    # Example usage
    root_dirs = [
        os.path.join('..',  'WildScenes2d', 'V-01'),
        os.path.join('..',  'WildScenes2d', 'V-02'),
        os.path.join('..',  'WildScenes2d', 'V-03')
    ]

    for root_dir in root_dirs:
        WildScenesDataset.image_file_base = os.path.join(root_dir, 'image')
        WildScenesDataset.label_file_base = os.path.join(root_dir, 'indexLabel')
        WildScenesDataset.make_data_list()
# Out:
# Created directory: datasets/data_list
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377950-815682737.png, ../WildScenes2d/V-01/indexLabel/1623377950-815682737.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378431-680051558.png, ../WildScenes2d/V-01/indexLabel/1623378431-680051558.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377963-278224325.png, ../WildScenes2d/V-01/indexLabel/1623377963-278224325.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378448-361270243.png, ../WildScenes2d/V-01/indexLabel/1623378448-361270243.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378457-343599344.png, ../WildScenes2d/V-01/indexLabel/1623378457-343599344.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377944-584645794.png, ../WildScenes2d/V-01/indexLabel/1623377944-584645794.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377918-856426136.png, ../WildScenes2d/V-01/indexLabel/1623377918-856426136.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378442-867568574.png, ../WildScenes2d/V-01/indexLabel/1623378442-867568574.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378475-161419462.png, ../WildScenes2d/V-01/indexLabel/1623378475-161419462.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377925-159527445.png, ../WildScenes2d/V-01/indexLabel/1623377925-159527445.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377967-230808446.png, ../WildScenes2d/V-01/indexLabel/1623377967-230808446.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377975-271355579.png, ../WildScenes2d/V-01/indexLabel/1623377975-271355579.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378472-548403715.png, ../WildScenes2d/V-01/indexLabel/1623378472-548403715.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377959-258456400.png, ../WildScenes2d/V-01/indexLabel/1623377959-258456400.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377914-976167099.png, ../WildScenes2d/V-01/indexLabel/1623377914-976167099.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378432-817128886.png, ../WildScenes2d/V-01/indexLabel/1623378432-817128886.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377921-000895815.png, ../WildScenes2d/V-01/indexLabel/1623377921-000895815.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623379147-649014941.png, ../WildScenes2d/V-01/indexLabel/1623379147-649014941.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378461-560428029.png, ../WildScenes2d/V-01/indexLabel/1623378461-560428029.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377932-457500069.png, ../WildScenes2d/V-01/indexLabel/1623377932-457500069.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378434-425091598.png, ../WildScenes2d/V-01/indexLabel/1623378434-425091598.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378471-949163819.png, ../WildScenes2d/V-01/indexLabel/1623378471-949163819.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378471-141438534.png, ../WildScenes2d/V-01/indexLabel/1623378471-141438534.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378456-535278349.png, ../WildScenes2d/V-01/indexLabel/1623378456-535278349.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377938-487636925.png, ../WildScenes2d/V-01/indexLabel/1623377938-487636925.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377928-906440235.png, ../WildScenes2d/V-01/indexLabel/1623377928-906440235.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378452-381188960.png, ../WildScenes2d/V-01/indexLabel/1623378452-381188960.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377971-116875354.png, ../WildScenes2d/V-01/indexLabel/1623377971-116875354.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378475-767872451.png, ../WildScenes2d/V-01/indexLabel/1623378475-767872451.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378466-250282109.png, ../WildScenes2d/V-01/indexLabel/1623378466-250282109.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378438-177133282.png, ../WildScenes2d/V-01/indexLabel/1623378438-177133282.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378440-857208892.png, ../WildScenes2d/V-01/indexLabel/1623378440-857208892.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378474-223396720.png, ../WildScenes2d/V-01/indexLabel/1623378474-223396720.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378474-631572153.png, ../WildScenes2d/V-01/indexLabel/1623378474-631572153.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377955-572774704.png, ../WildScenes2d/V-01/indexLabel/1623377955-572774704.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377949-478073244.png, ../WildScenes2d/V-01/indexLabel/1623377949-478073244.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377940-631594323.png, ../WildScenes2d/V-01/indexLabel/1623377940-631594323.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377979-089901258.png, ../WildScenes2d/V-01/indexLabel/1623377979-089901258.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377971-453577297.png, ../WildScenes2d/V-01/indexLabel/1623377971-453577297.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377937-885263562.png, ../WildScenes2d/V-01/indexLabel/1623377937-885263562.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377947-945370865.png, ../WildScenes2d/V-01/indexLabel/1623377947-945370865.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378472-887193153.png, ../WildScenes2d/V-01/indexLabel/1623378472-887193153.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378427-390332417.png, ../WildScenes2d/V-01/indexLabel/1623378427-390332417.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378422-633340839.png, ../WildScenes2d/V-01/indexLabel/1623378422-633340839.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378445-011197380.png, ../WildScenes2d/V-01/indexLabel/1623378445-011197380.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377936-611540335.png, ../WildScenes2d/V-01/indexLabel/1623377936-611540335.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377953-562703868.png, ../WildScenes2d/V-01/indexLabel/1623377953-562703868.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377933-730497020.png, ../WildScenes2d/V-01/indexLabel/1623377933-730497020.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378472-213350846.png, ../WildScenes2d/V-01/indexLabel/1623378472-213350846.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378124-414282018.png, ../WildScenes2d/V-01/indexLabel/1623378124-414282018.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371525-861256636.png, ../WildScenes2d/V-02/indexLabel/1623371525-861256636.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372454-157797550.png, ../WildScenes2d/V-02/indexLabel/1623372454-157797550.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372230-772307848.png, ../WildScenes2d/V-02/indexLabel/1623372230-772307848.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372521-420180813.png, ../WildScenes2d/V-02/indexLabel/1623372521-420180813.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372434-253787405.png, ../WildScenes2d/V-02/indexLabel/1623372434-253787405.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372402-027531639.png, ../WildScenes2d/V-02/indexLabel/1623372402-027531639.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372144-879597762.png, ../WildScenes2d/V-02/indexLabel/1623372144-879597762.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372154-324823083.png, ../WildScenes2d/V-02/indexLabel/1623372154-324823083.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372504-737095955.png, ../WildScenes2d/V-02/indexLabel/1623372504-737095955.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371553-399663830.png, ../WildScenes2d/V-02/indexLabel/1623371553-399663830.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372212-749178273.png, ../WildScenes2d/V-02/indexLabel/1623372212-749178273.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372412-348545805.png, ../WildScenes2d/V-02/indexLabel/1623372412-348545805.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372485-642087126.png, ../WildScenes2d/V-02/indexLabel/1623372485-642087126.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372224-943283537.png, ../WildScenes2d/V-02/indexLabel/1623372224-943283537.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372147-294848874.png, ../WildScenes2d/V-02/indexLabel/1623372147-294848874.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372439-411618052.png, ../WildScenes2d/V-02/indexLabel/1623372439-411618052.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371746-560163622.png, ../WildScenes2d/V-02/indexLabel/1623371746-560163622.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372237-405520214.png, ../WildScenes2d/V-02/indexLabel/1623372237-405520214.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372223-335281335.png, ../WildScenes2d/V-02/indexLabel/1623372223-335281335.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372158-614123707.png, ../WildScenes2d/V-02/indexLabel/1623372158-614123707.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371694-165746654.png, ../WildScenes2d/V-02/indexLabel/1623371694-165746654.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371749-575212865.png, ../WildScenes2d/V-02/indexLabel/1623371749-575212865.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371520-232709990.png, ../WildScenes2d/V-02/indexLabel/1623371520-232709990.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372413-549474998.png, ../WildScenes2d/V-02/indexLabel/1623372413-549474998.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372455-223763072.png, ../WildScenes2d/V-02/indexLabel/1623372455-223763072.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371556-479737924.png, ../WildScenes2d/V-02/indexLabel/1623371556-479737924.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372514-854162748.png, ../WildScenes2d/V-02/indexLabel/1623372514-854162748.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371705-491733083.png, ../WildScenes2d/V-02/indexLabel/1623371705-491733083.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372213-955337677.png, ../WildScenes2d/V-02/indexLabel/1623372213-955337677.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372166-522957250.png, ../WildScenes2d/V-02/indexLabel/1623372166-522957250.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372152-448974761.png, ../WildScenes2d/V-02/indexLabel/1623372152-448974761.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371719-559023496.png, ../WildScenes2d/V-02/indexLabel/1623371719-559023496.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371559-360771446.png, ../WildScenes2d/V-02/indexLabel/1623371559-360771446.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372249-133346946.png, ../WildScenes2d/V-02/indexLabel/1623372249-133346946.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372139-719708357.png, ../WildScenes2d/V-02/indexLabel/1623372139-719708357.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371724-449906692.png, ../WildScenes2d/V-02/indexLabel/1623371724-449906692.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372386-615881991.png, ../WildScenes2d/V-02/indexLabel/1623372386-615881991.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372222-129254738.png, ../WildScenes2d/V-02/indexLabel/1623372222-129254738.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372409-395710009.png, ../WildScenes2d/V-02/indexLabel/1623372409-395710009.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372419-379133964.png, ../WildScenes2d/V-02/indexLabel/1623372419-379133964.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372150-371797468.png, ../WildScenes2d/V-02/indexLabel/1623372150-371797468.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372455-827141732.png, ../WildScenes2d/V-02/indexLabel/1623372455-827141732.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372421-924687173.png, ../WildScenes2d/V-02/indexLabel/1623372421-924687173.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372217-774205964.png, ../WildScenes2d/V-02/indexLabel/1623372217-774205964.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372226-082224990.png, ../WildScenes2d/V-02/indexLabel/1623372226-082224990.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372444-838690471.png, ../WildScenes2d/V-02/indexLabel/1623372444-838690471.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371747-096244104.png, ../WildScenes2d/V-02/indexLabel/1623371747-096244104.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371734-835146085.png, ../WildScenes2d/V-02/indexLabel/1623371734-835146085.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371566-529890877.png, ../WildScenes2d/V-02/indexLabel/1623371566-529890877.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372414-822560337.png, ../WildScenes2d/V-02/indexLabel/1623372414-822560337.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372382-595328682.png, ../WildScenes2d/V-02/indexLabel/1623372382-595328682.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371539-998076858.png, ../WildScenes2d/V-02/indexLabel/1623371539-998076858.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372515-591219320.png, ../WildScenes2d/V-02/indexLabel/1623372515-591219320.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372168-059947393.png, ../WildScenes2d/V-02/indexLabel/1623372168-059947393.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372251-073425134.png, ../WildScenes2d/V-02/indexLabel/1623372251-073425134.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371726-325901453.png, ../WildScenes2d/V-02/indexLabel/1623371726-325901453.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371528-407463797.png, ../WildScenes2d/V-02/indexLabel/1623371528-407463797.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372395-928513870.png, ../WildScenes2d/V-02/indexLabel/1623372395-928513870.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372252-748443677.png, ../WildScenes2d/V-02/indexLabel/1623372252-748443677.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372245-981808804.png, ../WildScenes2d/V-02/indexLabel/1623372245-981808804.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372247-254322211.png, ../WildScenes2d/V-02/indexLabel/1623372247-254322211.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371564-725056182.png, ../WildScenes2d/V-02/indexLabel/1623371564-725056182.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372448-122986959.png, ../WildScenes2d/V-02/indexLabel/1623372448-122986959.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371728-201992955.png, ../WildScenes2d/V-02/indexLabel/1623371728-201992955.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371731-552068602.png, ../WildScenes2d/V-02/indexLabel/1623371731-552068602.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372519-477170095.png, ../WildScenes2d/V-02/indexLabel/1623372519-477170095.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371524-521185325.png, ../WildScenes2d/V-02/indexLabel/1623371524-521185325.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372407-988948070.png, ../WildScenes2d/V-02/indexLabel/1623372407-988948070.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372446-182849280.png, ../WildScenes2d/V-02/indexLabel/1623372446-182849280.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372392-377375568.png, ../WildScenes2d/V-02/indexLabel/1623372392-377375568.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372158-077007462.png, ../WildScenes2d/V-02/indexLabel/1623372158-077007462.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371535-041875646.png, ../WildScenes2d/V-02/indexLabel/1623371535-041875646.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372141-327487284.png, ../WildScenes2d/V-02/indexLabel/1623372141-327487284.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372517-065131942.png, ../WildScenes2d/V-02/indexLabel/1623372517-065131942.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372165-514076857.png, ../WildScenes2d/V-02/indexLabel/1623372165-514076857.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372163-907233049.png, ../WildScenes2d/V-02/indexLabel/1623372163-907233049.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372243-971832277.png, ../WildScenes2d/V-02/indexLabel/1623372243-971832277.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371517-687711145.png, ../WildScenes2d/V-02/indexLabel/1623371517-687711145.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372233-318391899.png, ../WildScenes2d/V-02/indexLabel/1623372233-318391899.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371692-490727279.png, ../WildScenes2d/V-02/indexLabel/1623371692-490727279.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372399-144373627.png, ../WildScenes2d/V-02/indexLabel/1623372399-144373627.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372404-639150676.png, ../WildScenes2d/V-02/indexLabel/1623372404-639150676.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372169-674295382.png, ../WildScenes2d/V-02/indexLabel/1623372169-674295382.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372456-168641065.png, ../WildScenes2d/V-02/indexLabel/1623372456-168641065.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372429-629782057.png, ../WildScenes2d/V-02/indexLabel/1623372429-629782057.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372417-103177458.png, ../WildScenes2d/V-02/indexLabel/1623372417-103177458.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371547-635649872.png, ../WildScenes2d/V-02/indexLabel/1623371547-635649872.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372211-141246091.png, ../WildScenes2d/V-02/indexLabel/1623372211-141246091.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372440-952776946.png, ../WildScenes2d/V-02/indexLabel/1623372440-952776946.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372442-493836283.png, ../WildScenes2d/V-02/indexLabel/1623372442-493836283.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371571-291265424.png, ../WildScenes2d/V-02/indexLabel/1623371571-291265424.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372142-934782603.png, ../WildScenes2d/V-02/indexLabel/1623372142-934782603.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372138-981681625.png, ../WildScenes2d/V-02/indexLabel/1623372138-981681625.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372423-738295486.png, ../WildScenes2d/V-02/indexLabel/1623372423-738295486.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371530-684783090.png, ../WildScenes2d/V-02/indexLabel/1623371530-684783090.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371721-703007072.png, ../WildScenes2d/V-02/indexLabel/1623371721-703007072.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372170-873821785.png, ../WildScenes2d/V-02/indexLabel/1623372170-873821785.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372437-937692949.png, ../WildScenes2d/V-02/indexLabel/1623372437-937692949.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371707-632949929.png, ../WildScenes2d/V-02/indexLabel/1623371707-632949929.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372240-152354264.png, ../WildScenes2d/V-02/indexLabel/1623372240-152354264.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372227-154322719.png, ../WildScenes2d/V-02/indexLabel/1623372227-154322719.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371745-423407686.png, ../WildScenes2d/V-02/indexLabel/1623371745-423407686.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371750-446114205.png, ../WildScenes2d/V-02/indexLabel/1623371750-446114205.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372254-222739870.png, ../WildScenes2d/V-02/indexLabel/1623372254-222739870.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371537-384605568.png, ../WildScenes2d/V-02/indexLabel/1623371537-384605568.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371729-743044771.png, ../WildScenes2d/V-02/indexLabel/1623371729-743044771.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371561-303953660.png, ../WildScenes2d/V-02/indexLabel/1623371561-303953660.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372400-687154585.png, ../WildScenes2d/V-02/indexLabel/1623372400-687154585.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372451-740723564.png, ../WildScenes2d/V-02/indexLabel/1623372451-740723564.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372155-666854906.png, ../WildScenes2d/V-02/indexLabel/1623372155-666854906.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372215-630330490.png, ../WildScenes2d/V-02/indexLabel/1623372215-630330490.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371515-140576610.png, ../WildScenes2d/V-02/indexLabel/1623371515-140576610.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372450-199103175.png, ../WildScenes2d/V-02/indexLabel/1623372450-199103175.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372238-477445902.png, ../WildScenes2d/V-02/indexLabel/1623372238-477445902.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372220-320253245.png, ../WildScenes2d/V-02/indexLabel/1623372220-320253245.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372397-206453017.png, ../WildScenes2d/V-02/indexLabel/1623372397-206453017.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372410-802844510.png, ../WildScenes2d/V-02/indexLabel/1623372410-802844510.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371712-188820098.png, ../WildScenes2d/V-02/indexLabel/1623371712-188820098.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372412-880195380.png, ../WildScenes2d/V-02/indexLabel/1623372412-880195380.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372381-389358600.png, ../WildScenes2d/V-02/indexLabel/1623372381-389358600.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371522-242912672.png, ../WildScenes2d/V-02/indexLabel/1623371522-242912672.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371562-911851473.png, ../WildScenes2d/V-02/indexLabel/1623371562-911851473.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371541-136679894.png, ../WildScenes2d/V-02/indexLabel/1623371541-136679894.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371527-468596757.png, ../WildScenes2d/V-02/indexLabel/1623371527-468596757.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372403-298466120.png, ../WildScenes2d/V-02/indexLabel/1623372403-298466120.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371709-977813398.png, ../WildScenes2d/V-02/indexLabel/1623371709-977813398.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372522-961268215.png, ../WildScenes2d/V-02/indexLabel/1623372522-961268215.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372426-949612618.png, ../WildScenes2d/V-02/indexLabel/1623372426-949612618.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372452-476792216.png, ../WildScenes2d/V-02/indexLabel/1623372452-476792216.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371710-983205234.png, ../WildScenes2d/V-02/indexLabel/1623371710-983205234.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372431-505623434.png, ../WildScenes2d/V-02/indexLabel/1623372431-505623434.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371734-366009460.png, ../WildScenes2d/V-02/indexLabel/1623371734-366009460.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372159-349809555.png, ../WildScenes2d/V-02/indexLabel/1623372159-349809555.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371523-247549559.png, ../WildScenes2d/V-02/indexLabel/1623371523-247549559.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371531-756540578.png, ../WildScenes2d/V-02/indexLabel/1623371531-756540578.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372168-999584807.png, ../WildScenes2d/V-02/indexLabel/1623372168-999584807.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372389-497300877.png, ../WildScenes2d/V-02/indexLabel/1623372389-497300877.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372235-060254358.png, ../WildScenes2d/V-02/indexLabel/1623372235-060254358.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371702-875848650.png, ../WildScenes2d/V-02/indexLabel/1623371702-875848650.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372160-287873963.png, ../WildScenes2d/V-02/indexLabel/1623372160-287873963.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372385-208964524.png, ../WildScenes2d/V-02/indexLabel/1623372385-208964524.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371693-303922467.png, ../WildScenes2d/V-02/indexLabel/1623371693-303922467.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372157-546530873.png, ../WildScenes2d/V-02/indexLabel/1623372157-546530873.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623371741-871039179.png, ../WildScenes2d/V-02/indexLabel/1623371741-871039179.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372148-629718679.png, ../WildScenes2d/V-02/indexLabel/1623372148-629718679.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-02/image/1623372162-163825874.png, ../WildScenes2d/V-02/indexLabel/1623372162-163825874.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699685-599545547.png, ../WildScenes2d/V-03/indexLabel/1639699685-599545547.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699988-200941277.png, ../WildScenes2d/V-03/indexLabel/1639699988-200941277.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697225-745668525.png, ../WildScenes2d/V-03/indexLabel/1639697225-745668525.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699636-568263219.png, ../WildScenes2d/V-03/indexLabel/1639699636-568263219.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699954-020401497.png, ../WildScenes2d/V-03/indexLabel/1639699954-020401497.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697525-696105068.png, ../WildScenes2d/V-03/indexLabel/1639697525-696105068.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697514-157437296.png, ../WildScenes2d/V-03/indexLabel/1639697514-157437296.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699643-829071224.png, ../WildScenes2d/V-03/indexLabel/1639699643-829071224.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699614-187262428.png, ../WildScenes2d/V-03/indexLabel/1639699614-187262428.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700020-581775173.png, ../WildScenes2d/V-03/indexLabel/1639700020-581775173.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700023-646945775.png, ../WildScenes2d/V-03/indexLabel/1639700023-646945775.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700021-248427261.png, ../WildScenes2d/V-03/indexLabel/1639700021-248427261.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697781-917507754.png, ../WildScenes2d/V-03/indexLabel/1639697781-917507754.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699973-274347129.png, ../WildScenes2d/V-03/indexLabel/1639699973-274347129.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700053-499939437.png, ../WildScenes2d/V-03/indexLabel/1639700053-499939437.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699621-646735058.png, ../WildScenes2d/V-03/indexLabel/1639699621-646735058.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699663-080600044.png, ../WildScenes2d/V-03/indexLabel/1639699663-080600044.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697775-989559100.png, ../WildScenes2d/V-03/indexLabel/1639697775-989559100.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699936-030415888.png, ../WildScenes2d/V-03/indexLabel/1639699936-030415888.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697500-686205428.png, ../WildScenes2d/V-03/indexLabel/1639697500-686205428.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697506-422463489.png, ../WildScenes2d/V-03/indexLabel/1639697506-422463489.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700024-646669269.png, ../WildScenes2d/V-03/indexLabel/1639700024-646669269.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697494-819369159.png, ../WildScenes2d/V-03/indexLabel/1639697494-819369159.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699991-332627422.png, ../WildScenes2d/V-03/indexLabel/1639699991-332627422.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697775-456831972.png, ../WildScenes2d/V-03/indexLabel/1639697775-456831972.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697496-689294735.png, ../WildScenes2d/V-03/indexLabel/1639697496-689294735.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700051-569276122.png, ../WildScenes2d/V-03/indexLabel/1639700051-569276122.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699618-583063870.png, ../WildScenes2d/V-03/indexLabel/1639699618-583063870.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700023-182257958.png, ../WildScenes2d/V-03/indexLabel/1639700023-182257958.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699666-877893866.png, ../WildScenes2d/V-03/indexLabel/1639699666-877893866.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697777-255508070.png, ../WildScenes2d/V-03/indexLabel/1639697777-255508070.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697482-152921974.png, ../WildScenes2d/V-03/indexLabel/1639697482-152921974.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699640-232155822.png, ../WildScenes2d/V-03/indexLabel/1639699640-232155822.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700040-506086931.png, ../WildScenes2d/V-03/indexLabel/1639700040-506086931.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697527-358573705.png, ../WildScenes2d/V-03/indexLabel/1639697527-358573705.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697814-226027245.png, ../WildScenes2d/V-03/indexLabel/1639697814-226027245.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697816-220124580.png, ../WildScenes2d/V-03/indexLabel/1639697816-220124580.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699647-629274941.png, ../WildScenes2d/V-03/indexLabel/1639699647-629274941.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700042-041377780.png, ../WildScenes2d/V-03/indexLabel/1639700042-041377780.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697789-244473553.png, ../WildScenes2d/V-03/indexLabel/1639697789-244473553.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699964-013264440.png, ../WildScenes2d/V-03/indexLabel/1639699964-013264440.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697803-565615809.png, ../WildScenes2d/V-03/indexLabel/1639697803-565615809.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700039-106562492.png, ../WildScenes2d/V-03/indexLabel/1639700039-106562492.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699664-413237303.png, ../WildScenes2d/V-03/indexLabel/1639699664-413237303.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697796-570864502.png, ../WildScenes2d/V-03/indexLabel/1639697796-570864502.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697221-612165998.png, ../WildScenes2d/V-03/indexLabel/1639697221-612165998.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699945-961143637.png, ../WildScenes2d/V-03/indexLabel/1639699945-961143637.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700028-578259721.png, ../WildScenes2d/V-03/indexLabel/1639700028-578259721.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699993-337018215.png, ../WildScenes2d/V-03/indexLabel/1639699993-337018215.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697774-926897709.png, ../WildScenes2d/V-03/indexLabel/1639697774-926897709.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697810-757878714.png, ../WildScenes2d/V-03/indexLabel/1639697810-757878714.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697521-890209120.png, ../WildScenes2d/V-03/indexLabel/1639697521-890209120.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699989-400279051.png, ../WildScenes2d/V-03/indexLabel/1639699989-400279051.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700043-577127888.png, ../WildScenes2d/V-03/indexLabel/1639700043-577127888.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699625-442987572.png, ../WildScenes2d/V-03/indexLabel/1639699625-442987572.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699940-761340982.png, ../WildScenes2d/V-03/indexLabel/1639699940-761340982.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697805-629255326.png, ../WildScenes2d/V-03/indexLabel/1639697805-629255326.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697482-419460236.png, ../WildScenes2d/V-03/indexLabel/1639697482-419460236.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697220-078510091.png, ../WildScenes2d/V-03/indexLabel/1639697220-078510091.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700053-033503647.png, ../WildScenes2d/V-03/indexLabel/1639700053-033503647.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697774-861247369.png, ../WildScenes2d/V-03/indexLabel/1639697774-861247369.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699629-173224380.png, ../WildScenes2d/V-03/indexLabel/1639699629-173224380.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699695-657362087.png, ../WildScenes2d/V-03/indexLabel/1639699695-657362087.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700035-974039275.png, ../WildScenes2d/V-03/indexLabel/1639700035-974039275.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697519-757270476.png, ../WildScenes2d/V-03/indexLabel/1639697519-757270476.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697775-057193277.png, ../WildScenes2d/V-03/indexLabel/1639697775-057193277.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697520-424631950.png, ../WildScenes2d/V-03/indexLabel/1639697520-424631950.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699940-229422668.png, ../WildScenes2d/V-03/indexLabel/1639699940-229422668.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699691-793326086.png, ../WildScenes2d/V-03/indexLabel/1639699691-793326086.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699965-285193563.png, ../WildScenes2d/V-03/indexLabel/1639699965-285193563.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700057-698232992.png, ../WildScenes2d/V-03/indexLabel/1639700057-698232992.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699943-360241116.png, ../WildScenes2d/V-03/indexLabel/1639699943-360241116.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697775-190359954.png, ../WildScenes2d/V-03/indexLabel/1639697775-190359954.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699980-871014508.png, ../WildScenes2d/V-03/indexLabel/1639699980-871014508.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699632-771497172.png, ../WildScenes2d/V-03/indexLabel/1639699632-771497172.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697806-961542836.png, ../WildScenes2d/V-03/indexLabel/1639697806-961542836.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697779-852675560.png, ../WildScenes2d/V-03/indexLabel/1639697779-852675560.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697505-486333450.png, ../WildScenes2d/V-03/indexLabel/1639697505-486333450.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697533-626381386.png, ../WildScenes2d/V-03/indexLabel/1639697533-626381386.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699984-535799354.png, ../WildScenes2d/V-03/indexLabel/1639699984-535799354.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700022-047842643.png, ../WildScenes2d/V-03/indexLabel/1639700022-047842643.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700042-904556386.png, ../WildScenes2d/V-03/indexLabel/1639700042-904556386.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700024-046886536.png, ../WildScenes2d/V-03/indexLabel/1639700024-046886536.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700022-380854461.png, ../WildScenes2d/V-03/indexLabel/1639700022-380854461.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697790-710785325.png, ../WildScenes2d/V-03/indexLabel/1639697790-710785325.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697785-048163152.png, ../WildScenes2d/V-03/indexLabel/1639697785-048163152.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699937-701679752.png, ../WildScenes2d/V-03/indexLabel/1639699937-701679752.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697487-486412552.png, ../WildScenes2d/V-03/indexLabel/1639697487-486412552.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699658-950036150.png, ../WildScenes2d/V-03/indexLabel/1639699658-950036150.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697774-457721922.png, ../WildScenes2d/V-03/indexLabel/1639697774-457721922.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699977-139420310.png, ../WildScenes2d/V-03/indexLabel/1639699977-139420310.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700031-311395682.png, ../WildScenes2d/V-03/indexLabel/1639700031-311395682.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697511-087220451.png, ../WildScenes2d/V-03/indexLabel/1639697511-087220451.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697504-362047391.png, ../WildScenes2d/V-03/indexLabel/1639697504-362047391.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699610-456417297.png, ../WildScenes2d/V-03/indexLabel/1639699610-456417297.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700047-635886399.png, ../WildScenes2d/V-03/indexLabel/1639700047-635886399.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700034-909476367.png, ../WildScenes2d/V-03/indexLabel/1639700034-909476367.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699655-019473661.png, ../WildScenes2d/V-03/indexLabel/1639699655-019473661.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699950-023586841.png, ../WildScenes2d/V-03/indexLabel/1639699950-023586841.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697506-019041920.png, ../WildScenes2d/V-03/indexLabel/1639697506-019041920.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697517-755455993.png, ../WildScenes2d/V-03/indexLabel/1639697517-755455993.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699672-741290738.png, ../WildScenes2d/V-03/indexLabel/1639699672-741290738.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697481-752864663.png, ../WildScenes2d/V-03/indexLabel/1639697481-752864663.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697774-590871830.png, ../WildScenes2d/V-03/indexLabel/1639697774-590871830.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697220-611765985.png, ../WildScenes2d/V-03/indexLabel/1639697220-611765985.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699608-393115528.png, ../WildScenes2d/V-03/indexLabel/1639699608-393115528.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699939-295313737.png, ../WildScenes2d/V-03/indexLabel/1639699939-295313737.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699934-368451056.png, ../WildScenes2d/V-03/indexLabel/1639699934-368451056.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697530-825611258.png, ../WildScenes2d/V-03/indexLabel/1639697530-825611258.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697483-552863877.png, ../WildScenes2d/V-03/indexLabel/1639697483-552863877.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700029-511282318.png, ../WildScenes2d/V-03/indexLabel/1639700029-511282318.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697774-725148779.png, ../WildScenes2d/V-03/indexLabel/1639697774-725148779.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699960-683408770.png, ../WildScenes2d/V-03/indexLabel/1639699960-683408770.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700056-032239992.png, ../WildScenes2d/V-03/indexLabel/1639700056-032239992.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699930-165580981.png, ../WildScenes2d/V-03/indexLabel/1639699930-165580981.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699956-821281007.png, ../WildScenes2d/V-03/indexLabel/1639699956-821281007.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697507-286430525.png, ../WildScenes2d/V-03/indexLabel/1639697507-286430525.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699668-743134373.png, ../WildScenes2d/V-03/indexLabel/1639699668-743134373.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699651-493996678.png, ../WildScenes2d/V-03/indexLabel/1639699651-493996678.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697491-419766049.png, ../WildScenes2d/V-03/indexLabel/1639697491-419766049.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697803-364485954.png, ../WildScenes2d/V-03/indexLabel/1639697803-364485954.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699687-464158338.png, ../WildScenes2d/V-03/indexLabel/1639699687-464158338.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697803-897331617.png, ../WildScenes2d/V-03/indexLabel/1639697803-897331617.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699969-282568827.png, ../WildScenes2d/V-03/indexLabel/1639699969-282568827.png
# total: 2789 | train: 1952 | val: 557 | test: 280
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377950-815682737.png, ../WildScenes2d/V-01/indexLabel/1623377950-815682737.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378431-680051558.png, ../WildScenes2d/V-01/indexLabel/1623378431-680051558.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377963-278224325.png, ../WildScenes2d/V-01/indexLabel/1623377963-278224325.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378448-361270243.png, ../WildScenes2d/V-01/indexLabel/1623378448-361270243.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378457-343599344.png, ../WildScenes2d/V-01/indexLabel/1623378457-343599344.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377944-584645794.png, ../WildScenes2d/V-01/indexLabel/1623377944-584645794.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623377918-856426136.png, ../WildScenes2d/V-01/indexLabel/1623377918-856426136.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-01/image/1623378442-867568574.png, ../WildScenes2d/V-01/indexLabel/1623378442-867568574.png
# ...
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699621-646735058.png, ../WildScenes2d/V-03/indexLabel/1639699621-646735058.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699663-080600044.png, ../WildScenes2d/V-03/indexLabel/1639699663-080600044.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697775-989559100.png, ../WildScenes2d/V-03/indexLabel/1639697775-989559100.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699936-030415888.png, ../WildScenes2d/V-03/indexLabel/1639699936-030415888.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697500-686205428.png, ../WildScenes2d/V-03/indexLabel/1639697500-686205428.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697506-422463489.png, ../WildScenes2d/V-03/indexLabel/1639697506-422463489.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700024-646669269.png, ../WildScenes2d/V-03/indexLabel/1639700024-646669269.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697494-819369159.png, ../WildScenes2d/V-03/indexLabel/1639697494-819369159.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699991-332627422.png, ../WildScenes2d/V-03/indexLabel/1639699991-332627422.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697775-456831972.png, ../WildScenes2d/V-03/indexLabel/1639697775-456831972.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697496-689294735.png, ../WildScenes2d/V-03/indexLabel/1639697496-689294735.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700051-569276122.png, ../WildScenes2d/V-03/indexLabel/1639700051-569276122.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699618-583063870.png, ../WildScenes2d/V-03/indexLabel/1639699618-583063870.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700023-182257958.png, ../WildScenes2d/V-03/indexLabel/1639700023-182257958.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699666-877893866.png, ../WildScenes2d/V-03/indexLabel/1639699666-877893866.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697777-255508070.png, ../WildScenes2d/V-03/indexLabel/1639697777-255508070.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697482-152921974.png, ../WildScenes2d/V-03/indexLabel/1639697482-152921974.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699640-232155822.png, ../WildScenes2d/V-03/indexLabel/1639699640-232155822.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700040-506086931.png, ../WildScenes2d/V-03/indexLabel/1639700040-506086931.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697527-358573705.png, ../WildScenes2d/V-03/indexLabel/1639697527-358573705.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697814-226027245.png, ../WildScenes2d/V-03/indexLabel/1639697814-226027245.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697816-220124580.png, ../WildScenes2d/V-03/indexLabel/1639697816-220124580.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699647-629274941.png, ../WildScenes2d/V-03/indexLabel/1639699647-629274941.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700042-041377780.png, ../WildScenes2d/V-03/indexLabel/1639700042-041377780.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697789-244473553.png, ../WildScenes2d/V-03/indexLabel/1639697789-244473553.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699964-013264440.png, ../WildScenes2d/V-03/indexLabel/1639699964-013264440.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697803-565615809.png, ../WildScenes2d/V-03/indexLabel/1639697803-565615809.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700039-106562492.png, ../WildScenes2d/V-03/indexLabel/1639700039-106562492.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699664-413237303.png, ../WildScenes2d/V-03/indexLabel/1639699664-413237303.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697796-570864502.png, ../WildScenes2d/V-03/indexLabel/1639697796-570864502.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697221-612165998.png, ../WildScenes2d/V-03/indexLabel/1639697221-612165998.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699945-961143637.png, ../WildScenes2d/V-03/indexLabel/1639699945-961143637.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700028-578259721.png, ../WildScenes2d/V-03/indexLabel/1639700028-578259721.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699993-337018215.png, ../WildScenes2d/V-03/indexLabel/1639699993-337018215.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697774-926897709.png, ../WildScenes2d/V-03/indexLabel/1639697774-926897709.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697810-757878714.png, ../WildScenes2d/V-03/indexLabel/1639697810-757878714.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697521-890209120.png, ../WildScenes2d/V-03/indexLabel/1639697521-890209120.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699989-400279051.png, ../WildScenes2d/V-03/indexLabel/1639699989-400279051.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700043-577127888.png, ../WildScenes2d/V-03/indexLabel/1639700043-577127888.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699625-442987572.png, ../WildScenes2d/V-03/indexLabel/1639699625-442987572.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699940-761340982.png, ../WildScenes2d/V-03/indexLabel/1639699940-761340982.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697805-629255326.png, ../WildScenes2d/V-03/indexLabel/1639697805-629255326.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697482-419460236.png, ../WildScenes2d/V-03/indexLabel/1639697482-419460236.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697220-078510091.png, ../WildScenes2d/V-03/indexLabel/1639697220-078510091.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700053-033503647.png, ../WildScenes2d/V-03/indexLabel/1639700053-033503647.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697774-861247369.png, ../WildScenes2d/V-03/indexLabel/1639697774-861247369.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699629-173224380.png, ../WildScenes2d/V-03/indexLabel/1639699629-173224380.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699695-657362087.png, ../WildScenes2d/V-03/indexLabel/1639699695-657362087.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700035-974039275.png, ../WildScenes2d/V-03/indexLabel/1639700035-974039275.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697519-757270476.png, ../WildScenes2d/V-03/indexLabel/1639697519-757270476.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697775-057193277.png, ../WildScenes2d/V-03/indexLabel/1639697775-057193277.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697520-424631950.png, ../WildScenes2d/V-03/indexLabel/1639697520-424631950.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699940-229422668.png, ../WildScenes2d/V-03/indexLabel/1639699940-229422668.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699691-793326086.png, ../WildScenes2d/V-03/indexLabel/1639699691-793326086.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699965-285193563.png, ../WildScenes2d/V-03/indexLabel/1639699965-285193563.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700057-698232992.png, ../WildScenes2d/V-03/indexLabel/1639700057-698232992.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699943-360241116.png, ../WildScenes2d/V-03/indexLabel/1639699943-360241116.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697775-190359954.png, ../WildScenes2d/V-03/indexLabel/1639697775-190359954.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699980-871014508.png, ../WildScenes2d/V-03/indexLabel/1639699980-871014508.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699632-771497172.png, ../WildScenes2d/V-03/indexLabel/1639699632-771497172.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697806-961542836.png, ../WildScenes2d/V-03/indexLabel/1639697806-961542836.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697779-852675560.png, ../WildScenes2d/V-03/indexLabel/1639697779-852675560.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697505-486333450.png, ../WildScenes2d/V-03/indexLabel/1639697505-486333450.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697533-626381386.png, ../WildScenes2d/V-03/indexLabel/1639697533-626381386.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699984-535799354.png, ../WildScenes2d/V-03/indexLabel/1639699984-535799354.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700022-047842643.png, ../WildScenes2d/V-03/indexLabel/1639700022-047842643.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700042-904556386.png, ../WildScenes2d/V-03/indexLabel/1639700042-904556386.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700024-046886536.png, ../WildScenes2d/V-03/indexLabel/1639700024-046886536.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700022-380854461.png, ../WildScenes2d/V-03/indexLabel/1639700022-380854461.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697790-710785325.png, ../WildScenes2d/V-03/indexLabel/1639697790-710785325.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697785-048163152.png, ../WildScenes2d/V-03/indexLabel/1639697785-048163152.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699937-701679752.png, ../WildScenes2d/V-03/indexLabel/1639699937-701679752.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697487-486412552.png, ../WildScenes2d/V-03/indexLabel/1639697487-486412552.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699658-950036150.png, ../WildScenes2d/V-03/indexLabel/1639699658-950036150.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697774-457721922.png, ../WildScenes2d/V-03/indexLabel/1639697774-457721922.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699977-139420310.png, ../WildScenes2d/V-03/indexLabel/1639699977-139420310.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700031-311395682.png, ../WildScenes2d/V-03/indexLabel/1639700031-311395682.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697511-087220451.png, ../WildScenes2d/V-03/indexLabel/1639697511-087220451.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697504-362047391.png, ../WildScenes2d/V-03/indexLabel/1639697504-362047391.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699610-456417297.png, ../WildScenes2d/V-03/indexLabel/1639699610-456417297.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700047-635886399.png, ../WildScenes2d/V-03/indexLabel/1639700047-635886399.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700034-909476367.png, ../WildScenes2d/V-03/indexLabel/1639700034-909476367.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699655-019473661.png, ../WildScenes2d/V-03/indexLabel/1639699655-019473661.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699950-023586841.png, ../WildScenes2d/V-03/indexLabel/1639699950-023586841.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697506-019041920.png, ../WildScenes2d/V-03/indexLabel/1639697506-019041920.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697517-755455993.png, ../WildScenes2d/V-03/indexLabel/1639697517-755455993.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699672-741290738.png, ../WildScenes2d/V-03/indexLabel/1639699672-741290738.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697481-752864663.png, ../WildScenes2d/V-03/indexLabel/1639697481-752864663.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697774-590871830.png, ../WildScenes2d/V-03/indexLabel/1639697774-590871830.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697220-611765985.png, ../WildScenes2d/V-03/indexLabel/1639697220-611765985.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699608-393115528.png, ../WildScenes2d/V-03/indexLabel/1639699608-393115528.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699939-295313737.png, ../WildScenes2d/V-03/indexLabel/1639699939-295313737.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699934-368451056.png, ../WildScenes2d/V-03/indexLabel/1639699934-368451056.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697530-825611258.png, ../WildScenes2d/V-03/indexLabel/1639697530-825611258.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697483-552863877.png, ../WildScenes2d/V-03/indexLabel/1639697483-552863877.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700029-511282318.png, ../WildScenes2d/V-03/indexLabel/1639700029-511282318.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697774-725148779.png, ../WildScenes2d/V-03/indexLabel/1639697774-725148779.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699960-683408770.png, ../WildScenes2d/V-03/indexLabel/1639699960-683408770.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639700056-032239992.png, ../WildScenes2d/V-03/indexLabel/1639700056-032239992.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699930-165580981.png, ../WildScenes2d/V-03/indexLabel/1639699930-165580981.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699956-821281007.png, ../WildScenes2d/V-03/indexLabel/1639699956-821281007.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697507-286430525.png, ../WildScenes2d/V-03/indexLabel/1639697507-286430525.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699668-743134373.png, ../WildScenes2d/V-03/indexLabel/1639699668-743134373.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699651-493996678.png, ../WildScenes2d/V-03/indexLabel/1639699651-493996678.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697491-419766049.png, ../WildScenes2d/V-03/indexLabel/1639697491-419766049.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697803-364485954.png, ../WildScenes2d/V-03/indexLabel/1639697803-364485954.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699687-464158338.png, ../WildScenes2d/V-03/indexLabel/1639699687-464158338.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639697803-897331617.png, ../WildScenes2d/V-03/indexLabel/1639697803-897331617.png
# Warning: Skipping invalid file pair ../WildScenes2d/V-03/image/1639699969-282568827.png, ../WildScenes2d/V-03/indexLabel/1639699969-282568827.png
# total: 2789 | train: 1952 | val: 557 | test: 280

# %%
import os
import sys
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from data_split import WildScenesDataset
from utils.transforms import TrainTransform, TestTransform

color_map = {
    0: [224, 31, 77],  # Bush
    1: [64, 180, 78],  # Dirt
    2: [26, 127, 127],  # Fence
    3: [127, 127, 127],  # Grass
    4: [145, 24, 178],  # Gravel
    5: [125, 128, 16],  # Log
    6: [251, 225, 48],  # Mud
    7: [248, 190, 190],  # Other-object
    8: [89, 239, 239],  # Other-terrain
    9: [173, 255, 196],  # Rock
    10: [19, 0, 126],  # Sky
    11: [167, 110, 44],  # Structure
    12: [208, 245, 71],  # Tree-foliage
    13: [238, 47, 227],  # Tree-trunk
    14: [40, 127, 198],  # Water
    15: [0, 0, 0],      # 背景类（黑色）
    16: [128, 128, 128],  # 忽略类（灰色）
}

class EnhancedWildScenesDataset(WildScenesDataset):
    def __init__(self, dataset_type, transform=None):
        super().__init__(dataset_type, transform)
        self.color_map = self._load_color_map()
        self.transform = self._get_transform(dataset_type)

    def __getitem__(self, index):
        image_path = self._data_frame['image'][index]
        label_path = self._data_frame['label'][index]

        image = Image.open(image_path).convert('RGB')
        original_label, mapped_label = self.test_label_mapping(label_path)
        label = Image.fromarray(mapped_label.astype(np.uint8))

        if self.transform is not None:
            image, label = self.transform(image, label)

        return image, label

    def _load_color_map(self):
        return {key: np.array(value) for key, value in color_map.items()}

    def _get_transform(self, dataset_type):
        if dataset_type == 'train':
            return TrainTransform()
        elif dataset_type in ['valid', 'test']:
            return TestTransform()
        else:
            raise ValueError('Invalid dataset type')

    @staticmethod
    def get_color_coded_label(label_trainId):
        height, width = label_trainId.shape
        label_RGB = np.zeros((height, width, 3), dtype=np.uint8)
        for trainId, color in color_map.items():
            label_RGB[label_trainId == trainId] = color
        return label_RGB

    @staticmethod
    def get_data_loader(dataset_type, batch_size=4):
        dataset = EnhancedWildScenesDataset(dataset_type)
        shuffle = dataset_type == 'train'
        return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, num_workers=0, pin_memory=True, drop_last=True)

# if __name__ == '__main__':
#     # 测试data_loader
#     train_loader = EnhancedWildScenesDataset.get_data_loader('train', batch_size=4)
#     for images, labels in train_loader:
#         print(f"Batch image shape: {images.shape}")  # 一个批次的图像数据形状，一个批次4个图像，每个图像3通道，每个图像尺寸256*341
#         print(f"Batch label shape: {labels.shape}")  # 一个批次的label数据形状，单通道，表示的是trainId标注的
#         print(f"Batch label unique values: {torch.unique(labels)}")
#         break

#     dataset = EnhancedWildScenesDataset('train')
#     image, label = dataset[0]
#     color_coded_label = dataset.get_color_coded_label(label.numpy())
#     print(f"Color-coded label shape: {color_coded_label.shape}")  # 使用颜色编码的label图像形状，发现是3通道，成了！
# Out:
# Batch image shape: torch.Size([4, 3, 256, 256])
# Batch label shape: torch.Size([4, 256, 256])
# Batch label unique values: tensor([ 0,  5,  6, 12, 13, 14, 16])
# Color-coded label shape: (256, 256, 3)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.cuda.amp import GradScaler, autocast
from tqdm import tqdm
import numpy as np
import os
import logging
from data_load import EnhancedWildScenesDataset
from utils.metrics import calculate_miou_train, calculate_pixel_accuracy, calculate_dice_coefficient
from utils.losses import CombinedLoss
from utils.log import setup_logger, save_checkpoint
from models.unet import UNet
import torch.nn.functional as F


def setup_logger(log_file):
    logging.basicConfig(level=logging.INFO,
                        format='%(asctime)s - %(levelname)s - %(message)s',
                        handlers=[
                            logging.FileHandler(log_file),
                            logging.StreamHandler()
                        ])

def save_checkpoint(model, optimizer, epoch, metrics, path):
    state = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'metrics': metrics
    }
    torch.save(state, path)

def train_epoch(model, dataloader, criterion, optimizer, scheduler, device, num_classes, scaler):
    model.train()
    total_loss = 0
    total_miou = 0
    total_pixel_acc = 0
    total_dice = 0
    num_batches = 0

    for images, labels in tqdm(dataloader, desc="Training"):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        with autocast():
            outputs = model(images)
            if outputs.shape[-2:] != labels.shape[-2:]:
                outputs = F.interpolate(outputs, size=labels.shape[-2:], mode='bilinear', align_corners=False)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item()
        pred = torch.argmax(outputs, dim=1)
        miou = calculate_miou_train(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)
        pixel_acc = calculate_pixel_accuracy(pred.cpu().numpy(), labels.cpu().numpy())
        dice = calculate_dice_coefficient(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)

        if not np.isnan(miou):
            total_miou += miou
            total_pixel_acc += pixel_acc
            total_dice += dice
            num_batches += 1

    return (total_loss / len(dataloader),
            total_miou / num_batches if num_batches > 0 else 0.0,
            total_pixel_acc / num_batches if num_batches > 0 else 0.0,
            total_dice / num_batches if num_batches > 0 else 0.0)

def validate_epoch(model, dataloader, criterion, device, num_classes):
    model.eval()
    total_loss = 0
    total_miou = 0
    total_pixel_acc = 0
    total_dice = 0

    with torch.no_grad():
        for images, labels in tqdm(dataloader, desc="Validating"):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            if outputs.shape[-2:] != labels.shape[-2:]:
                outputs = F.interpolate(outputs, size=labels.shape[-2:], mode='bilinear', align_corners=False)
            loss = criterion(outputs, labels)

            total_loss += loss.item()
            pred = torch.argmax(outputs, dim=1)
            miou = calculate_miou_train(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)
            pixel_acc = calculate_pixel_accuracy(pred.cpu().numpy(), labels.cpu().numpy())
            dice = calculate_dice_coefficient(pred.cpu().numpy(), labels.cpu().numpy(), num_classes)

            total_miou += miou
            total_pixel_acc += pixel_acc
            total_dice += dice

    num_batches = len(dataloader)
    return (total_loss / num_batches,
            total_miou / num_batches,
            total_pixel_acc / num_batches,
            total_dice / num_batches)

def train(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device, save_dir):
    best_loss = float('inf')
    best_miou = 0
    scaler = GradScaler()

    for epoch in range(num_epochs):
        logging.info(f"Epoch {epoch + 1}/{num_epochs}")

        train_loss, train_miou, train_pixel_acc, train_dice = train_epoch(model, train_loader, criterion, optimizer, scheduler, device, num_classes, scaler)
        logging.info(f"Epoch {epoch + 1} - Train Loss: {train_loss:.4f}, Train mIoU: {train_miou:.4f}, "
                     f"Train Pixel Acc: {train_pixel_acc:.4f}, Train Dice: {train_dice:.4f}")

        val_loss, val_miou, val_pixel_acc, val_dice = validate_epoch(model, val_loader, criterion, device, num_classes)
        logging.info(f"Epoch {epoch + 1} - Val Loss: {val_loss:.4f}, Val mIoU: {val_miou:.4f}, "
                     f"Val Pixel Acc: {val_pixel_acc:.4f}, Val Dice: {val_dice:.4f}")

        scheduler.step(val_loss)

        metrics = {
            'val_loss': val_loss,
            'val_miou': val_miou,
            'val_pixel_acc': val_pixel_acc,
            'val_dice': val_dice
        }

        if val_miou > best_miou:
            best_miou = val_miou
            best_model_path = os.path.join(save_dir, f'best_model_epoch_{epoch + 1}.pth')
            save_checkpoint(model, optimizer, epoch + 1, metrics, best_model_path)
            logging.info(f"Epoch {epoch + 1} - Best model saved with Val mIoU: {best_miou:.4f}")

        if (epoch + 1) % 5 == 0:
            checkpoint_path = os.path.join(save_dir, f'checkpoint_epoch_{epoch + 1}.pth')
            save_checkpoint(model, optimizer, epoch + 1, metrics, checkpoint_path)
            logging.info(f"Epoch {epoch + 1} - Checkpoint saved")

        current_lr = optimizer.param_groups[0]['lr']
        logging.info(f"Current learning rate: {current_lr:.6f}")

    logging.info(f"Training completed after {num_epochs} epochs.")
    return best_model_path

if __name__ == "__main__":
    save_dir = 'model_checkpoints/Unet'
    os.makedirs(save_dir, exist_ok=True)

    log_file = os.path.join(save_dir, 'training.log')
    setup_logger(log_file)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logging.info(f"Using device: {device}")

    train_loader = EnhancedWildScenesDataset.get_data_loader('train', batch_size=8)
    val_loader = EnhancedWildScenesDataset.get_data_loader('valid', batch_size=8)

    num_classes = 17

    model = UNet(3, num_classes).to(device)

    criterion = CombinedLoss(weight_focal=1.0, weight_dice=0.5)

    optimizer = optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=5e-5, weight_decay=0.01)

    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5)

    num_epochs = 50
    best_model_path = train(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device, save_dir)
    logging.info(f"Training completed! Best model saved at {best_model_path}")
# Out:
# 2024-07-26 01:24:16,119 - INFO - Using device: cuda
# 2024-07-26 01:24:16,738 - INFO - Epoch 1/60
# Training: 100%|██████████| 244/244 [22:15<00:00,  5.47s/it]
# 2024-07-26 01:46:31,841 - INFO - Epoch 1 - Train Loss: 1.1914, Train mIoU: 0.1744, Train Pixel Acc: 0.7038, Train Dice: 0.2150
# Validating: 100%|██████████| 69/69 [06:10<00:00,  5.36s/it]
# 2024-07-26 01:52:41,892 - INFO - Epoch 1 - Val Loss: 0.8037, Val mIoU: 0.5552, Val Pixel Acc: 0.7822, Val Dice: 0.5953
# 2024-07-26 01:52:42,217 - INFO - Epoch 1 - Best model saved with Val mIoU: 0.5552
# 2024-07-26 01:52:42,219 - INFO - Current learning rate: 0.000050
# 2024-07-26 01:52:42,220 - INFO - Epoch 2/60
# Training: 100%|██████████| 244/244 [21:25<00:00,  5.27s/it]
# 2024-07-26 02:14:07,229 - INFO - Epoch 2 - Train Loss: 0.8033, Train mIoU: 0.2750, Train Pixel Acc: 0.7809, Train Dice: 0.3176
# Validating: 100%|██████████| 69/69 [06:04<00:00,  5.28s/it]
# 2024-07-26 02:20:11,414 - INFO - Epoch 2 - Val Loss: 0.7317, Val mIoU: 0.6134, Val Pixel Acc: 0.8018, Val Dice: 0.6537
# 2024-07-26 02:20:11,752 - INFO - Epoch 2 - Best model saved with Val mIoU: 0.6134
# 2024-07-26 02:20:11,753 - INFO - Current learning rate: 0.000050
# 2024-07-26 02:20:11,755 - INFO - Epoch 3/60
# Training: 100%|██████████| 244/244 [21:45<00:00,  5.35s/it]
# 2024-07-26 02:41:57,166 - INFO - Epoch 3 - Train Loss: 0.7437, Train mIoU: 0.3186, Train Pixel Acc: 0.7905, Train Dice: 0.3634
# Validating: 100%|██████████| 69/69 [06:09<00:00,  5.36s/it]
# 2024-07-26 02:48:06,946 - INFO - Epoch 3 - Val Loss: 0.6784, Val mIoU: 0.6280, Val Pixel Acc: 0.8131, Val Dice: 0.6697
# 2024-07-26 02:48:07,259 - INFO - Epoch 3 - Best model saved with Val mIoU: 0.6280
# 2024-07-26 02:48:07,261 - INFO - Current learning rate: 0.000050
# 2024-07-26 02:48:07,262 - INFO - Epoch 4/60
# Training: 100%|██████████| 244/244 [21:44<00:00,  5.35s/it]
# 2024-07-26 03:09:51,607 - INFO - Epoch 4 - Train Loss: 0.7017, Train mIoU: 0.3699, Train Pixel Acc: 0.8018, Train Dice: 0.4148
# Validating: 100%|██████████| 69/69 [06:17<00:00,  5.47s/it]
# 2024-07-26 03:16:09,054 - INFO - Epoch 4 - Val Loss: 0.6602, Val mIoU: 0.6305, Val Pixel Acc: 0.8192, Val Dice: 0.6704
# 2024-07-26 03:16:09,415 - INFO - Epoch 4 - Best model saved with Val mIoU: 0.6305
# 2024-07-26 03:16:09,416 - INFO - Current learning rate: 0.000050
# 2024-07-26 03:16:09,417 - INFO - Epoch 5/60
# Training: 100%|██████████| 244/244 [22:16<00:00,  5.48s/it]
# 2024-07-26 03:38:25,867 - INFO - Epoch 5 - Train Loss: 0.6787, Train mIoU: 0.4168, Train Pixel Acc: 0.8062, Train Dice: 0.4633
# Validating: 100%|██████████| 69/69 [06:16<00:00,  5.45s/it]
# 2024-07-26 03:44:42,062 - INFO - Epoch 5 - Val Loss: 0.6578, Val mIoU: 0.6313, Val Pixel Acc: 0.8200, Val Dice: 0.6730
# 2024-07-26 03:44:42,405 - INFO - Epoch 5 - Best model saved with Val mIoU: 0.6313
# 2024-07-26 03:44:42,762 - INFO - Epoch 5 - Checkpoint saved
# 2024-07-26 03:44:42,763 - INFO - Current learning rate: 0.000050
# 2024-07-26 03:44:42,764 - INFO - Epoch 6/60
# Training: 100%|██████████| 244/244 [22:00<00:00,  5.41s/it]
# 2024-07-26 04:06:43,554 - INFO - Epoch 6 - Train Loss: 0.6638, Train mIoU: 0.4496, Train Pixel Acc: 0.8093, Train Dice: 0.4972
# Validating: 100%|██████████| 69/69 [06:08<00:00,  5.34s/it]
# 2024-07-26 04:12:51,749 - INFO - Epoch 6 - Val Loss: 0.6388, Val mIoU: 0.6393, Val Pixel Acc: 0.8260, Val Dice: 0.6811
# 2024-07-26 04:12:52,097 - INFO - Epoch 6 - Best model saved with Val mIoU: 0.6393
# 2024-07-26 04:12:52,098 - INFO - Current learning rate: 0.000050
# 2024-07-26 04:12:52,100 - INFO - Epoch 7/60
# Training: 100%|██████████| 244/244 [22:17<00:00,  5.48s/it]
# 2024-07-26 04:35:09,529 - INFO - Epoch 7 - Train Loss: 0.6458, Train mIoU: 0.4810, Train Pixel Acc: 0.8133, Train Dice: 0.5297
# Validating: 100%|██████████| 69/69 [06:13<00:00,  5.42s/it]
# 2024-07-26 04:41:23,490 - INFO - Epoch 7 - Val Loss: 0.6291, Val mIoU: 0.6396, Val Pixel Acc: 0.8248, Val Dice: 0.6823
# 2024-07-26 04:41:23,831 - INFO - Epoch 7 - Best model saved with Val mIoU: 0.6396
# 2024-07-26 04:41:23,833 - INFO - Current learning rate: 0.000050
# 2024-07-26 04:41:23,834 - INFO - Epoch 8/60
# Training: 100%|██████████| 244/244 [22:11<00:00,  5.46s/it]
# 2024-07-26 05:03:35,514 - INFO - Epoch 8 - Train Loss: 0.6357, Train mIoU: 0.4988, Train Pixel Acc: 0.8163, Train Dice: 0.5476
# Validating: 100%|██████████| 69/69 [06:24<00:00,  5.57s/it]
# 2024-07-26 05:10:00,078 - INFO - Epoch 8 - Val Loss: 0.6192, Val mIoU: 0.6443, Val Pixel Acc: 0.8310, Val Dice: 0.6871
# 2024-07-26 05:10:00,732 - INFO - Epoch 8 - Best model saved with Val mIoU: 0.6443
# 2024-07-26 05:10:00,734 - INFO - Current learning rate: 0.000050
# 2024-07-26 05:10:00,736 - INFO - Epoch 9/60
# Training: 100%|██████████| 244/244 [22:22<00:00,  5.50s/it]
# 2024-07-26 05:32:23,682 - INFO - Epoch 9 - Train Loss: 0.6227, Train mIoU: 0.5143, Train Pixel Acc: 0.8201, Train Dice: 0.5643
# Validating: 100%|██████████| 69/69 [06:10<00:00,  5.37s/it]
# 2024-07-26 05:38:34,293 - INFO - Epoch 9 - Val Loss: 0.6102, Val mIoU: 0.6405, Val Pixel Acc: 0.8306, Val Dice: 0.6864
# 2024-07-26 05:38:34,294 - INFO - Current learning rate: 0.000050
# 2024-07-26 05:38:34,295 - INFO - Epoch 10/60
# Training: 100%|██████████| 244/244 [21:50<00:00,  5.37s/it]
# 2024-07-26 06:00:24,870 - INFO - Epoch 10 - Train Loss: 0.6162, Train mIoU: 0.5163, Train Pixel Acc: 0.8212, Train Dice: 0.5659
# Validating: 100%|██████████| 69/69 [06:10<00:00,  5.37s/it]
# 2024-07-26 06:06:35,414 - INFO - Epoch 10 - Val Loss: 0.6053, Val mIoU: 0.6525, Val Pixel Acc: 0.8301, Val Dice: 0.6998
# 2024-07-26 06:06:35,746 - INFO - Epoch 10 - Best model saved with Val mIoU: 0.6525
# 2024-07-26 06:06:36,111 - INFO - Epoch 10 - Checkpoint saved
# 2024-07-26 06:06:36,112 - INFO - Current learning rate: 0.000050
# 2024-07-26 06:06:36,113 - INFO - Epoch 11/60
# Training: 100%|██████████| 244/244 [21:56<00:00,  5.39s/it]
# 2024-07-26 06:28:32,266 - INFO - Epoch 11 - Train Loss: 0.6140, Train mIoU: 0.5192, Train Pixel Acc: 0.8207, Train Dice: 0.5696
# Validating: 100%|██████████| 69/69 [06:09<00:00,  5.36s/it]
# 2024-07-26 06:34:42,197 - INFO - Epoch 11 - Val Loss: 0.6067, Val mIoU: 0.6532, Val Pixel Acc: 0.8309, Val Dice: 0.7001
# 2024-07-26 06:34:42,534 - INFO - Epoch 11 - Best model saved with Val mIoU: 0.6532
# 2024-07-26 06:34:42,536 - INFO - Current learning rate: 0.000050
# 2024-07-26 06:34:42,537 - INFO - Epoch 12/60
# Training: 100%|██████████| 244/244 [21:51<00:00,  5.38s/it]
# 2024-07-26 06:56:34,340 - INFO - Epoch 12 - Train Loss: 0.6004, Train mIoU: 0.5275, Train Pixel Acc: 0.8254, Train Dice: 0.5781
# Validating: 100%|██████████| 69/69 [06:08<00:00,  5.34s/it]
# 2024-07-26 07:02:42,956 - INFO - Epoch 12 - Val Loss: 0.5893, Val mIoU: 0.6547, Val Pixel Acc: 0.8350, Val Dice: 0.7019
# 2024-07-26 07:02:43,298 - INFO - Epoch 12 - Best model saved with Val mIoU: 0.6547
# 2024-07-26 07:02:43,300 - INFO - Current learning rate: 0.000050
# 2024-07-26 07:02:43,301 - INFO - Epoch 13/60
# Training: 100%|██████████| 244/244 [21:44<00:00,  5.35s/it]
# 2024-07-26 07:24:28,181 - INFO - Epoch 13 - Train Loss: 0.5947, Train mIoU: 0.5235, Train Pixel Acc: 0.8272, Train Dice: 0.5744
# Validating: 100%|██████████| 69/69 [06:10<00:00,  5.37s/it]
# 2024-07-26 07:30:38,811 - INFO - Epoch 13 - Val Loss: 0.5883, Val mIoU: 0.6564, Val Pixel Acc: 0.8341, Val Dice: 0.7046
# 2024-07-26 07:30:39,150 - INFO - Epoch 13 - Best model saved with Val mIoU: 0.6564
# 2024-07-26 07:30:39,152 - INFO - Current learning rate: 0.000050
# 2024-07-26 07:30:39,153 - INFO - Epoch 14/60
# Training: 100%|██████████| 244/244 [22:10<00:00,  5.45s/it]
# 2024-07-26 07:52:49,848 - INFO - Epoch 14 - Train Loss: 0.5873, Train mIoU: 0.5374, Train Pixel Acc: 0.8291, Train Dice: 0.5890
# Validating: 100%|██████████| 69/69 [06:14<00:00,  5.42s/it]
# 2024-07-26 07:59:03,942 - INFO - Epoch 14 - Val Loss: 0.5897, Val mIoU: 0.6577, Val Pixel Acc: 0.8304, Val Dice: 0.7102
# 2024-07-26 07:59:04,278 - INFO - Epoch 14 - Best model saved with Val mIoU: 0.6577
# 2024-07-26 07:59:04,280 - INFO - Current learning rate: 0.000050
# 2024-07-26 07:59:04,281 - INFO - Epoch 15/60
# Training: 100%|██████████| 244/244 [21:48<00:00,  5.36s/it]
# 2024-07-26 08:20:52,332 - INFO - Epoch 15 - Train Loss: 0.5799, Train mIoU: 0.5382, Train Pixel Acc: 0.8301, Train Dice: 0.5914
# Validating: 100%|██████████| 69/69 [06:05<00:00,  5.30s/it]
# 2024-07-26 08:26:58,022 - INFO - Epoch 15 - Val Loss: 0.5920, Val mIoU: 0.6520, Val Pixel Acc: 0.8347, Val Dice: 0.7014
# 2024-07-26 08:26:58,359 - INFO - Epoch 15 - Checkpoint saved
# 2024-07-26 08:26:58,361 - INFO - Current learning rate: 0.000050
# 2024-07-26 08:26:58,362 - INFO - Epoch 16/60
# Training: 100%|██████████| 244/244 [21:53<00:00,  5.38s/it]
# 2024-07-26 08:48:52,179 - INFO - Epoch 16 - Train Loss: 0.5786, Train mIoU: 0.5446, Train Pixel Acc: 0.8303, Train Dice: 0.5985
# Validating: 100%|██████████| 69/69 [06:05<00:00,  5.29s/it]
# 2024-07-26 08:54:57,455 - INFO - Epoch 16 - Val Loss: 0.5807, Val mIoU: 0.6673, Val Pixel Acc: 0.8350, Val Dice: 0.7194
# 2024-07-26 08:54:57,763 - INFO - Epoch 16 - Best model saved with Val mIoU: 0.6673
# 2024-07-26 08:54:57,765 - INFO - Current learning rate: 0.000050
# 2024-07-26 08:54:57,766 - INFO - Epoch 17/60
# Training: 100%|██████████| 244/244 [21:43<00:00,  5.34s/it]
# 2024-07-26 09:16:41,740 - INFO - Epoch 17 - Train Loss: 0.5714, Train mIoU: 0.5369, Train Pixel Acc: 0.8321, Train Dice: 0.5921
# Validating: 100%|██████████| 69/69 [06:05<00:00,  5.29s/it]
# 2024-07-26 09:22:47,017 - INFO - Epoch 17 - Val Loss: 0.5728, Val mIoU: 0.6620, Val Pixel Acc: 0.8377, Val Dice: 0.7138
# 2024-07-26 09:22:47,018 - INFO - Current learning rate: 0.000050
# 2024-07-26 09:22:47,019 - INFO - Epoch 18/60
# Training: 100%|██████████| 244/244 [21:44<00:00,  5.35s/it]
# 2024-07-26 09:44:31,544 - INFO - Epoch 18 - Train Loss: 0.5624, Train mIoU: 0.5473, Train Pixel Acc: 0.8345, Train Dice: 0.6035
# Validating: 100%|██████████| 69/69 [05:56<00:00,  5.16s/it]
# 2024-07-26 09:50:27,836 - INFO - Epoch 18 - Val Loss: 0.5745, Val mIoU: 0.6618, Val Pixel Acc: 0.8384, Val Dice: 0.7124
# 2024-07-26 09:50:27,837 - INFO - Current learning rate: 0.000050
# 2024-07-26 09:50:27,838 - INFO - Epoch 19/60
# Training: 100%|██████████| 244/244 [21:19<00:00,  5.25s/it]
# 2024-07-26 10:11:47,790 - INFO - Epoch 19 - Train Loss: 0.5628, Train mIoU: 0.5576, Train Pixel Acc: 0.8344, Train Dice: 0.6149
# Validating: 100%|██████████| 69/69 [05:57<00:00,  5.18s/it]
# 2024-07-26 10:17:44,998 - INFO - Epoch 19 - Val Loss: 0.5641, Val mIoU: 0.6614, Val Pixel Acc: 0.8385, Val Dice: 0.7166
# 2024-07-26 10:17:44,999 - INFO - Current learning rate: 0.000050
# 2024-07-26 10:17:45,000 - INFO - Epoch 20/60
# Training: 100%|██████████| 244/244 [21:30<00:00,  5.29s/it]
# 2024-07-26 10:39:15,198 - INFO - Epoch 20 - Train Loss: 0.5528, Train mIoU: 0.5636, Train Pixel Acc: 0.8374, Train Dice: 0.6219
# Validating: 100%|██████████| 69/69 [06:00<00:00,  5.23s/it]
# 2024-07-26 10:45:15,832 - INFO - Epoch 20 - Val Loss: 0.5605, Val mIoU: 0.6639, Val Pixel Acc: 0.8392, Val Dice: 0.7180
# 2024-07-26 10:45:16,211 - INFO - Epoch 20 - Checkpoint saved
# 2024-07-26 10:45:16,212 - INFO - Current learning rate: 0.000050
# 2024-07-26 10:45:16,213 - INFO - Epoch 21/60
# Training: 100%|██████████| 244/244 [21:26<00:00,  5.27s/it]
# 2024-07-26 11:06:43,087 - INFO - Epoch 21 - Train Loss: 0.5461, Train mIoU: 0.5737, Train Pixel Acc: 0.8387, Train Dice: 0.6331
# Validating: 100%|██████████| 69/69 [06:00<00:00,  5.23s/it]
# 2024-07-26 11:12:43,870 - INFO - Epoch 21 - Val Loss: 0.5678, Val mIoU: 0.6597, Val Pixel Acc: 0.8419, Val Dice: 0.7112
# 2024-07-26 11:12:43,871 - INFO - Current learning rate: 0.000050
# 2024-07-26 11:12:43,873 - INFO - Epoch 22/60
# Training: 100%|██████████| 244/244 [21:20<00:00,  5.25s/it]
# 2024-07-26 11:34:04,258 - INFO - Epoch 22 - Train Loss: 0.5415, Train mIoU: 0.5788, Train Pixel Acc: 0.8404, Train Dice: 0.6382
# Validating: 100%|██████████| 69/69 [05:59<00:00,  5.21s/it]
# 2024-07-26 11:40:03,771 - INFO - Epoch 22 - Val Loss: 0.5614, Val mIoU: 0.6680, Val Pixel Acc: 0.8414, Val Dice: 0.7243
# 2024-07-26 11:40:04,118 - INFO - Epoch 22 - Best model saved with Val mIoU: 0.6680
# 2024-07-26 11:40:04,119 - INFO - Current learning rate: 0.000050
# 2024-07-26 11:40:04,120 - INFO - Epoch 23/60
# Training: 100%|██████████| 244/244 [21:19<00:00,  5.24s/it]
# 2024-07-26 12:01:23,739 - INFO - Epoch 23 - Train Loss: 0.5431, Train mIoU: 0.5663, Train Pixel Acc: 0.8389, Train Dice: 0.6272
# Validating: 100%|██████████| 69/69 [05:57<00:00,  5.19s/it]
# 2024-07-26 12:07:21,616 - INFO - Epoch 23 - Val Loss: 0.5711, Val mIoU: 0.6690, Val Pixel Acc: 0.8385, Val Dice: 0.7206
# 2024-07-26 12:07:21,932 - INFO - Epoch 23 - Best model saved with Val mIoU: 0.6690
# 2024-07-26 12:07:21,934 - INFO - Current learning rate: 0.000050
# 2024-07-26 12:07:21,935 - INFO - Epoch 24/60
# Training: 100%|██████████| 244/244 [21:45<00:00,  5.35s/it]
# 2024-07-26 12:29:07,179 - INFO - Epoch 24 - Train Loss: 0.5361, Train mIoU: 0.5727, Train Pixel Acc: 0.8418, Train Dice: 0.6337
# Validating: 100%|██████████| 69/69 [05:58<00:00,  5.20s/it]
# 2024-07-26 12:35:05,773 - INFO - Epoch 24 - Val Loss: 0.5597, Val mIoU: 0.6704, Val Pixel Acc: 0.8439, Val Dice: 0.7256
# 2024-07-26 12:35:06,108 - INFO - Epoch 24 - Best model saved with Val mIoU: 0.6704
# 2024-07-26 12:35:06,110 - INFO - Current learning rate: 0.000050
# 2024-07-26 12:35:06,111 - INFO - Epoch 25/60
# Training: 100%|██████████| 244/244 [21:55<00:00,  5.39s/it]
# 2024-07-26 12:57:02,111 - INFO - Epoch 25 - Train Loss: 0.5305, Train mIoU: 0.5784, Train Pixel Acc: 0.8432, Train Dice: 0.6401
# Validating: 100%|██████████| 69/69 [06:29<00:00,  5.64s/it]
# 2024-07-26 13:03:31,617 - INFO - Epoch 25 - Val Loss: 0.5562, Val mIoU: 0.6709, Val Pixel Acc: 0.8424, Val Dice: 0.7265
# 2024-07-26 13:03:31,958 - INFO - Epoch 25 - Best model saved with Val mIoU: 0.6709
# 2024-07-26 13:03:32,290 - INFO - Epoch 25 - Checkpoint saved
# 2024-07-26 13:03:32,292 - INFO - Current learning rate: 0.000050
# 2024-07-26 13:03:32,293 - INFO - Epoch 26/60
# Training: 100%|██████████| 244/244 [23:30<00:00,  5.78s/it]
# 2024-07-26 13:27:02,596 - INFO - Epoch 26 - Train Loss: 0.5239, Train mIoU: 0.5776, Train Pixel Acc: 0.8442, Train Dice: 0.6401
# Validating: 100%|██████████| 69/69 [06:42<00:00,  5.83s/it]
# 2024-07-26 13:33:44,770 - INFO - Epoch 26 - Val Loss: 0.5580, Val mIoU: 0.6729, Val Pixel Acc: 0.8407, Val Dice: 0.7308
# 2024-07-26 13:33:45,121 - INFO - Epoch 26 - Best model saved with Val mIoU: 0.6729
# 2024-07-26 13:33:45,123 - INFO - Current learning rate: 0.000050
# 2024-07-26 13:33:45,124 - INFO - Epoch 27/60
# Training: 100%|██████████| 244/244 [23:32<00:00,  5.79s/it]
# 2024-07-26 13:57:17,268 - INFO - Epoch 27 - Train Loss: 0.5196, Train mIoU: 0.5851, Train Pixel Acc: 0.8456, Train Dice: 0.6485
# Validating: 100%|██████████| 69/69 [06:37<00:00,  5.76s/it]
# 2024-07-26 14:03:54,771 - INFO - Epoch 27 - Val Loss: 0.5572, Val mIoU: 0.6784, Val Pixel Acc: 0.8456, Val Dice: 0.7345
# 2024-07-26 14:03:55,124 - INFO - Epoch 27 - Best model saved with Val mIoU: 0.6784
# 2024-07-26 14:03:55,125 - INFO - Current learning rate: 0.000050
# 2024-07-26 14:03:55,125 - INFO - Epoch 28/60
# Training: 100%|██████████| 244/244 [22:50<00:00,  5.62s/it]
# 2024-07-26 14:26:45,408 - INFO - Epoch 28 - Train Loss: 0.5167, Train mIoU: 0.5957, Train Pixel Acc: 0.8459, Train Dice: 0.6592
# Validating: 100%|██████████| 69/69 [06:28<00:00,  5.62s/it]
# 2024-07-26 14:33:13,532 - INFO - Epoch 28 - Val Loss: 0.5519, Val mIoU: 0.6788, Val Pixel Acc: 0.8384, Val Dice: 0.7375
# 2024-07-26 14:33:13,865 - INFO - Epoch 28 - Best model saved with Val mIoU: 0.6788
# 2024-07-26 14:33:13,867 - INFO - Current learning rate: 0.000050
# 2024-07-26 14:33:13,868 - INFO - Epoch 29/60
# Training: 100%|██████████| 244/244 [23:21<00:00,  5.74s/it]
# 2024-07-26 14:56:34,929 - INFO - Epoch 29 - Train Loss: 0.5140, Train mIoU: 0.5987, Train Pixel Acc: 0.8467, Train Dice: 0.6633
# Validating: 100%|██████████| 69/69 [06:32<00:00,  5.68s/it]
# 2024-07-26 15:03:06,952 - INFO - Epoch 29 - Val Loss: 0.5488, Val mIoU: 0.6818, Val Pixel Acc: 0.8412, Val Dice: 0.7415
# 2024-07-26 15:03:07,289 - INFO - Epoch 29 - Best model saved with Val mIoU: 0.6818
# 2024-07-26 15:03:07,291 - INFO - Current learning rate: 0.000050
# 2024-07-26 15:03:07,292 - INFO - Epoch 30/60
# Training: 100%|██████████| 244/244 [23:14<00:00,  5.72s/it]
# 2024-07-26 15:26:22,234 - INFO - Epoch 30 - Train Loss: 0.5113, Train mIoU: 0.5891, Train Pixel Acc: 0.8482, Train Dice: 0.6538
# Validating: 100%|██████████| 69/69 [06:30<00:00,  5.67s/it]
# 2024-07-26 15:32:53,235 - INFO - Epoch 30 - Val Loss: 0.5485, Val mIoU: 0.6845, Val Pixel Acc: 0.8413, Val Dice: 0.7447
# 2024-07-26 15:32:53,604 - INFO - Epoch 30 - Best model saved with Val mIoU: 0.6845
# 2024-07-26 15:32:53,962 - INFO - Epoch 30 - Checkpoint saved
# 2024-07-26 15:32:53,963 - INFO - Current learning rate: 0.000050
# 2024-07-26 15:32:53,963 - INFO - Epoch 31/60
# Training: 100%|██████████| 244/244 [23:43<00:00,  5.83s/it]
# 2024-07-26 15:56:37,236 - INFO - Epoch 31 - Train Loss: 0.5040, Train mIoU: 0.6013, Train Pixel Acc: 0.8496, Train Dice: 0.6671
# Validating: 100%|██████████| 69/69 [06:41<00:00,  5.82s/it]
# 2024-07-26 16:03:19,023 - INFO - Epoch 31 - Val Loss: 0.5438, Val mIoU: 0.6828, Val Pixel Acc: 0.8452, Val Dice: 0.7430
# 2024-07-26 16:03:19,024 - INFO - Current learning rate: 0.000050
# 2024-07-26 16:03:19,025 - INFO - Epoch 32/60
# Training: 100%|██████████| 244/244 [24:04<00:00,  5.92s/it]
# 2024-07-26 16:27:23,509 - INFO - Epoch 32 - Train Loss: 0.5013, Train mIoU: 0.5987, Train Pixel Acc: 0.8510, Train Dice: 0.6640
# Validating: 100%|██████████| 69/69 [06:31<00:00,  5.68s/it]
# 2024-07-26 16:33:55,197 - INFO - Epoch 32 - Val Loss: 0.5571, Val mIoU: 0.6774, Val Pixel Acc: 0.8361, Val Dice: 0.7385
# 2024-07-26 16:33:55,198 - INFO - Current learning rate: 0.000050
# 2024-07-26 16:33:55,198 - INFO - Epoch 33/60
# Training: 100%|██████████| 244/244 [23:12<00:00,  5.71s/it]
# 2024-07-26 16:57:07,544 - INFO - Epoch 33 - Train Loss: 0.4966, Train mIoU: 0.6037, Train Pixel Acc: 0.8513, Train Dice: 0.6691
# Validating: 100%|██████████| 69/69 [06:25<00:00,  5.58s/it]
# 2024-07-26 17:03:32,558 - INFO - Epoch 33 - Val Loss: 0.5433, Val mIoU: 0.6760, Val Pixel Acc: 0.8399, Val Dice: 0.7376
# 2024-07-26 17:03:32,559 - INFO - Current learning rate: 0.000050
# 2024-07-26 17:03:32,560 - INFO - Epoch 34/60
# Training: 100%|██████████| 244/244 [23:11<00:00,  5.70s/it]
# 2024-07-26 17:26:43,710 - INFO - Epoch 34 - Train Loss: 0.4924, Train mIoU: 0.6180, Train Pixel Acc: 0.8518, Train Dice: 0.6842
# Validating: 100%|██████████| 69/69 [06:39<00:00,  5.78s/it]
# 2024-07-26 17:33:22,752 - INFO - Epoch 34 - Val Loss: 0.5361, Val mIoU: 0.6837, Val Pixel Acc: 0.8437, Val Dice: 0.7455
# 2024-07-26 17:33:22,753 - INFO - Current learning rate: 0.000050
# 2024-07-26 17:33:22,754 - INFO - Epoch 35/60
# Training: 100%|██████████| 244/244 [22:05<00:00,  5.43s/it]
# 2024-07-26 17:55:28,468 - INFO - Epoch 35 - Train Loss: 0.4835, Train mIoU: 0.6170, Train Pixel Acc: 0.8524, Train Dice: 0.6840
# Validating: 100%|██████████| 69/69 [06:01<00:00,  5.24s/it]
# 2024-07-26 18:01:29,979 - INFO - Epoch 35 - Val Loss: 0.5174, Val mIoU: 0.6906, Val Pixel Acc: 0.8461, Val Dice: 0.7535
# 2024-07-26 18:01:30,321 - INFO - Epoch 35 - Best model saved with Val mIoU: 0.6906
# 2024-07-26 18:01:30,653 - INFO - Epoch 35 - Checkpoint saved
# 2024-07-26 18:01:30,654 - INFO - Current learning rate: 0.000050
# 2024-07-26 18:01:30,655 - INFO - Epoch 36/60
# Training: 100%|██████████| 244/244 [21:42<00:00,  5.34s/it]
# 2024-07-26 18:23:12,909 - INFO - Epoch 36 - Train Loss: 0.4667, Train mIoU: 0.6517, Train Pixel Acc: 0.8517, Train Dice: 0.7178
# Validating: 100%|██████████| 69/69 [06:07<00:00,  5.32s/it]
# 2024-07-26 18:29:20,051 - INFO - Epoch 36 - Val Loss: 0.4986, Val mIoU: 0.6913, Val Pixel Acc: 0.8398, Val Dice: 0.7529
# 2024-07-26 18:29:20,386 - INFO - Epoch 36 - Best model saved with Val mIoU: 0.6913
# 2024-07-26 18:29:20,387 - INFO - Current learning rate: 0.000050
# 2024-07-26 18:29:20,388 - INFO - Epoch 37/60
# Training: 100%|██████████| 244/244 [21:54<00:00,  5.39s/it]
# 2024-07-26 18:51:14,696 - INFO - Epoch 37 - Train Loss: 0.4448, Train mIoU: 0.6494, Train Pixel Acc: 0.8497, Train Dice: 0.7160
# Validating: 100%|██████████| 69/69 [06:48<00:00,  5.92s/it]
# 2024-07-26 18:58:02,877 - INFO - Epoch 37 - Val Loss: 0.4600, Val mIoU: 0.6869, Val Pixel Acc: 0.8420, Val Dice: 0.7452
# 2024-07-26 18:58:02,877 - INFO - Current learning rate: 0.000050
# 2024-07-26 18:58:02,878 - INFO - Epoch 38/60
# Training: 100%|██████████| 244/244 [22:29<00:00,  5.53s/it]
# 2024-07-26 19:20:32,121 - INFO - Epoch 38 - Train Loss: 0.4165, Train mIoU: 0.6657, Train Pixel Acc: 0.8470, Train Dice: 0.7320
# Validating: 100%|██████████| 69/69 [06:14<00:00,  5.42s/it]
# 2024-07-26 19:26:46,234 - INFO - Epoch 38 - Val Loss: 0.4515, Val mIoU: 0.6850, Val Pixel Acc: 0.8397, Val Dice: 0.7467
# 2024-07-26 19:26:46,236 - INFO - Current learning rate: 0.000050
# 2024-07-26 19:26:46,237 - INFO - Epoch 39/60
# Training: 100%|██████████| 244/244 [23:09<00:00,  5.69s/it]
# 2024-07-26 19:49:55,497 - INFO - Epoch 39 - Train Loss: 0.3916, Train mIoU: 0.6784, Train Pixel Acc: 0.8487, Train Dice: 0.7440
# Validating: 100%|██████████| 69/69 [06:08<00:00,  5.35s/it]
# 2024-07-26 19:56:04,369 - INFO - Epoch 39 - Val Loss: 0.4199, Val mIoU: 0.6995, Val Pixel Acc: 0.8407, Val Dice: 0.7621
# 2024-07-26 19:56:04,736 - INFO - Epoch 39 - Best model saved with Val mIoU: 0.6995
# 2024-07-26 19:56:04,737 - INFO - Current learning rate: 0.000050
# 2024-07-26 19:56:04,738 - INFO - Epoch 40/60
# Training: 100%|██████████| 244/244 [22:02<00:00,  5.42s/it]
# 2024-07-26 20:18:07,014 - INFO - Epoch 40 - Train Loss: 0.3691, Train mIoU: 0.6978, Train Pixel Acc: 0.8493, Train Dice: 0.7643
# Validating: 100%|██████████| 69/69 [06:29<00:00,  5.64s/it]
# 2024-07-26 20:24:36,232 - INFO - Epoch 40 - Val Loss: 0.4004, Val mIoU: 0.6967, Val Pixel Acc: 0.8364, Val Dice: 0.7576
# 2024-07-26 20:24:36,601 - INFO - Epoch 40 - Checkpoint saved
# 2024-07-26 20:24:36,602 - INFO - Current learning rate: 0.000050
# 2024-07-26 20:24:36,603 - INFO - Epoch 41/60
# Training: 100%|██████████| 244/244 [23:40<00:00,  5.82s/it]
# 2024-07-26 20:48:16,728 - INFO - Epoch 41 - Train Loss: 0.3515, Train mIoU: 0.7004, Train Pixel Acc: 0.8492, Train Dice: 0.7674
# Validating: 100%|██████████| 69/69 [06:42<00:00,  5.84s/it]
# 2024-07-26 20:54:59,548 - INFO - Epoch 41 - Val Loss: 0.3943, Val mIoU: 0.7009, Val Pixel Acc: 0.8396, Val Dice: 0.7628
# 2024-07-26 20:54:59,969 - INFO - Epoch 41 - Best model saved with Val mIoU: 0.7009
# 2024-07-26 20:54:59,970 - INFO - Current learning rate: 0.000050
# 2024-07-26 20:54:59,970 - INFO - Epoch 42/60
# Training: 100%|██████████| 244/244 [22:17<00:00,  5.48s/it]
# 2024-07-26 21:17:17,369 - INFO - Epoch 42 - Train Loss: 0.3454, Train mIoU: 0.7021, Train Pixel Acc: 0.8488, Train Dice: 0.7678
# Validating: 100%|██████████| 69/69 [06:47<00:00,  5.91s/it]
# 2024-07-26 21:24:05,325 - INFO - Epoch 42 - Val Loss: 0.3787, Val mIoU: 0.7013, Val Pixel Acc: 0.8443, Val Dice: 0.7629
# 2024-07-26 21:24:05,668 - INFO - Epoch 42 - Best model saved with Val mIoU: 0.7013
# 2024-07-26 21:24:05,670 - INFO - Current learning rate: 0.000050
# 2024-07-26 21:24:05,671 - INFO - Epoch 43/60
# Training: 100%|██████████| 244/244 [24:00<00:00,  5.90s/it]
# 2024-07-26 21:48:05,988 - INFO - Epoch 43 - Train Loss: 0.3359, Train mIoU: 0.7030, Train Pixel Acc: 0.8497, Train Dice: 0.7691
# Validating: 100%|██████████| 69/69 [06:07<00:00,  5.33s/it]
# 2024-07-26 21:54:13,464 - INFO - Epoch 43 - Val Loss: 0.3767, Val mIoU: 0.7014, Val Pixel Acc: 0.8429, Val Dice: 0.7627
# 2024-07-26 21:54:13,824 - INFO - Epoch 43 - Best model saved with Val mIoU: 0.7014
# 2024-07-26 21:54:13,826 - INFO - Current learning rate: 0.000050
# 2024-07-26 21:54:13,827 - INFO - Epoch 44/60
# Training: 100%|██████████| 244/244 [22:10<00:00,  5.45s/it]
# 2024-07-26 22:16:24,536 - INFO - Epoch 44 - Train Loss: 0.3284, Train mIoU: 0.7026, Train Pixel Acc: 0.8497, Train Dice: 0.7695
# Validating: 100%|██████████| 69/69 [06:13<00:00,  5.41s/it]
# 2024-07-26 22:22:37,659 - INFO - Epoch 44 - Val Loss: 0.3920, Val mIoU: 0.6931, Val Pixel Acc: 0.8448, Val Dice: 0.7514
# 2024-07-26 22:22:37,661 - INFO - Current learning rate: 0.000050
# 2024-07-26 22:22:37,662 - INFO - Epoch 45/60
# Training: 100%|██████████| 244/244 [21:57<00:00,  5.40s/it]
# 2024-07-26 22:44:34,685 - INFO - Epoch 45 - Train Loss: 0.3201, Train mIoU: 0.7082, Train Pixel Acc: 0.8497, Train Dice: 0.7755
# Validating: 100%|██████████| 69/69 [06:09<00:00,  5.35s/it]
# 2024-07-26 22:50:43,803 - INFO - Epoch 45 - Val Loss: 0.3728, Val mIoU: 0.6986, Val Pixel Acc: 0.8397, Val Dice: 0.7607
# 2024-07-26 22:50:44,143 - INFO - Epoch 45 - Checkpoint saved
# 2024-07-26 22:50:44,145 - INFO - Current learning rate: 0.000050
# 2024-07-26 22:50:44,146 - INFO - Epoch 46/60
# Training: 100%|██████████| 244/244 [21:52<00:00,  5.38s/it]
# 2024-07-26 23:12:36,819 - INFO - Epoch 46 - Train Loss: 0.3091, Train mIoU: 0.7123, Train Pixel Acc: 0.8521, Train Dice: 0.7794
# Validating: 100%|██████████| 69/69 [06:10<00:00,  5.37s/it]
# 2024-07-26 23:18:47,152 - INFO - Epoch 46 - Val Loss: 0.3819, Val mIoU: 0.6955, Val Pixel Acc: 0.8404, Val Dice: 0.7546
# 2024-07-26 23:18:47,153 - INFO - Current learning rate: 0.000050
# 2024-07-26 23:18:47,154 - INFO - Epoch 47/60
# Training: 100%|██████████| 244/244 [22:01<00:00,  5.42s/it]
# 2024-07-26 23:40:48,472 - INFO - Epoch 47 - Train Loss: 0.3043, Train mIoU: 0.7132, Train Pixel Acc: 0.8535, Train Dice: 0.7799
# Validating: 100%|██████████| 69/69 [06:12<00:00,  5.40s/it]
# 2024-07-26 23:47:00,819 - INFO - Epoch 47 - Val Loss: 0.3803, Val mIoU: 0.6947, Val Pixel Acc: 0.8425, Val Dice: 0.7540
# 2024-07-26 23:47:00,821 - INFO - Current learning rate: 0.000050
# 2024-07-26 23:47:00,822 - INFO - Epoch 48/60
# Training:  59%|█████▊    | 143/244 [12:56<09:06,  5.41s/it]

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
from tqdm import tqdm
import seaborn as sns
from data_load import EnhancedWildScenesDataset
from torchvision import models
from models.unet import UNet
from sklearn.metrics import confusion_matrix
import csv
import pandas as pd

# 定义颜色映射
color_map = {
    1: [224, 31, 77],  # Bush
    0: [64, 180, 78],  # Dirt
    2: [26, 127, 127],  # Fence
    14: [127, 127, 127],  # Grass
    3: [145, 24, 178],  # Gravel
    13: [125, 128, 16],  # Log
    12: [251, 225, 48],  # Mud
    7: [248, 190, 190],  # Other-object
    8: [89, 239, 239],  # Other-terrain
    9: [173, 255, 196],  # Rock
    16: [19, 0, 126],  # Sky
    11: [167, 110, 44],  # Structure
    6: [208, 245, 71],  # Tree-foliage
    5: [238, 47, 227],  # Tree-trunk
    4: [40, 127, 198],  # Water
    15: [0, 0, 0],  # 背景类（黑色）
    10: [128, 128, 128],  # 忽略类（灰色）
}

class_names = ['Dirt', 'Bush', 'Fence', 'Gravel', 'Water', 'Tree-trunk', 'Tree-Foliage', 'Other-object',
               'Other-terrain', 'Rock', 'Ignore', 'Structure', 'Mud', 'Log', 'Grass', 'Background', 'Sky']


def apply_color_map(segmentation):
    color_segmentation = np.zeros((*segmentation.shape, 3), dtype=np.uint8)
    for class_idx, color in color_map.items():
        color_segmentation[segmentation == class_idx] = color
    return color_segmentation


def overlay_segmentation(image, segmentation, alpha=0.5):
    colored_seg = apply_color_map(segmentation)
    return (image * (1 - alpha) + colored_seg * alpha).astype(np.uint8)


def save_comparison(image, ground_truth, prediction, index, save_dir):
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

    ax1.imshow(image.permute(1, 2, 0).cpu().numpy())
    ax1.set_title('Original Image')
    ax1.axis('off')

    ax2.imshow(apply_color_map(ground_truth.cpu().numpy()))
    ax2.set_title('Ground Truth')
    ax2.axis('off')

    ax3.imshow(apply_color_map(prediction.cpu().numpy()))
    ax3.set_title('Prediction')
    ax3.axis('off')

    ax4.imshow(overlay_segmentation(image.permute(1, 2, 0).cpu().numpy(), prediction.cpu().numpy()))
    ax4.set_title('Overlay')
    ax4.axis('off')

    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, f'comparison_{index}.png'))
    plt.close()


def plot_confusion_matrix(y_true, y_pred, save_path):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.savefig(save_path)
    plt.close()


def plot_per_class_iou(class_iou, save_path):
    plt.figure(figsize=(12, 6))
    valid_iou = [iou for iou in class_iou if not np.isnan(iou)]
    plt.bar(range(len(valid_iou)), valid_iou)
    plt.title('Per-class IoU')
    plt.xlabel('Class')
    plt.ylabel('IoU')
    valid_class_names = [name for i, name in enumerate(class_names) if i < len(valid_iou)]
    plt.xticks(range(len(valid_iou)), valid_class_names, rotation=90)
    plt.tight_layout()
    plt.savefig(save_path)
    plt.close()


def calculate_miou(pred, target, num_classes):
    ious = []
    pred = pred.ravel()
    target = target.ravel()
    for cls in range(num_classes):
        pred_inds = pred == cls
        target_inds = target == cls
        intersection = np.logical_and(pred_inds, target_inds).sum()
        union = np.logical_or(pred_inds, target_inds).sum()
        if union == 0:
            ious.append(float('nan'))  # 如果该类别不存在，则IoU为NaN
        else:
            ious.append(intersection / union)
    miou = np.nanmean(ious)  # 忽略NaN值计算平均IoU
    return miou, np.array(ious)


def visualize_results(model, dataloader, device, num_classes, save_dir):
    model.eval()
    all_class_ious = np.zeros(num_classes)
    class_counts = np.zeros(num_classes)
    image_ious = []

    with torch.no_grad():
        for i, (images, labels) in enumerate(tqdm(dataloader, desc="Visualizing")):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)

            if len(labels.shape) == 4 and labels.shape[1] > 1:
                labels = torch.argmax(labels, dim=1)

            if outputs.shape[2:] != labels.shape[1:]:
                outputs = F.interpolate(outputs, size=labels.shape[1:], mode='bilinear', align_corners=True)

            pred = torch.argmax(outputs, dim=1)

            # 计算每张图片的IoU
            for j in range(images.shape[0]):
                image_index = i * dataloader.batch_size + j
                _, class_ious = calculate_miou(pred[j].cpu().numpy(), labels[j].cpu().numpy(), num_classes)
                all_class_ious += np.nan_to_num(class_ious)
                class_counts += ~np.isnan(class_ious)
                image_ious.append(class_ious)

                # 只保存特定索引的图片
                if image_index in [0, 10, 20, 30]:
                    save_comparison(images[j], labels[j], pred[j], image_index, save_dir)

    # 计算平均IoU
    average_ious = np.where(class_counts > 0, all_class_ious / class_counts, 0)

    print("Class IoUs:")
    for cls, iou in enumerate(average_ious):
        print(f"Class {cls} ({class_names[cls]}): {iou:.4f}")

    # 绘制每类IoU图
    plot_per_class_iou(average_ious, os.path.join(save_dir, 'per_class_iou.png'))

    # 计算mIoU
    miou = np.mean(average_ious)
    print(f"Mean IoU: {miou:.4f}")

    # 创建并保存CSV文件
    csv_file = os.path.join(save_dir, 'image_class_ious.csv')
    df = pd.DataFrame(image_ious, columns=[f"{cls}_{name}" for cls, name in enumerate(class_names)])
    df.index.name = 'Image_Number'
    df.to_csv(csv_file)
    print(f"Image-wise class IoUs saved to {csv_file}")

    return average_ious, miou

if __name__ == "__main__":
    save_dir = 'visualization_results/Unet'
    os.makedirs(save_dir, exist_ok=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    num_classes = 17

    # 创建UNet模型实例
    model = UNet(3, num_classes).to(device)

    # 加载模型权重
    model_path = os.path.join('model_checkpoints', 'Unet', 'checkpoint_epoch_50.pth')
    checkpoint = torch.load(model_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])

    model.eval()

    test_loader = EnhancedWildScenesDataset.get_data_loader('test', batch_size=8)

    # 运行可视化并获取结果
    class_ious, miou = visualize_results(model, test_loader, device, num_classes, save_dir)

    # 保存结果到文件
    results_file = os.path.join(save_dir, 'iou_results.txt')
    with open(results_file, 'w') as f:
        f.write(f"Mean IoU: {miou:.4f}\n\n")
        f.write("Class IoUs:\n")
        for cls, iou in enumerate(class_ious):
            f.write(f"Class {cls} ({class_names[cls]}): {iou:.4f}\n")

    print(f"Visualization results and IoU statistics saved in {save_dir}")
